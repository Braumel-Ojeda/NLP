# %% [markdown]
# # Preprocessing: Normalization and Lemmatization
#
# On this notebook is developed the normalization and lemmatization for preprocessing part within the NLP process.

# %%
# Importamos las bibliotecas necesarias...
from nltk.corpus import PlaintextCorpusReader
from bs4 import BeautifulSoup
import re

# %%
def lemmatize(text):
    from pickle import dump
    lemmas = dict()
    
    with open('./generate.txt', encoding = 'latin1') as file:
        lines = file.readlines()
        for line in lines:
            line = line.strip()
            if line != '':
                words = line.split()
                token = words[0].strip()
                token = token.replace('#', '')
                lemma = words[-1].strip()
                lemmas[token] = lemma
                
    lemmatized_text = []
    for word in text:
        if word in lemmas.keys():
            lemmatized_text.append(lemmas[word])
        else:
            lemmatized_text.append(word)
    return lemmatized_text

# %%
def normalize(path = './../EXCELSIOR_100_files/'):
    # Obtenemos el corpus del directorio...
    corpus = PlaintextCorpusReader(path, '.*')
    file_list = corpus.fileids()
    # Se reune el contenido textual de todos los archivos
    all_text = ''
    for file in file_list:
        with open(path + file, encoding = 'utf-8') as rfile:
            text = rfile.read()
            all_text += text
    # Limpiamos las etiquetas HTML
    soup = BeautifulSoup(all_text, 'lxml')
    clean_text = soup.get_text()
    clean_text = clean_text.lower()
    # Realizamos tokenización
    words = clean_text.split()
    alphabetic_words = []
    for word in words:
        token = []
        for character in word:
            if re.match(r'^[a-záéíóúñü+$]', character):
                token.append(character)
        token = ''.join(token)
        if token != '':
            alphabetic_words.append(token)        
    
    # Quitamos 'Stop words'...
    with open('./stopwords_es.txt', encoding = 'utf-8') as f:
        stop_words = f.readlines()
        stop_words = [w.strip() for w in stop_words]
    final_words = [word for word in alphabetic_words if word not in stop_words]
    print('Fin de la normalización...')
    return final_words

# %%
try:
    words = normalize()
    print(f'Algunas palabras despues de la normalización: \n{words[:200]}')
except Exception as e:
    print('Ocurrió el siguiente error: ', e)
# Out:
# Fin de la normalización...
# Algunas palabras despues de la normalización:
# ['emodhtm', 'httpwwwexcelsiorcommxarthtml', 'excelsior', 'editorial', 'martes', 'abril', 'monstruosa', 'diferencia', 'colosistas', 'colosismo', 'luis', 'gutierrez', 'gonzalez', 'luis', 'gutiérrez', 'sotomayor', 'federico', 'arreola', 'colosistas', 'cabales', 'según', 'dijo', 'amigo', 'luis', 'donaldo', 'ciertamente', 'nombre', 'circunstancias', 'luis', 'donaldo', 'colosio', 'llenado', 'insistentemente', 'volúmenes', 'espacios', 'medios', 'comunicación', 'renovada', 'actualidad', 'padecido', 'frenético', 'vaivén', 'ficciones', 'judiciales', 'políticas', 'integran', 'disgregan', 'metafísicas', 'metafísicas', 'aún', 'luis', 'donaldo', 'desprende', 'envuelve', 'lado', 'espejo', 'dos', 'años', 'eternos', 'insolvencias', 'dale', 'dale', 'fantasía', 'magia', 'dónde', 'quedó', 'bolita', 'traído', 'pueblo', 'hastío', 'cansancio', 'inminencia', 'percibe', 'váyanse', 'diablo', 'quórum', 'nacional', 'veía', 'decidido', 'instalar', 'sécula', 'seculórum', 'demandas', 'justicia', 'segundo', 'aniversario', 'asesinato', 'colosismo', 'astroso', 'luto', 'protagónico', 'intentado', 'empapar', 'drama', 'colosista', 'espesas', 'negras', 'lágrimas', 'llorona', 'profesional', 'velorio', 'antigüita', 'diciéndose', 'heredero', 'ideas', 'derechos', 'supuesto', 'paradigma', 'trampa', 'tendió', 'esotérico', 'colosismo', 'presidente', 'zedillo', 'ponce', 'león', 'amigo', 'líder', 'mandatario', 'dedica', 'culto', 'seguimiento', 'espirituales', 'dándole', 'satisfacción', 'compromisos', 'políticos', 'aquel', 'contrajo', 'actitud', 'moral', 'propició', 'trampa', 'fulano', 'zutano', 'dijeron', 'discípulos', 'hermanos', 'compañeros', 'lucha', 'asesores', 'caído', 'veras', 'hicieron', 'lado', 'vieron', 'cargar', 'don', 'ernesto', 'tropel', 'búfalos', 'llora', 'mama', 'colosistas', 'supieron', 'quisieron', 'vergüenza', 'confundidos', 'pegarse', 'ubre', 'mal', 'hicieron', 'colosismo', 'repartió', 'mercedes', 'presidenciales', 'parteaguas', 'brecha', 'insondable', 'separando', 'colosistas', 'colosismo', 'bandos', 'luis', 'donaldo', 'llamaba', 'dijo', 'nombres', 'respectivos', 'cabales', 'oportunistas', 'efeméride', 'dolorosa', 'colosismo', 'intentó', 'constituirse', 'dogma', 'doctrina', 'credo', 'político', 'allá', 'magdalena', 'leyendo', 'lumpen', 'histriónico', 'viendo', 'protagonismos', 'don', 'luis', 'colosio']

# %%
try:
    words_lemmatized = lemmatize(words)
    print(f'Algunas palabras despues de la lematización: \n{words_lemmatized[:200]}')
except Exception as e:
    print('Ocurrió el siguiente error: ', e)
# Out:
# Algunas palabras despues de la lematización:
# ['emodhtm', 'httpwwwexcelsiorcommxarthtml', 'excelsior', 'editorial', 'martes', 'abril', 'monstruoso', 'diferencia', 'colosistas', 'colosismo', 'luis', 'gutierrez', 'gonzalez', 'luis', 'gutiérrez', 'sotomayor', 'federico', 'arreola', 'colosistas', 'cabal', 'según', 'decir', 'amigo', 'luis', 'donaldo', 'ciertamente', 'nombre', 'circunstancia', 'luis', 'donaldo', 'colosio', 'llenar', 'insistentemente', 'volumen', 'espacio', 'medio', 'comunicación', 'renovar', 'actualidad', 'padecer', 'frenético', 'vaivén', 'ficción', 'judicial', 'política', 'integrar', 'disgregar', 'metafísicas', 'metafísicas', 'aún', 'luis', 'donaldo', 'desprender', 'envolver', 'lado', 'espejo', 'dos', 'año', 'eterno', 'insolvencias', 'dar', 'dar', 'fantasía', 'magia', 'dónde', 'quedar', 'bolita', 'traer', 'pueblo', 'hastío', 'cansancio', 'inminencia', 'percibir', 'ir', 'diablo', 'quórum', 'nacional', 'ver', 'decidido', 'instalar', 'sécula', 'seculórum', 'demanda', 'justicia', 'segundo', 'aniversario', 'asesinato', 'colosismo', 'astroso', 'luto', 'protagónico', 'intentar', 'empapar', 'drama', 'colosista', 'espeso', 'negra', 'lágrima', 'llorona', 'profesional', 'velorio', 'antigüita', 'decir', 'heredero', 'idea', 'derecho', 'suponer', 'paradigma', 'trampa', 'tender', 'esotérico', 'colosismo', 'presidente', 'zedillo', 'ponce', 'león', 'amigo', 'líder', 'mandatario', 'dedicar', 'culto', 'seguimiento', 'espiritual', 'dar', 'satisfacción', 'compromiso', 'político', 'aquel', 'contraer', 'actitud', 'moral', 'propiciar', 'trampa', 'fulano', 'zutano', 'decir', 'discípulo', 'hermano', 'compañero', 'lucha', 'asesorar', 'caer', 'veras', 'hacer', 'lado', 'ver', 'cargar', 'don', 'ernesto', 'tropel', 'búfalo', 'llorar', 'mama', 'colosistas', 'saber', 'querer', 'vergüenza', 'confundido', 'pegar', 'ubre', 'mal', 'hacer', 'colosismo', 'repartir', 'mercedes', 'presidenciales', 'parteaguas', 'brecha', 'insondable', 'separar', 'colosistas', 'colosismo', 'bando', 'luis', 'donaldo', 'llamar', 'decir', 'nombre', 'respectivo', 'cabal', 'oportunista', 'efeméride', 'doloroso', 'colosismo', 'intentar', 'constituir', 'dogma', 'doctrina', 'credo', 'político', 'allá', 'magdalena', 'leer', 'lumpen', 'histriónico', 'ver', 'protagonismos', 'don', 'luis', 'colosio']

# %%
from collections import Counter

def make_vocabulary(words):
    vocabulary = sorted(list(set(words)))
    return vocabulary


def find_context(word, words, window_size = 4):
    context = list()
    for i in range(len(words)):
        if words[i] == word:
            context += words[i - window_size:i] + words[i + 1:i + window_size + 1]
    return context


def create_vector_space(words, vocabulary):
    vector_space = list()
    for word in vocabulary:
        context = find_context(word, words)
        counter = Counter(context)
        vector_space.append(counter)
    return vector_space

# %%
vocabulary = make_vocabulary(words_lemmatized)

# %%
vocabulary
# Out:
# ['abandonar',
#  'abandono',
#  'abarcar',
#  'abarrotar',
#  'abascal',
#  'abasto',
#  'abatir',
#  'abbasso',
#  'abdicar',
#  'aberrantes',
#  'abierto',
#  'abitia',
#  'abono',
#  'abordaje',
#  'aborigen',
#  'abraham',
#  'abrego',
#  'abril',
#  'abrir',
#  'absalón',
#  'absoluto',
#  'absuelto',
#  'absurdamente',
#  'absurdo',
#  'abuelo',
#  'abundante',
#  'abundar',
#  'aburto',
#  'abusar',
#  'abuso',
#  'ac',
#  'acabado',
#  'acabar',
#  'acaparar',
#  'acapulco',
#  'acarreo',
#  'acaso',
#  'accesible',
#  'acceso',
#  'accidente',
#  'accionar',
#  'accionista',
#  'acción',
#  'acelerar',
#  'acento',
#  'acentuado',
#  'aceptabilidad',
#  'aceptar',
#  'acercar',
#  'acero',
#  'acertado',
#  'acierto',
#  'aclaración',
#  'aclarar',
#  'acompañado',
#  'acompañamiento',
#  'acompañar',
#  'aconsejable',
#  'aconsejar',
#  'acontecimiento',
#  'acopio',
#  'acoplamiento',
#  'acoplar',
#  'acorde',
#  'acotar',
#  'acrecentar',
#  'acreditar',
#  'acreedor',
#  'actitud',
#  'activar',
#  'actividad',
#  'activo',
#  'acto',
#  'actor',
#  'actriz',
#  'actuación',
#  'actual',
#  'actualidad',
#  'actualizar',
#  'actualmente',
#  'actuar',
#  'acudir',
#  'acuerdo',
#  'acumulación',
#  'acumular',
#  'acusación',
#  'acusado',
#  'acusar',
#  'adaptar',
#  'adecuadamente',
#  'adecuado',
#  'adelante',
#  'además',
#  'ades',
#  'adeudos',
#  'adicional',
#  'adición',
#  'adjudicar',
#  'adjunta',
#  'adjunto',
#  'administración',
#  'administrador',
#  'administradora',
#  'administrativa',
#  'administrativo',
#  'admirar',
#  'admitir',
#  'adolf',
#  'adolfo',
#  'adoptar',
#  'adornar',
#  'adquirir',
#  'adquisición',
#  'adquisitivo',
#  'adreessen',
#  'adrián',
#  'aducir',
#  'adulto',
#  'advenedizo',
#  'advenimiento',
#  'adverso',
#  'advertencia',
#  'advertir',
#  'advirtiótambién',
#  'aedpch',
#  'aerolíneas',
#  'aeronave',
#  'aeroportuarias',
#  'aeropuerto',
#  'afectado',
#  'afectar',
#  'aferrar',
#  'afiliar',
#  'afirmación',
#  'afirmar',
#  'afore',
#  'afores',
#  'aforismo',
#  'aforo',
#  'afortunado',
#  'afrancisco',
#  'africa',
#  'afrontar',
#  'afuera',
#  'afán',
#  'agencia',
#  'agenda',
#  'agente',
#  'agilidad',
#  'agilizar',
#  'agobiar',
#  'agonía',
#  'agosto',
#  'agotar',
#  'agradecer',
#  'agradezgo',
#  'agrario',
#  'agrarismo',
#  'agraristas',
#  'agraviado',
#  'agreden',
#  'agregado',
#  'agregar',
#  'agremiados',
#  'agricultor',
#  'agro',
#  'agropecuario',
#  'agrupación',
#  'agrupar',
#  'agrícola',
#  'agua',
#  'aguascalientes',
#  'agudización',
#  'agudizar',
#  'agudo',
#  'aguilar',
#  'aguinaco',
#  'aguirre',
#  'agustin',
#  'ahogada',
#  'ahogar',
#  'ahondar',
#  'ahora',
#  'ahorita',
#  'ahorrador',
#  'ahorradores',
#  'ahorro',
#  'ahuyentar',
#  'ahí',
#  'aicm',
#  'aicn',
#  'aire',
#  'aislado',
#  'ajustar',
#  'ajuste',
#  'ala',
#  'alabat',
#  'alarcón',
#  'alargamiento',
#  'alarmante',
#  'alberto',
#  'albino',
#  'albor',
#  'alcalde',
#  'alcance',
#  'alcanzar',
#  'alcayaga',
#  'alcista',
#  'alcohólica',
#  'aldf',
#  'alegar',
#  'alegre',
#  'alejandro',
#  'alejar',
#  'alemania',
#  'alemanista',
#  'alemán',
#  'alentador',
#  'alerta',
#  'alertar',
#  'alfa',
#  'alfaro',
#  'alfonso',
#  'alfredo',
#  'alférez',
#  'alguien',
#  'alguna',
#  'alguno',
#  'algún',
#  'aliado',
#  'alianza',
#  'alice',
#  'alimentación',
#  'alimentario',
#  'alimenticio',
#  'alimento',
#  'allegada',
#  'allende',
#  'alliance',
#  'allora',
#  'allá',
#  'allí',
#  'almacenar',
#  'almoloya',
#  'alonso',
#  'alpha',
#  'alponte',
#  'alpro',
#  'alrededor',
#  'alta',
#  'altamirano',
#  'altar',
#  'altarcito',
#  'alteración',
#  'alterar',
#  'alternar',
#  'altibajos',
#  'alto',
#  'altoparlante',
#  'altura',
#  'altísimo',
#  'alumno',
#  'alvarado',
#  'alvarez',
#  'alvaro',
#  'alza',
#  'alzamiento',
#  'amador',
#  'amargo',
#  'amarra',
#  'amañar',
#  'ambas',
#  'ambicioso',
#  'ambiente',
#  'ambos',
#  'amelia',
#  'amenaza',
#  'america',
#  'americom',
#  'amhym',
#  'amib',
#  'amiga',
#  'amigo',
#  'amor',
#  'amortización',
#  'amparo',
#  'ampliamente',
#  'ampliar',
#  'amplio',
#  'américa',
#  'analista',
#  'analizar',
#  'analítico',
#  'anarquía',
#  'anciano',
#  'andar',
#  'andreessen',
#  'andres',
#  'andrés',
#  'andrómeda',
#  'ane',
#  'anexo',
#  'angel',
#  'angeles',
#  'angloamericanos',
#  'angustia',
#  'angustioso',
#  'anhelar',
#  'anillo',
#  'aniversario',
#  'anomalía',
#  'anotar',
#  'ansioso',
#  'antagónico',
#  'antaño',
#  'antecesor',
#  'antelmo',
#  'anteproyecto',
#  'anterior',
#  'anteriormente',
#  'anticipación',
#  'anticipar',
#  'anticonstitucionales',
#  'antiguo',
#  'antigüita',
#  'antimigratoria',
#  'antipatía',
#  'antonio',
#  'antorcha',
#  'antuna',
#  'anual',
#  'anuencia',
#  'anular',
#  'anunciar',
#  'anuncio',
#  'anáhuac',
#  'análisis',
#  'apacible',
#  'apaciguar',
#  'apapacho',
#  'aparato',
#  'aparecer',
#  'aparentemente',
#  'aparición',
#  'apartado',
#  'apartar',
#  'aparte',
#  'apegar',
#  'apego',
#  'apelación',
#  'apenas',
#  'apertura',
#  'aplicable',
#  'aplicación',
#  'aplicado',
#  'aplicar',
#  'apoderado',
#  'apoderamientos',
#  'apoderar',
#  'aporrear',
#  'aportar',
#  'apostar',
#  'apoteótica',
#  'apoyar',
#  'apoyo',
#  'apple',
#  'applets',
#  'apreciación',
#  'apreciar',
#  'aprehensión',
#  'aprender',
#  'apresar',
#  'apresta',
#  'apresurar',
#  'aprobación',
#  'aprobar',
#  'apropiado',
#  'aprovechada',
#  'aprovechamiento',
#  'aprovechar',
#  'aproximadamente',
#  'aproximado',
#  'aptitud',
#  'apuntar',
#  'aquejar',
#  'aquel',
#  'aquella',
#  'aquello',
#  'aquellos',
#  'aquél',
#  'aquí',
#  'ara',
#  'aragón',
#  'arancel',
#  'arbitral',
#  'arbitrario',
#  'arca',
#  'archivo',
#  'arco',
#  'arder',
#  'ardid',
#  'arena',
#  'argentina',
#  'argumentar',
#  'argumento',
#  'aria',
#  'arizmendi',
#  'arma',
#  'armada',
#  'armado',
#  'armando',
#  'armonía',
#  'armónicamente',
#  'armónico',
#  'arnault',
#  'arqueológico',
#  'arquitecto',
#  'arquitectura',
#  'arrancar',
#  'arrastrar',
#  'arreglo',
#  'arrendadora',
#  'arreola',
#  'arresto',
#  'arriba',
#  'arribar',
#  'arribo',
#  'arrobaexcelsiorcommx',
#  'arrojar',
#  'arropar',
#  'arroyo',
#  'arte',
#  'artificial',
#  'artimaña',
#  'artista',
#  'arturo',
#  'artículo',
#  'arvizu',
#  'arzobispo',
#  'arzú',
#  'asa',
#  'asalariada',
#  'asalariado',
#  'asaltante',
#  'asamblea',
#  'asambleísta',
#  'asambleístas',
#  'ascender',
#  'ascensión',
#  'ascenso',
#  'asegurar',
#  'asentar',
#  'asentir',
#  'asequible',
#  'asesinar',
#  'asesinato',
#  'asesino',
#  'asesorar',
#  'asesoría',
#  'aseverar',
#  'asfixia',
#  'asfixiar',
#  'asignación',
#  'asignar',
#  'asimilar',
#  'asimismo',
#  'asir',
#  'asistencia',
#  'asistencial',
#  'asistente',
#  'asistir',
#  'asociación',
#  'asociar',
#  'aspecto',
#  'aspiración',
#  'aspirar',
#  'astronauta',
#  'astroso',
#  'astucia',
#  'asueto',
#  'asumir',
#  'asunto',
#  'atacar',
#  'atajar',
#  'atar',
#  'atención',
#  'atender',
#  'atentamente',
#  'atentar',
#  'aterrizaje',
#  'aterrizar',
#  'atinadamente',
#  'atinado',
#  'atisbar',
#  'atlantis',
#  'atoyac',
#  'atracar',
#  'atractivo',
#  'atraer',
#  'atraso',
#  'atravesar',
#  'através',
#  'atribución',
#  'audio',
#  'auditar',
#  'auditoria',
#  'auditorias',
#  'auditorio',
#  'auditoría',
#  'augusta',
#  'aumentar',
#  'aumento',
#  'aun',
#  'aunque',
#  'auque',
#  'aurora',
#  'ausentismo',
#  'auspiciar',
#  'australia',
#  'austria',
#  'auto',
#  'autobús',
#  'autoconsumo',
#  'autoinvasiones',
#  'automática',
#  'automáticamente',
#  'automático',
#  'automóvil',
#  'autonomía',
#  'autopista',
#  'autor',
#  'autoridad',
#  'autoritarismo',
#  'autorizar',
#  'autotransporte',
#  'autotransportes',
#  'autrey',
#  'auténtica',
#  'auténtico',
#  'autónomo',
#  'auxiliar',
#  'auxilio',
#  'av',
#  'avalúos',
#  'avance',
#  'avanzar',
#  'avecinan',
#  'avelar',
#  'avenida',
#  'averiguaciones',
#  'averiguar',
#  'aversión',
#  'avila',
#  'avisar',
#  'aviso',
#  'avión',
#  'ayala',
#  'ayer',
#  'ayuda',
#  'ayudar',
#  'ayuno',
#  'azcapotzalco',
#  'azteca',
#  'azul',
#  'azúcar',
#  'aéreo',
#  'añadir',
#  'año',
#  'aún',
#  'bache',
#  'bah',
#  'baile',
#  'baja',
#  'bajar',
#  'bajo',
#  'balance',
#  'balanza',
#  'baldenegro',
#  'balneario',
#  'balón',
#  'banamex',
#  'banc',
#  'banca',
#  'bancario',
#  'bancarrota',
#  'banco',
#  'bancomer',
#  'bandera',
#  'bandido',
#  'bando',
#  'banjidal',
#  'banobras',
#  'banquero',
#  'banqueta',
#  'banrural',
#  'banxico',
#  'baranda',
#  'barato',
#  'barba',
#  'barca',
#  'barco',
#  'barra',
#  'barragán',
#  'barreda',
#  'barrio',
#  'bartola',
#  'basar',
#  'base',
#  'bastante',
#  'bastar',
#  'basura',
#  'baño',
#  'bdem',
#  'beach',
#  'bebida',
#  'beca',
#  'becerril',
#  'bell',
#  'beltrones',
#  'belén',
#  'bendecir',
#  'bendición',
#  'beneficiar',
#  'beneficiario',
#  'beneficios',
#  'benito',
#  'benévolo',
#  'berdejo',
#  'bernal',
#  'besar',
#  'bezanilla',
#  'bianual',
#  'bicicleta',
#  'bien',
#  'bienestar',
#  'bienintencionado',
#  'bienvenidos',
#  'bill',
#  'billete',
#  'bimestre',
#  'biofísicos',
#  'biológico',
#  'bla',
#  'blaha',
#  'blanca',
#  'blanco',
#  'blando',
#  'blanquiazul',
#  'blemas',
#  'bloquear',
#  'bmv',
#  'bobo',
#  'boca',
#  'bodrios',
#  'boeing',
#  'bolita',
#  'bolsa',
#  'bolseros',
#  'bombardear',
#  'bonhomía',
#  'bonos',
#  'boom',
#  'borde',
#  'bordo',
#  'borghese',
#  'borja',
#  'borrego',
#  'bosque',
#  'botín',
#  'bours',
#  'brasil',
#  'braun',
#  'brecha',
#  'bretaña',
#  'brete',
#  'breve',
#  'breves',
#  'brindar',
#  'brito',
#  'británica',
#  'brote',
#  'brusco',
#  'brutal',
#  'bruto',
#  'buena',
#  'bueno',
#  'bulevar',
#  'burla',
#  'burlar',
#  'bursátil',
#  'busca',
#  'buscar',
#  'butírica',
#  'buzonsímbolo',
#  'básicamente',
#  'básico',
#  'búfalo',
#  'búho',
#  'búsqueda',
#  'cabal',
#  'caballero',
#  'caballeroso',
#  'cabalmente',
#  'caber',
#  'cabeza',
#  'cabezal',
#  'cabida',
#  'cabildo',
#  'cabina',
#  'cabo',
#  'cabrera',
#  'cada',
#  'cadena',
#  'caer',
#  'café',
#  'caifás',
#  'cairo',
#  'caj',
#  'cajb',
#  'cajero',
#  'calabozo',
#  'calado',
#  'calcular',
#  'caldaria',
#  'caldera',
#  'calderón',
#  'calidad',
#  'calificación',
#  'calificar',
#  'california',
#  'californianas',
#  'calle',
#  'callejón',
#  'calley',
#  'callista',
#  'calor',
#  'calumnia',
#  'cama',
#  'camacho',
#  'cambiar',
#  'cambiaria',
#  'cambiario',
#  'cambio',
#  'caminar',
#  'camino',
#  'camioneras',
#  'camioneta',
#  'campa',
#  'campamento',
#  'campaña',
#  'campesina',
#  'campesinado',
#  'campesino',
#  'campestre',
#  'campion',
#  'campo',
#  'canacintra',
#  'canaco',
#  'canadiense',
#  'canadá',
#  'canal',
#  'canalizar',
#  'cancelar',
#  'cancino',
#  'cancún',
#  'candado',
#  'candidato',
#  'candidatura',
#  'cano',
#  'cansancio',
#  'cantar',
#  'cantidad',
#  'cantinflas',
#  'canto',
#  'capacidad',
#  'capacitación',
#  'capital',
#  'capitalino',
#  'capitalismo',
#  'capitalización',
#  'capitalizar',
#  'capricho',
#  'captación',
#  'captar',
#  'cara',
#  'caracterizado',
#  'caracterizar',
#  'característica',
#  'carantoña',
#  'cardenismo',
#  'cardenista',
#  'cardiaca',
#  'cardiología',
#  'cardona',
#  'carecer',
#  'carencia',
#  'carga',
#  'cargar',
#  'cargo',
#  'caribe',
#  'carlos',
#  'carne',
#  'caro',
#  'carpio',
#  'carranza',
#  'carrera',
#  'carretera',
#  'carretero',
#  'carruseles',
#  'carso',
#  'carta',
#  'cartera',
#  'cartulina',
#  'carácter',
#  'casa',
#  'casanova',
#  'casar',
#  'casi',
#  'casilla',
#  'caso',
#  'castellano',
#  'castigar',
#  'castigo',
#  'castillo',
#  'catalizador',
#  'catar',
#  'catastrófico',
#  'catorcena',
#  'catálogo',
#  'catástrofe',
#  'católica',
#  'católico',
#  'cauce',
#  'caudillesca',
#  'caudillo',
#  'causa',
#  'causante',
#  'causar',
#  'cautivo',
#  'caída',
#  'caído',
#  'cañaveral',
#  'cañedo',
#  'caótico',
#  'cce',
#  'cdiez',
#  'cdrom',
#  'ceder',
#  'ceesp',
#  'celebración',
#  'celebrar',
#  'cemex',
#  'cen',
#  'cena',
#  'ceniza',
#  'censura',
#  'censurar',
#  'centavo',
#  'centenar',
#  'central',
#  'centro',
#  'centroamericana',
#  'ceoic',
#  'cepal',
#  'cerca',
#  'cercano',
#  'cercanía',
#  'cerda',
#  'cerdo',
#  'ceremonia',
#  'ceremonial',
#  'cero',
#  'cerrado',
#  'cerrar',
#  'certidumbre',
#  'certificación',
#  'cesarman',
#  'cese',
#  'cete',
#  'cfe',
#  'chabacano',
#  'chacona',
#  'chapa',
#  'chapopote',
#  'chargoy',
#  'charros',
#  'charter',
#  'charters',
#  'cheque',
#  'chiapaneca',
#  'chiapaneco',
#  'chiapas',
#  'chico',
#  'chicomuselo',
#  'chile',
#  'chilton',
#  'china',
#  'chino',
#  'chirinos',
#  'chis',
#  'chiste',
#  'chivo',
#  'chocante',
#  'chofer',
#  'choque',
#  'chovinismo',
#  'churubuscoal',
#  'chávez',
#  'chéquelo',
#  'ciberespacio',
#  'ciberlectores',
#  'ciclo',
#  'cien',
#  'ciencia',
#  'cienfuegos',
#  'ciento',
#  'científica',
#  'científico',
#  'cierne',
#  'cierre',
#  'ciertamente',
#  'cierto',
#  'cifra',
#  'cifrián',
#  'cihmech',
#  'cima',
#  'cimentaciones',
#  'cimentar',
#  'cimiento',
#  'cinco',
#  'cine',
#  'cinematografistas',
#  'cinematográfico',
#  'cinescopios',
#  'cinturón',
#  'cioac',
#  'circuito',
#  'circulación',
#  'circulante',
#  'circular',
#  'circunstancia',
#  'cirugía',
#  'cita',
#  'citadino',
#  'citar',
#  'citroen',
#  'ciudad',
#  'ciudadano',
#  'civil',
#  'civilizado',
#  'clandestino',
#  'clara',
#  'claramente',
#  'claremont',
#  'clark',
#  'claro',
#  'claroscuro',
#  'clase',
#  'clasificación',
#  'clave',
#  'clavícula',
#  'clemencia',
#  'clero',
#  'cliente',
#  'clienteservidor',
#  'clifford',
#  'clima',
#  'clásico',
#  'cláusula',
#  'clérigo',
#  'cna',
#  'cnbv',
#  'cnc',
#  'cniv',
#  'cnpi',
#  'co',
#  'coalcomán',
#  'coalición',
#  'cobarde',
#  'cobertura',
#  'cobrar',
#  'cocoyoc',
#  'coexistir',
#  'coger',
#  'coicidieron',
#  'coincidente',
#  'coincidir',
#  'col',
#  'colaborar',
#  'colbeth',
#  'colchón',
#  'coleccionar',
#  'colección',
#  'colectivo',
#  'colega',
#  'colegiado',
#  'colegiatura',
#  'colgado',
#  'colgar',
#  'college',
#  ...]

# %%
len(vocabulary)
# Out:
# 5471

# %%
def similar_words(text, word, window=8, probability=True, tf_idf=False, dot_product=False, cosine=True):
    
    vocabulary = sorted(list(set(text)))
    contexts = {}
    for w in vocabulary:
        context = []
        for i in range(len(text)):
            if text[i] == w:
                for j in range(i - int(window/2), i): # Left context
                    if j >= 0:
                        context.append(text[j])
                    try:
                        for j in range(i + 1, i + int(window/2) + 1): # Right context
                            context.append(text[j])
                    except IndexError:
                        pass
        contexts[w] = context
        
    import numpy as np

    if probability:
        vectors = {}

        for v in vocabulary:
            context = contexts[v]
            vector = []
            for voc in vocabulary:
                vector.append(context.count(voc))
            vector = np.array(vector)
            s = np.sum(vector)
            vector = vector/s
            vectors[v] = vector

    if dot_product:
        similarities = {}
        v = vectors[word]
        for w in vectors.keys():
            similarities[w] = np.dot(vectors[w], v)
        similarities = (sorted(similarities.items(), key=lambda item: item[1], reverse=True))
        with open('similar_words_with_dot_product_of_prob_vectors_to_' + word + 'w', encoding = 'UTF-8') as f:
            for item in similarities:
                f.write(str(item) + '\n')

    if cosine:
        similarities = {}
        v1 = vectors[word]
        for w in vectors.keys():
            v2 = vectors[w]
            similarities[w] = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
        similarities = (sorted(similarities.items(), key=lambda item: item[1], reverse=True))
        with open('similar_words_with_cosine_of_prob_vectors_to_' + word + 'w', encoding = 'UTF-8') as f:
            for item in similarities:
                f.write(str(item) + '\n')

# %%
similar_words(words_lemmatized, 'perro', window=8, probability=True, tf_idf=False, dot_product=False, cosine=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 similar_words(words_lemmatized, 'perro', window=8, probability=True, tf_idf=False, dot_product=False, cosine=True)
#
# Input In [15], in similar_words(text, word, window, probability, tf_idf, dot_product, cosine)
#      44 if cosine:
#      45     similarities = {}
# ---> 46     v1 = vectors[word]
#      47     for w in vectors.keys():
#      48         v2 = vectors[w]
#
# KeyError: 'perro'

# %%
v = {'perro':2}

# %%
import nltk
sent_tokenizer = nltk.data.load('nltk:tokenizers/punkt/english.pickle')sentences = sent_tokenizer.tokenize(t.lowercase())
sentences = sent_tokenizer.tokenize(t.lowercase())

# Tenemos que normalizar cada oración y aun así obtener resultados de las palabras con mejor relación.
