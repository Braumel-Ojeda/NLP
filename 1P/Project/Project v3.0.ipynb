# %% [markdown]
# # Preprocessing, Word Association with POS Tagging and BM25 improvement

# %% [markdown]
# On this notebook is developed the preprocessing and word association with tagging to our corpus made by newspaper texts.

# %% [markdown]
# ## Preprocessing: Normalization with POS tagging
#
# First, we are going to define our functions to prepare our data by tagging each word with its respective Part of Speech. This tagging is done to get better results when we were looking for word associations, because a priori those tags will help us to filter the words that belong to the same POS and then apply the similarity measures detailed later.

# %%
import nltk
from bs4 import BeautifulSoup
import re

# %%
def extract_text_from_corpus(path):
    # Getting corpus from the directory
    corpus = nltk.corpus.PlaintextCorpusReader(path, '.*')
    file_list = corpus.fileids()
    
    # Reuniting all text content from files on the directory
    all_text = ''
    for file in file_list:
        with open(path + file, encoding = 'utf-8') as rfile:
            text = rfile.read()
            all_text += text
    
    # Cleaning HTML tags
    soup = BeautifulSoup(all_text, 'lxml')
    clean_text = soup.get_text()
    clean_text = clean_text.lower()
    
    return clean_text

# %%
def tokenize_by_words(text):
    words = text.split()
    alphabetic_words = list()
    
    for word in words:
        token = []
        for character in word:
            if re.match(r'^[a-záéíóúñü+$]', character):
                token.append(character)
        token = ''.join(token)
        if token != '':
            alphabetic_words.append(token)
    
    return alphabetic_words

def tokenize_by_sents(text):
    tokens = nltk.data.load("tokenizers/punkt/spanish.pickle") 
    sents = tokens.tokenize(text)
    alphabetic_sents = list()
    
    for sent in sents:
        sent_token = tokenize_by_words(sent)
        alphabetic_sents.append(sent_token)
    
    return alphabetic_sents

# %%
def remove_stop_words_from_sents(sents, path = './stopwords_es.txt'):
    with open(path, encoding = 'utf-8') as f:
        stop_words = f.readlines()
        stop_words = [w.strip() for w in stop_words]
        
    clean_sents = list()
    for sent in sents:
        clean_sent = [word for word in sent if word not in stop_words]
        clean_sents.append(clean_sent)
    
    return clean_sents

# %%
from nltk.corpus import cess_esp
from pickle import dump

def make_and_save_spanish_tagger(fname):
        
    tags_sents = list()
    for sent in cess_esp.tagged_sents():
        tags_sents_aux = [tag for (word, tag) in sent]
        tags_sents = tags_sents + tags_sents_aux
    
    most_used_tag_sents = nltk.FreqDist(tags_sents).max()
    
    default_tagger = nltk.DefaultTagger(most_used_tag_sents)
    
    patterns = [
        (r'.o$', 'n'),
        (r'.os$', 'n'),
        (r'.a$', 'n'),
        (r'.as$', 'n'),
        (r'.e$', 'n'),
        (r'.es$', 'n'),
        (r'.^[0-9]+$', 'z')
    ]
    
    regexp_tagger = nltk.RegexpTagger(patterns, backoff = default_tagger)
    
    cess_tagged_sents = cess_esp.tagged_sents()
    spanish_tagger = nltk.UnigramTagger(cess_tagged_sents, backoff = regexp_tagger)
    
    output = open(fname, 'wb')
    dump(spanish_tagger, output, -1)
    output.close()

# %%
make_and_save_spanish_tagger('./spanish_tagger.pkl')

# %%
from pickle import load

def tag(text, path = './spanish_tagger.pkl'):
    input_f = open(path, 'rb')
    tagger = load(input_f)
    input_f.close()
    tagged_sentences = [tagger.tag(sent) for sent in text]
    
    return tagged_sentences

# %%
def lemmatize_from_sents(text, path = './generate.txt'):
    
    lemmas = dict()
    with open(path, encoding = 'latin1') as file:
        lines = file.readlines()
        for line in lines:
            line = line.strip()
            if line != '':
                words = line.split()
                token = words[0].strip()
                token = token.replace('#', '')
                lemma = words[-1].strip()
                tag = words[-2].strip()
                tag = tag[0].lower()
                lemmas[(token, tag)] = (lemma, tag)
    
    lemmatized_text = list()
    for sent in text:
        lemmatized_sent = list()
        for word in sent:
            if word in lemmas.keys():
                lemmatized_sent.append(lemmas[word])
            else:
                lemmatized_sent.append(word)
        
        lemmatized_text.append(lemmatized_sent)

    return lemmatized_text

# %%
def normalize_by_sents(path):
    clean_text = extract_text_from_corpus(path)
    alphabetic_sents = tokenize_by_sents(clean_text)     
    clean_sents = remove_stop_words_from_sents(alphabetic_sents)
    tagged_sents = tag(text = clean_sents)
    
    new_tagged_sents = list()
    for sent in tagged_sents:
        new_sent = list()
        for element in sent:
            word = element[0]
            tag_elem = element[1]
            new_sent.append((word, tag_elem[0].lower()))
        new_tagged_sents.append(new_sent)
    preprocessed_text_sents = lemmatize_from_sents(text = new_tagged_sents)
    
    return preprocessed_text_sents

# %%
def preprocessing(path = './../EXCELSIOR_100_files/'):
    try:
        preprocessed_text_sents = normalize_by_sents(path)
        print('\033[1mNormalization by sentence tokens completed\033[0m')
        
        return preprocessed_text_sents

    except Exception as e:
        print('An error has occured: ', e)

# %% [markdown]
# #### Preprocessing with sentence tokens

# %%
preprocessed_text_sents = preprocessing()
# Out:
# Normalization by sentence tokens completed

# %%
words = list()
for sent in preprocessed_text_sents:
    for word in sent:
        words.append(word)

# %%
vocabulary = list(sorted(set(words)))
len(vocabulary)
# Out:
# 6402

# %% [markdown]
# ## Word associations and BM25 improvement
#
# Once we have completed our preprocessing, it's time to define the functions to find the similarity between words, hence get the word associations in our corpus. In order to do that, we must have functions to extract the contexts from the preprocessed text with sentence tokens. Then, we also need a function to calculate the probability's vector for each word. And finally, functions to quantify the similarity between words based on the dot product or the cosine measure between vectors.

# %%
def get_contexts_sents(vocabulary, text, window = 8):
    contexts = dict()
    for w in vocabulary:
        context = list()
        for sent in text:
            for i in range(len(sent)):
                if sent[i] == w:
                    for j in range(i - int(window / 2), i):
                        if j >= 0:
                            context.append(sent[j])
                    try:
                        for j in range(i + 1, i + (int(window / 2) + 1)):
                            context.append(sent[j])
                    except IndexError:
                        pass
        contexts[w] = context
    return contexts

# %%
import numpy as np

# %%
def get_vectors(vocabulary, contexts):
    vectors = dict()
    for v in vocabulary:
        context = contexts[v]
        vector = []
        for voc in vocabulary:
            vector.append(context.count(voc))
        vector = np.array(vector)
        vectors[v] = vector
    dls = list()
    for v in vectors.values():
        dls.append(np.sum(v))
    avdl = np.sum(dls) / len(dls)
    for k, v in vectors.items():
        new_vector = bm25(v, avdl)
        s = np.sum(new_vector)
        if s != 0:
            new_vector = new_vector / s
        vectors[k] = new_vector
    return vectors

def get_idf(vectors):
    num_context = len(vectors)
    total_aparitions = [0 for i in range(num_context)]
    for v in vectors.values():
        i = 0
        for element in v:
            if element != 0:
                total_aparitions[i] = total_aparitions[i] + 1
            i = i + 1
    idf = list()
    for element in total_aparitions:
        if element != 0:
            idf.append(np.log((num_context + 1) / element))
        else:
            idf.append(element)
    return idf

# %%
def bm25(vector, avdl, k = 0.25, b = 0.25):
    new_vector = np.divide((k+1) * vector, vector + k * (1 - b + (b * np.sum(vector) / avdl)))
    return new_vector

def s_bm25(word, idf, vectors, aux_path = ''):
    similarities = dict()
    v = np.multiply(idf, vectors[word])
    for w in vectors.keys():
        # v2 = np.multiply(idf, vectors[w])
        v2 = vectors[w]
        similarities[w] = np.dot(v, v2)
    similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
    
    with open('./bm25_idf/similar_words_to_' + word[0] + '_' + word[1] + '_with_bm25_idf' + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
        for item in similarities:
            f.write(str(item) + '\n')

def s_dot_product(word, idf, vectors, aux_path = ''):
    similarities = dict()
    v = np.multiply(vectors[word], idf)
    for w in vectors.keys():
        v2 = np.multiply(vectors[w], idf)
        similarities[w] = np.dot(v2, v)
    similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
    
    with open('./dot_product_idf/similar_words_to_' + word[0] + '_' + word[1] + '_with_dot_product_idf' + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
        for item in similarities:
            f.write(str(item) + '\n')


def s_cosine(word, idf, vectors, aux_path = ''):
    similarities = dict()
    v = np.multiply(vectors[word], idf)
    for w in vectors.keys():
        v2 = np.multiply(vectors[w], idf)
        if np.linalg.norm(v) == 0 or np.linalg.norm(v2) == 0:
            similarities[w] = 0
        else:
            similarities[w] = np.dot(v, v2) / (np.linalg.norm(v) * np.linalg.norm(v2))
    similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
    
    with open('./cosine_idf/similar_words_to_' + word[0] + '_' + word[1] + '_with_cosine_idf' + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
        for item in similarities:
            f.write(str(item) + '\n')

# %%
def similar_words_improved(word, vectors, vocabulary, aux_path = '', bm25 = False, dot_product = False, cosine = False):   
    idf = get_idf(vectors)
    
    words = list()
    for v in vocabulary:
        if v[0] == word:
            words.append(v)
    for word in words:
        tag = word[1]
        new_vectors = dict()
        for k, v in vectors.items():
            if k[1] == tag:
                new_vectors[k] = v
                
        if bm25:
            s_bm25(word, idf, new_vectors, aux_path)
        
        if dot_product:
            s_dot_product(word, idf, new_vectors, aux_path)

        if cosine:
            s_cosine(word, idf, new_vectors, aux_path)

# %%
contexts_s = get_contexts_sents(vocabulary, preprocessed_text_sents)
vectors_s = get_vectors(vocabulary, contexts_s)
idf = get_idf(vectors_s)
print(np.sum(idf))
# Out:
# 40375.39504534626

# %%
w = "empresa"
print(w)
try:
    similar_words_improved(w, vectors_s, vocabulary, aux_path = '', bm25 = True, dot_product = True, cosine = True)
    print('Similarity estimations of \033[1m(' + w + ')\033[0m completed\n')
except Exception as e:
    print('An error has occured: ' + str(e) + ' in word ' + w[0] + ', ' + w[1])
# Out:
# empresa
# Similarity estimations of (empresa) completed

# %%
vectors_s
# Out:
# {('abandonando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abandonar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abandonaran', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abandonaron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abandono', 'n'): array([0.  , 0.  , 0.  , ..., 0.25, 0.  , 0.  ]),
#  ('abarcan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abarcar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abarrotado',
#   's'): array([0.        , 0.14285714, 0.        , ..., 0.        , 0.        ,
#         0.        ]),
#  ('abascal', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abasto', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abatir', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abatió', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abbasso', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abdicar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aberrantes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abierto', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abitia', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abono', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abordaje', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aborigen', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aborígenes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abraham', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abrego', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abril', 'w'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abrir', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('absalón', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('absoluto', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('absuelto', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('absurdamente', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('absurdo', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abuelos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abundantes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abundó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aburto',
#   's'): array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.04119722]),
#  ('abusan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('abuso', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ac', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acabar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acaparar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acapulco', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acarreo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acaso', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('accesible', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('accesibles',
#   's'): array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.07091196]),
#  ('acceso', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('accidente',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.01924185, 0.        ,
#         0.        ]),
#  ('accionista', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acción',
#   'n'): array([0.00543996, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]),
#  ('acelera', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acelerado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acelerar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acento', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acentos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acentuado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aceptabilidad', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aceptar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acercaba', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acercar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acero', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acertada', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acertadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acertar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acierto', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aclaraciones', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aclaración', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aclarar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aclarar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acompaña', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acompañado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acompañamiento', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acompañar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aconsejable', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aconsejan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acontecimiento',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.07142857, 0.        ,
#         0.        ]),
#  ('acopio', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acoplado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acoplamientos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acorde', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acotar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acrecentar',
#   's'): array([0.        , 0.        , 0.        , ..., 0.        , 0.16666667,
#         0.        ]),
#  ('acreditadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acreditado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acreditar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acredite', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acreedor', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actitud', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actividad',
#   'n'): array([0.        , 0.        , 0.01038898, ..., 0.        , 0.        ,
#         0.        ]),
#  ('activo', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('activo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acto', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actor', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actriz', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actuación',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.07142857, 0.        ,
#         0.        ]),
#  ('actual', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actualidad', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actualizada', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actualizados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actualmente', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actualícese', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actuar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('actuó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acudan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acudir', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acuerdo',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.00792325, 0.        ,
#         0.        ]),
#  ('acumulación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acumulada', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acumular', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acusación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acusado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('acusar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adaptarse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adecuadamente', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adecuado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adelante', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('además',
#   'r'): array([0.        , 0.        , 0.        , ..., 0.00509199, 0.        ,
#         0.        ]),
#  ('ades', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adeudos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adicional', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adición', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adjudicados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adjudicar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adjudicarlas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adjuntas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adjunto', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('administración', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('administrador', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('administradora', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('administradoras', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('administradores', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('administrativo', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('admirarla', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('admitir', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adolf', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adolfo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adoptar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adornado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adquiridos', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adquirieron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adquirir', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adquirirá', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adquisición', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adquisitivo',
#   'a'): array([0.        , 0.        , 0.        , ..., 0.07091196, 0.        ,
#         0.        ]),
#  ('adreessen', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adrián', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adujo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adulto', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('advenedizo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('advenimiento', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('adverso', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('advertencia', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('advertir',
#   'v'): array([0.        , 0.        , 0.        , ..., 0.        , 0.00941947,
#         0.        ]),
#  ('advertiría', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('advirtiótambién', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aedpch', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aerolíneas', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aeronave', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aeroportuarias', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aeropuerto', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afectados', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afectar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aferran', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aferrarse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afiliados', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afirmación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afirmar',
#   'v'): array([0.        , 0.        , 0.        , ..., 0.        , 0.01339443,
#         0.        ]),
#  ('afore', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afores',
#   's'): array([0.        , 0.        , 0.        , ..., 0.        , 0.01488802,
#         0.        ]),
#  ('aforismo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aforo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afortunados', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afrancisco', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('africa', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afrontarán', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afuera', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('afán', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agencia', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agencias',
#   's'): array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.04166667]),
#  ('agenda', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agente', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agilidad', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agilizar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agobiados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agobiar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agonía', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agosto', 'w'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agotar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agotarse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agradecer', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agradezgo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agrarias', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agrario', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agrarios',
#   's'): array([0.        , 0.        , 0.        , ..., 0.03702956, 0.        ,
#         0.        ]),
#  ('agrarismo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agraristas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agraviado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agreden', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agregado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agregar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agregar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agregaron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agregará', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agremiados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agricultor', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agro', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agropecuaria', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agropecuario', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agropecuario',
#   's'): array([0.        , 0.        , 0.        , ..., 0.16666667, 0.        ,
#         0.        ]),
#  ('agrupación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agrupadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agrupar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agrícola', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agua', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aguascalientes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agudice', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agudiza', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agudización', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agudizando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agudizarse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agudo', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aguilar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aguinaco', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aguirre', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('agustin', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahogada', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahogan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahondar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahora', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahorita', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahorrador', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahorradores', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahorro',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.        , 0.01464906,
#         0.        ]),
#  ('ahuyentó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ahí', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aicm', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aicn', 's'): array([0.   , 0.   , 0.   , ..., 0.125, 0.   , 0.   ]),
#  ('aire', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aislados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ajustarse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ajuste',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.02311297, 0.        ,
#         0.        ]),
#  ('ajustes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ala', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alabat', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alarcón', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alargamiento', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alarmante', 'a'): array([0.   , 0.   , 0.   , ..., 0.125, 0.   , 0.   ]),
#  ('alberto', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('albino', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('albores', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcalde', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcance', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcancen', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcances', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcanzada', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcanzar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcanzará', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcayaga', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcista', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alcohólicas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aldf', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alegar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alegre', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alegres', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alejados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alejandro', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alejémonos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alemania', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alemanista', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alemán', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alemán', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alentador', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alerta', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alertado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alertas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alfa', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alfaro', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alfonso', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alfredo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alférez', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alguien', 'p'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alguna', 'd'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alguno', 'p'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('algún', 'd'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aliado', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alianza', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alianzas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alice', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alimentación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alimentario', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alimenticios', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alimento', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('allegada', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('allende', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alliance', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('allora', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('allá', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('allí', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('almacenada', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('almoloya', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alonso', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alpha', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alponte', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alpro', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alrededor',
#   'r'): array([0.        , 0.        , 0.        , ..., 0.        , 0.02171958,
#         0.        ]),
#  ('altamirano', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('altar', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('altarcito', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alteración', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alterando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alterar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alteraron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alterno', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('altibajos', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alto', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('altoparlantes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('altura', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('altísimo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alumno', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alvarado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alvarez', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alvaro', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alza', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('alzamientos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amador', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amargo', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amarras', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amañadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ambas', 'd'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ambicioso', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ambiente', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ambos', 'd'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amelia', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amenaza', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('america', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('americom', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amhym', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amib', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amiga', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amigo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amor', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amortizaciones', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amortización', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amparo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ampliamente', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ampliar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amplio', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('amplíen', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('américa', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('analice', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('analista', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('analizar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('analítico', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anarquía', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ancianos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('andar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('andreessen', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('andres', 's'): array([0.   , 0.   , 0.   , ..., 0.125, 0.   , 0.   ]),
#  ('andrés', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('andrómeda', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ane', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anexo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('angel', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('angeles', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('angloamericanos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('angustia', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('angustioso', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anhelar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anillo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aniversario', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anomalías', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anotar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ansiosos',
#   's'): array([0.        , 0.14285714, 0.        , ..., 0.        , 0.        ,
#         0.        ]),
#  ('antagónicas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antaño', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antecesor', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antecesores', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antelmo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anteproyecto', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anterior', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anteriormente', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anticipa', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anticipación', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anticonstitucionales', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antiguo', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antigüita', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antimigratoria', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antipatías', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antonio', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antorcha', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('antuna', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anual', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anuencia', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anulado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anunciar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anunciará', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anuncio', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anunciándose', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('anáhuac', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('análisis',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.        , 0.01081463,
#         0.        ]),
#  ('apacible', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apaciguar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apapacho', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aparato', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aparecer', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aparentemente', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aparición', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aparta', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apartadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apartado', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aparte', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apegadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apego', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apelación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apenas', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apertura', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aplicable', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aplicación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aplicado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aplicando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aplicar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aplicará', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aplicó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoderado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoderados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoderamientos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoderarse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aporreado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aportados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aportar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aportó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apostaban', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apostados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apostar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoteótica', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoyaban', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoyada', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoyadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoyados', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoyar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoyarse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apoyo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apple', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('applets', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apreciación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apreciar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprehensión', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprender', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apresado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apresta', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apresurar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprobación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprobar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apropiado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprovechadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprovechamiento', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprovechar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprovecharse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprovechemos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aproximadamente', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aproximados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aprueban', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aptitudes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apuntadas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('apuntar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aquejan', 's'): array([0.   , 0.   , 0.   , ..., 0.125, 0.   , 0.   ]),
#  ('aquel', 'd'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aquella', 'd'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aquello', 'p'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aquellos', 'd'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aquél', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aquí', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aragón', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arancel', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arancel', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aras', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arbitral', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arbitraria', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arca', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('archivar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('archivos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arco', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arcos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arden', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arder', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ardid', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arena', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('argentino', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('argumentar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('argumento', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('argumento', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arias', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arizmendi', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arma', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('armado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('armando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('armonía', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('armónicamente', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('armónico', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arnault', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arqueológico', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arquitecto', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arquitectura', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrancando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrancar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrancaron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrastrar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrastraron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arreglo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arreglos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrendadora', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arreola', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrestos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arriba', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arribar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arribo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrobaexcelsiorcommx', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrojar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arrojar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arroparse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arroyos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arte', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('artificial', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('artimañas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('artista', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arturo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('artículo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arvizu', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arzobispo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('arzú', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asa', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asalariada', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asalariado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asaltante', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asamblea', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asambleísta', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asambleístas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ascender', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ascenderá', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ascensión', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ascenso', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aseguraban', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asegurados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asegurar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asegure', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asentar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asentó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asequible', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asesinar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asesinato',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.01842305, 0.        ,
#         0.        ]),
#  ('asesino', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asesino', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asesor', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asesoría', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aseverar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aseverar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aseveraron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asfixia', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asfixian', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asienta', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asientan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asigna', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asignaciones', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asignación', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asimila', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asimismo', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asistencia', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asistencial', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asistente', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asistir', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asociación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asociar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asociaran', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aspecto', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aspiración', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aspirar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('astronauta', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('astronautas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('astroso', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('astucia', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asueto', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asumir', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asumirse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('asunto', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('así', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ataba', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atacar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atacaría', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atajar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atención', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atender', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atenderlo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atenderá', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atendieron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atentamente', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atentar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aterrizaje', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aterrizar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atienden', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atinadamente', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atinado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atisbaron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atlantis', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atoyac', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atracarlos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atractivo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atraer', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atraso', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atravesar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atravesarlo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('através', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atrayendo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('atribución', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('audio', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auditar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auditoria', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auditorias', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auditorio', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auditoría', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auditorías', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('augusta', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aumentan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aumentar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aumento', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aun', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aunque', 'c'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auque', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aurora', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ausentismo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auspiciado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('australia', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('austria', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auto', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autobús', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autoconsumo', 's'): array([0.   , 0.125, 0.   , ..., 0.   , 0.   , 0.   ]),
#  ('autoinvasiones', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('automáticamente', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('automático', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('automático', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('automáticos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('automóvil', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autonomía', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autopista', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autor', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autoridad',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.00558505, 0.        ,
#         0.        ]),
#  ('autoritarismo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autorizado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autorizó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autotransporte', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autotransportes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autrey', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auténtico', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('autónomo', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auxilia', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auxiliares', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('auxilio', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('av', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avalúos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avance', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avanzar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avecinan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avelar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avenida', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('averiguaciones', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('averiguar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aversión', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avila', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avisar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avisos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('avión', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ayala', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ayer', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ayuda', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ayudar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ayudarlo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ayudarme', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ayudaron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ayuno', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('azcapotzalco', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('azteca', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('azul', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('azúcar', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('aéreo', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('añadir', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('año',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.00432227, 0.        ,
#         0.        ]),
#  ('aún', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bache', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bah', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('baile', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('baja', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bajar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bajo',
#   'a'): array([0.        , 0.        , 0.        , ..., 0.00930842, 0.        ,
#         0.        ]),
#  ('bajo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('balance', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('balanza', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('balanzas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('baldenegro', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('balnearios', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('balón', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banamex', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banc', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banca', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bancario', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bancarrotas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banco', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bancomer', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bandera', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bandido', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bando', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banjidal', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banobras', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banquero', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banquetas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banrural', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('banxico', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('baranda', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('barato', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('barba', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('barca', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('barco', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('barra', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('barragán', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('barreda', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('barrio',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.07692308, 0.        ,
#         0.        ]),
#  ('bartola', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('basada', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('basado', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('basarse', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('base', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bastan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bastante', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bastar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('basura', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('baño', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bdem', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beach', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bebidas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beca', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('becerril', 's'): array([0.   , 0.   , 0.   , ..., 0.125, 0.   , 0.   ]),
#  ('bell', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beltrones', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('belén', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bendecir', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bendición', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beneficiaban', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beneficiada', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beneficiados', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beneficiando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beneficiar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beneficiario', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('beneficio',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.07142857, 0.        ,
#         0.        ]),
#  ('beneficios', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('benito', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('benévolo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('berdejo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bernal', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bezanilla', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bianual', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bicicleta', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bien', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bien', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bienestar', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bienintencionado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bienvenidos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bill', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('billete', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bimestre', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('biofísicos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('biológico', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bla', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('blaha', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('blanco', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('blando', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('blanquiazul', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('blemas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bloquea', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bmv', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bobo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('boca', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bodrios', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('boeing', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bolita', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bolsa', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bolseros', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bombardea', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bonhomía', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bonos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('boom', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('borde', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bordo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('borghese', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('borja', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('borrego', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bosque', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('botín', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bours', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brasil', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('braun', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brecha', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bretaña', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brete', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('breve', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('breves', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brindar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brindar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brindándome', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brito', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('británico', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brote', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brusca', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brutal', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('brutales', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bruto', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bueno', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bulevar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('burladas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('burlan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('burlar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bursátil',
#   'a'): array([0.       , 0.       , 0.       , ..., 0.0103635, 0.       ,
#         0.       ]),
#  ('buscaban', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('buscar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('buscaremos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('butírica', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('buzonsímbolo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('básicamente', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('básico', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('bésame', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('búfalos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('búho', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('búsqueda',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.03213393, 0.        ,
#         0.        ]),
#  ('búsquedas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabal', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabales', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caballero', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caballeroso', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabalmente', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caber', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabeza', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabezal', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabida', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabildo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabina', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cabo',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.01372622, 0.        ,
#         0.        ]),
#  ('cabrera', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cada', 'd'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cadena', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caer', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('café', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caifás', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cairo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caj', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cajb', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cajero', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cajeros', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calabozo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calado', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calcular',
#   'v'): array([0.        , 0.        , 0.        , ..., 0.04744556, 0.        ,
#         0.        ]),
#  ('caldaria', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caldera', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calderón', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calidad', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calificaciones', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calificando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calificar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('california', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('californianas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calle', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('callejón', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calley', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('callista', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calor', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('calumnias', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cama', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('camacho', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cambiar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cambiaria', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cambiario', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cambio', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('camina', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caminar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('camino', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('camioneras', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('camioneta', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('campa', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('campamentos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('campaña', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('campesina',
#   's'): array([0.        , 0.02414224, 0.02414224, ..., 0.        , 0.        ,
#         0.        ]),
#  ('campesinado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('campesino', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('campestre', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('campion', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('campo',
#   'n'): array([0.        , 0.02071439, 0.        , ..., 0.        , 0.02071439,
#         0.        ]),
#  ('canacintra', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('canaco', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('canadiense', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('canadá', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('canal', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('canalicen', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('canalizarlos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cancelar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cancelaron', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cancino', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cancún', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('candados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('candidato', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('candidatura', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cano', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cansancio', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cantar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cantidad', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cantinflas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('canto', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capacidad', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capacitación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capital', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capitalina', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capitalinas',
#   's'): array([0.        , 0.        , 0.        , ..., 0.06621176, 0.        ,
#         0.        ]),
#  ('capitalino',
#   's'): array([0.       , 0.       , 0.       , ..., 0.0226057, 0.       ,
#         0.       ]),
#  ('capitalinos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capitalismo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capitaliza', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capitalización', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capitalizando', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capitalizar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('capitalizarlos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caprichos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('captación', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('captado', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('captados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('captó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cara', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caracterizan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caracterizar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('característica', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carantoñas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cardenismo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cardenista', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cardiaca', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cardiología', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cardona', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carecer', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carencias', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carga', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cargar', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cargo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caribe', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carlos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carne', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carnes', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caro', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carpio', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carranza', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carrera', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carretera',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.01602224, 0.        ,
#         0.        ]),
#  ('carretero', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carreteros', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carruseles', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carso', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carta', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cartera', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carteras', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cartulina', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('carácter', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('casa',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.01617245, 0.        ,
#         0.        ]),
#  ('casanova', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('casi', 'r'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('casillas', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caso', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('castellanos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('castigados', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('castigo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('castigue', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('castillo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('casó', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('catalizador', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('catastróficos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cato', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('catorcena', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('catálogo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('catástrofe', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('católica', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('católico', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cauces', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caudillesca', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caudillo', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('causa',
#   'n'): array([0.        , 0.        , 0.        , ..., 0.01754386, 0.        ,
#         0.        ]),
#  ('causan', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('causante', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('causar', 'v'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cautivo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caéis', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caída', 'n'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caídos', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cañaveral', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cañedo', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('caótica', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cce',
#   's'): array([0.        , 0.        , 0.        , ..., 0.03541653, 0.        ,
#         0.        ]),
#  ('cdiez', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cdrom', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cederá', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('cedido', 'a'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ('ceesp', 's'): array([0., 0., 0., ..., 0., 0., 0.]),
#  ...}
