# %% [markdown]
# # Preprocessing and Word Association

# %% [markdown]
# On this notebook is developed the preprocessing and word association with our corpus made by newspaper texts.

# %% [markdown]
# ## Preprocessing: Normalization
#
# First, we are going to define our functions to prepare our data before looking for word associations.

# %%
import nltk
from bs4 import BeautifulSoup
import re

# %%
def extract_text_from_corpus(path):
    # Getting corpus from the directory
    corpus = nltk.corpus.PlaintextCorpusReader(path, '.*')
    file_list = corpus.fileids()
    
    # Reuniting all text content from files on the directory
    all_text = ''
    for file in file_list:
        with open(path + file, encoding = 'utf-8') as rfile:
            text = rfile.read()
            all_text += text
    
    # Cleaning HTML tags
    soup = BeautifulSoup(all_text, 'lxml')
    clean_text = soup.get_text()
    clean_text = clean_text.lower()
    
    return clean_text

# %%
def tokenize_by_words(text):
    words = text.split()
    alphabetic_words = list()
    
    for word in words:
        token = []
        for character in word:
            if re.match(r'^[a-záéíóúñü+$]', character):
                token.append(character)
        token = ''.join(token)
        if token != '':
            alphabetic_words.append(token)
    
    return alphabetic_words

def tokenize_by_sents(text):
    tokens = nltk.data.load("tokenizers/punkt/spanish.pickle") 
    sents = tokens.tokenize(text)
    alphabetic_sents = list()
    
    for sent in sents:
        sent_token = tokenize_by_words(sent)
        sent_token = " ".join(sent_token)
        if sent_token != '':
            alphabetic_sents.append(sent_token)
    
    return alphabetic_sents

# %%
def remove_stop_words_from_words(words, path = './stopwords_es.txt'):
    with open(path, encoding = 'utf-8') as f:
        stop_words = f.readlines()
        stop_words = [w.strip() for w in stop_words]
    
    clean_words = [word for word in words if word not in stop_words]
    
    return clean_words
    
def remove_stop_words_from_sents(sents, path = './stopwords_es.txt'):
    with open(path, encoding = 'utf-8') as f:
        stop_words = f.readlines()
        stop_words = [w.strip() for w in stop_words]
        
    clean_sents = list()
    for sent in sents:
        words = sent.split()
        clean_sent = [word for word in words if word not in stop_words]
        clean_sent = ' '.join(clean_sent)
        if clean_sent != '':
            clean_sents.append(clean_sent)
    
    return clean_sents

# %%
def lemmatize_from_words(text, path = './generate.txt'):
    from pickle import dump
    lemmas = dict()
    with open(path, encoding = 'latin1') as file:
        lines = file.readlines()
        for line in lines:
            line = line.strip()
            if line != '':
                words = line.split()
                token = words[0].strip()
                token = token.replace('#', '')
                lemma = words[-1].strip()
                lemmas[token] = lemma
    
    lemmatized_text = list()
    for word in text:
        if word in lemmas.keys():
            lemmatized_text.append(lemmas[word])
        else:
            lemmatized_text.append(word)

    return lemmatized_text
    

def lemmatize_from_sents(text, path = './generate.txt'):
    from pickle import dump
    lemmas = dict()
    with open(path, encoding = 'latin1') as file:
        lines = file.readlines()
        for line in lines:
            line = line.strip()
            if line != '':
                words = line.split()
                token = words[0].strip()
                token = token.replace('#', '')
                lemma = words[-1].strip()
                lemmas[token] = lemma
    
    lemmatized_text = list()
    for sent in text:
        words = sent.split()
        lemmatized_sent = list()
        for word in words:
            if word in lemmas.keys():
                lemmatized_sent.append(lemmas[word])
            else:
                lemmatized_sent.append(word)
        
        lemmatized_sent = ' '.join(lemmatized_sent)
        if lemmatized_sent != '':
            lemmatized_text.append(lemmatized_sent)

    return lemmatized_text

# %%
def normalize_by_words(path):
    clean_text = extract_text_from_corpus(path)
    alphabetic_words = tokenize_by_words(clean_text)     
    clean_words = remove_stop_words_from_words(alphabetic_words)
    preprocessed_text_words  = lemmatize_from_words(text = clean_words)
    #print('\n\033[1mLemmatization from words completed\033[0m')
    #print(f'Some words after lemmatization: \n{preprocessed_text_words[:200]}')
    
    return preprocessed_text_words

def normalize_by_sents(path):
    clean_text = extract_text_from_corpus(path)
    alphabetic_sents = tokenize_by_sents(clean_text)     
    clean_sents = remove_stop_words_from_sents(alphabetic_sents)
    preprocessed_text_sents = lemmatize_from_sents(text = clean_sents)
    #print('\n\033[1mLemmatization from sentence completed\033[0m')
    #print(f'Some words after lemmatization: \n{preprocessed_text_sents[:200]}')
    
    return preprocessed_text_sents

# %%
def preprocessing(path = './../EXCELSIOR_100_files/', by_words = True, by_sents = False):
    if by_words:
        try:
            preprocessed_text_words  = normalize_by_words(path)
            print('\033[1mNormalization by word tokens completed\033[0m')
            #print(f'Some words after normalization: \n{clean_words[:200]}')
            
            return preprocessed_text_words
        
        except Exception as e:
            print('An error has occured: ', e)
    elif by_sents:
        try:
            preprocessed_text_sents = normalize_by_sents(path)
            print('\033[1mNormalization by sentence tokens completed\033[0m')
            #print(f'Some words after normalization: \n{clean_sents[:200]}')

            return preprocessed_text_sents
            
        except Exception as e:
            print('An error has occured: ', e)

# %% [markdown]
# #### Preprocessing with word tokens

# %%
preprocessed_text_words = preprocessing(by_words = True, by_sents = False)
# Out:
# Normalization by word tokens completed

# %% [markdown]
# #### Preprocessing with sentence tokens

# %%
preprocessed_text_sents = preprocessing(by_words = False, by_sents = True)
# Out:
# Normalization by sentence tokens completed

# %% [markdown]
# Besides, we are going to make a vocabulary from the preprocessed text made with word tokens.

# %%
def make_vocabulary(words):
    vocabulary = sorted(list(set(words)))
    return vocabulary

# %%
vocabulary = make_vocabulary(preprocessed_text_words)

# %%
len(vocabulary)
# Out:
# 5471

# %% [markdown]
# ## Word associations
#
# Once we have completed our preprocessing, it's time to define the functions to find the similarity between words, hence get the word associations in our corpus. In order to do that, we must have functions to extract the contexts from both text preprocessed gotten with words and sentences. Then, we also need a function to calculate the probability's vector for each word. And finally, functions to quantify the similarity between words based on the dot product or the cosine measure between vectors.

# %%
def get_contexts_words(vocabulary, text, window = 8):
    contexts = dict()
    for w in vocabulary:
        context = list()
        for i in range(len(text)):
            if text[i] == w:
                for j in range(i - int(window / 2), i):
                    if j >= 0:
                        context.append(text[j])
                try: 
                    for j in range(i + 1, i + (int(window / 2) + 1)):
                        context.append(text[j])
                except IndexError:
                        pass
        contexts[w] = context
    return contexts


def get_contexts_sents(vocabulary, text, window = 8):
    contexts = dict()
    for w in vocabulary:
        context = list()
        for sent in text:
            words = sent.split()
            for i in range(len(words)):
                if words[i] == w:
                    for j in range(i - int(window / 2), i):
                        if j >= 0:
                            context.append(words[j])
                    try:
                        for j in range(i + 1, i + (int(window / 2) + 1)):
                            context.append(words[j])
                    except IndexError:
                        pass
        contexts[w] = context
    
    return contexts

# %%
import numpy as np

def get_probabilities(vocabulary, contexts):
    vectors = dict()
    for v in vocabulary:
        context = contexts[v]
        vector = []
        for voc in vocabulary:
            vector.append(context.count(voc))
        vector = np.array(vector)
        s = np.sum(vector)
        if s != 0:
            vector = vector / s
        vectors[v] = vector
    return vectors


def s_dot_product(word, vectors, aux_path = ''):

    similarities = dict()
    v = vectors[word]
    for w in vectors.keys():
        similarities[w] = np.dot(vectors[w], v)
    similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
    
    with open('./dot_product/similar_words_with_dot_product_of_prob_vectors_to_' + word + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
        for item in similarities:
            f.write(str(item) + '\n')


def s_cosine(word, vectors, aux_path = ''):
    similarities = dict()
    v = vectors[word]
    for w in vectors.keys():
        v2 = vectors[w]
        norm1 = np.linalg.norm(v)
        norm2 = np.linalg.norm(v2)
        if norm1 == 0 or norm2 == 0:
            similarities[w] = 0
        else
            similarities[w] = np.dot(v, v2) / (norm1 * norm2)
    similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
    
    with open('./cosine/similar_words_with_cosine_of_prob_vectors_to_' + word + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
        for item in similarities:
            f.write(str(item) + '\n')

# %%
def similar_words(word, vectors, aux_path = '', tf_idf = False, dot_product = False, cosine = False):   
 
    if dot_product:
        s_dot_product(word, vectors, aux_path)
                
    if cosine:
        s_cosine(word, vectors, aux_path)

# %% [markdown]
# #### Word associations from preprocessed text with word tokens

# %%
contexts_w = get_contexts_words(vocabulary, preprocessed_text_words)
vectors_w = get_probabilities(vocabulary, contexts_w)
for w in vocabulary:
    try:
        similar_words(w, vectors_w, aux_path = '_by_words', dot_product = True, cosine = True)
        print('Similarity estimations of \033[1m' + w + '\033[0m completed\n')
    except Exception as e:
        print('An error has occured: ' + e + ' in word ' + w)
# Out:
# Similarity estimations of abandonar completed
#
# Similarity estimations of abandono completed
#
# Similarity estimations of abarcar completed
#
# Similarity estimations of abarrotar completed
#
# Similarity estimations of abascal completed
#
# Similarity estimations of abasto completed
#
# Similarity estimations of abatir completed
#
# Similarity estimations of abbasso completed
#
# Similarity estimations of abdicar completed
#
# Similarity estimations of aberrantes completed
#
# Similarity estimations of abierto completed
#
# Similarity estimations of abitia completed
#
# Similarity estimations of abono completed
#
# Similarity estimations of abordaje completed
#
# Similarity estimations of aborigen completed
#
# Similarity estimations of abraham completed
#
# Similarity estimations of abrego completed
#
# Similarity estimations of abril completed
#
# Similarity estimations of abrir completed
#
# Similarity estimations of absalón completed
#
# Similarity estimations of absoluto completed
#
# Similarity estimations of absuelto completed
#
# Similarity estimations of absurdamente completed
#
# Similarity estimations of absurdo completed
#
# Similarity estimations of abuelo completed
#
# Similarity estimations of abundante completed
#
# Similarity estimations of abundar completed
#
# Similarity estimations of aburto completed
#
# Similarity estimations of abusar completed
#
# Similarity estimations of abuso completed
#
# Similarity estimations of ac completed
#
# Similarity estimations of acabado completed
#
# Similarity estimations of acabar completed
#
# Similarity estimations of acaparar completed
#
# Similarity estimations of acapulco completed
#
# Similarity estimations of acarreo completed
#
# Similarity estimations of acaso completed
#
# Similarity estimations of accesible completed
#
# Similarity estimations of acceso completed
#
# Similarity estimations of accidente completed
#
# Similarity estimations of accionar completed
#
# Similarity estimations of accionista completed
#
# Similarity estimations of acción completed
#
# Similarity estimations of acelerar completed
#
# Similarity estimations of acento completed
#
# Similarity estimations of acentuado completed
#
# Similarity estimations of aceptabilidad completed
#
# Similarity estimations of aceptar completed
#
# Similarity estimations of acercar completed
#
# Similarity estimations of acero completed
#
# Similarity estimations of acertado completed
#
# Similarity estimations of acierto completed
#
# Similarity estimations of aclaración completed
#
# Similarity estimations of aclarar completed
#
# Similarity estimations of acompañado completed
#
# Similarity estimations of acompañamiento completed
#
# Similarity estimations of acompañar completed
#
# Similarity estimations of aconsejable completed
#
# Similarity estimations of aconsejar completed
#
# Similarity estimations of acontecimiento completed
#
# Similarity estimations of acopio completed
#
# Similarity estimations of acoplamiento completed
#
# Similarity estimations of acoplar completed
#
# Similarity estimations of acorde completed
#
# Similarity estimations of acotar completed
#
# Similarity estimations of acrecentar completed
#
# Similarity estimations of acreditar completed
#
# Similarity estimations of acreedor completed
#
# Similarity estimations of actitud completed
#
# Similarity estimations of activar completed
#
# Similarity estimations of actividad completed
#
# Similarity estimations of activo completed
#
# Similarity estimations of acto completed
#
# Similarity estimations of actor completed
#
# Similarity estimations of actriz completed
#
# Similarity estimations of actuación completed
#
# Similarity estimations of actual completed
#
# Similarity estimations of actualidad completed
#
# Similarity estimations of actualizar completed
#
# Similarity estimations of actualmente completed
#
# Similarity estimations of actuar completed
#
# Similarity estimations of acudir completed
#
# Similarity estimations of acuerdo completed
#
# Similarity estimations of acumulación completed
#
# Similarity estimations of acumular completed
#
# Similarity estimations of acusación completed
#
# Similarity estimations of acusado completed
#
# Similarity estimations of acusar completed
#
# Similarity estimations of adaptar completed
#
# Similarity estimations of adecuadamente completed
#
# Similarity estimations of adecuado completed
#
# Similarity estimations of adelante completed
#
# Similarity estimations of además completed
#
# Similarity estimations of ades completed
#
# Similarity estimations of adeudos completed
#
# Similarity estimations of adicional completed
#
# Similarity estimations of adición completed
#
# Similarity estimations of adjudicar completed
#
# Similarity estimations of adjunta completed
#
# Similarity estimations of adjunto completed
#
# Similarity estimations of administración completed
#
# Similarity estimations of administrador completed
#
# Similarity estimations of administradora completed
#
# Similarity estimations of administrativa completed
#
# Similarity estimations of administrativo completed
#
# Similarity estimations of admirar completed
#
# Similarity estimations of admitir completed
#
# Similarity estimations of adolf completed
#
# Similarity estimations of adolfo completed
#
# Similarity estimations of adoptar completed
#
# Similarity estimations of adornar completed
#
# Similarity estimations of adquirir completed
#
# Similarity estimations of adquisición completed
#
# Similarity estimations of adquisitivo completed
#
# Similarity estimations of adreessen completed
#
# Similarity estimations of adrián completed
#
# Similarity estimations of aducir completed
#
# Similarity estimations of adulto completed
#
# Similarity estimations of advenedizo completed
#
# Similarity estimations of advenimiento completed
#
# Similarity estimations of adverso completed
#
# Similarity estimations of advertencia completed
#
# Similarity estimations of advertir completed
#
# Similarity estimations of advirtiótambién completed
#
# Similarity estimations of aedpch completed
#
# Similarity estimations of aerolíneas completed
#
# Similarity estimations of aeronave completed
#
# Similarity estimations of aeroportuarias completed
#
# Similarity estimations of aeropuerto completed
#
# Similarity estimations of afectado completed
#
# Similarity estimations of afectar completed
#
# Similarity estimations of aferrar completed
#
# Similarity estimations of afiliar completed
#
# Similarity estimations of afirmación completed
#
# Similarity estimations of afirmar completed
#
# Similarity estimations of afore completed
#
# Similarity estimations of afores completed
#
# Similarity estimations of aforismo completed
#
# Similarity estimations of aforo completed
#
# Similarity estimations of afortunado completed
#
# Similarity estimations of afrancisco completed
#
# Similarity estimations of africa completed
#
# Similarity estimations of afrontar completed
#
# Similarity estimations of afuera completed
#
# Similarity estimations of afán completed
#
# Similarity estimations of agencia completed
#
# Similarity estimations of agenda completed
#
# Similarity estimations of agente completed
#
# Similarity estimations of agilidad completed
#
# Similarity estimations of agilizar completed
#
# Similarity estimations of agobiar completed
#
# Similarity estimations of agonía completed
# Similarity estimations of agosto completed
#
# Similarity estimations of agotar completed
#
# Similarity estimations of agradecer completed
#
# Similarity estimations of agradezgo completed
#
# Similarity estimations of agrario completed
#
# Similarity estimations of agrarismo completed
#
# Similarity estimations of agraristas completed
#
# Similarity estimations of agraviado completed
#
# Similarity estimations of agreden completed
#
# Similarity estimations of agregado completed
#
# Similarity estimations of agregar completed
#
# Similarity estimations of agremiados completed
#
# Similarity estimations of agricultor completed
#
# Similarity estimations of agro completed
#
# Similarity estimations of agropecuario completed
#
# Similarity estimations of agrupación completed
#
# Similarity estimations of agrupar completed
#
# Similarity estimations of agrícola completed
#
# Similarity estimations of agua completed
#
# Similarity estimations of aguascalientes completed
#
# Similarity estimations of agudización completed
#
# Similarity estimations of agudizar completed
#
# Similarity estimations of agudo completed
#
# Similarity estimations of aguilar completed
#
# Similarity estimations of aguinaco completed
#
# Similarity estimations of aguirre completed
#
# Similarity estimations of agustin completed
#
# Similarity estimations of ahogada completed
#
# Similarity estimations of ahogar completed
#
# Similarity estimations of ahondar completed
#
# Similarity estimations of ahora completed
#
# Similarity estimations of ahorita completed
#
# Similarity estimations of ahorrador completed
#
# Similarity estimations of ahorradores completed
#
# Similarity estimations of ahorro completed
#
# Similarity estimations of ahuyentar completed
#
# Similarity estimations of ahí completed
#
# Similarity estimations of aicm completed
#
# Similarity estimations of aicn completed
#
# Similarity estimations of aire completed
#
# Similarity estimations of aislado completed
#
# Similarity estimations of ajustar completed
#
# Similarity estimations of ajuste completed
#
# Similarity estimations of ala completed
#
# Similarity estimations of alabat completed
#
# Similarity estimations of alarcón completed
#
# Similarity estimations of alargamiento completed
#
# Similarity estimations of alarmante completed
#
# Similarity estimations of alberto completed
#
# Similarity estimations of albino completed
#
# Similarity estimations of albor completed
#
# Similarity estimations of alcalde completed
#
# Similarity estimations of alcance completed
#
# Similarity estimations of alcanzar completed
#
# Similarity estimations of alcayaga completed
#
# Similarity estimations of alcista completed
#
# Similarity estimations of alcohólica completed
#
# Similarity estimations of aldf completed
#
# Similarity estimations of alegar completed
#
# Similarity estimations of alegre completed
#
# Similarity estimations of alejandro completed
#
# Similarity estimations of alejar completed
#
# Similarity estimations of alemania completed
#
# Similarity estimations of alemanista completed
#
# Similarity estimations of alemán completed
#
# Similarity estimations of alentador completed
#
# Similarity estimations of alerta completed
#
# Similarity estimations of alertar completed
#
# Similarity estimations of alfa completed
#
# Similarity estimations of alfaro completed
#
# Similarity estimations of alfonso completed
#
# Similarity estimations of alfredo completed
#
# Similarity estimations of alférez completed
#
# Similarity estimations of alguien completed
#
# Similarity estimations of alguna completed
#
# Similarity estimations of alguno completed
#
# Similarity estimations of algún completed
#
# Similarity estimations of aliado completed
#
# Similarity estimations of alianza completed
#
# Similarity estimations of alice completed
#
# Similarity estimations of alimentación completed
#
# Similarity estimations of alimentario completed
#
# Similarity estimations of alimenticio completed
#
# Similarity estimations of alimento completed
#
# Similarity estimations of allegada completed
#
# Similarity estimations of allende completed
#
# Similarity estimations of alliance completed
#
# Similarity estimations of allora completed
#
# Similarity estimations of allá completed
#
# Similarity estimations of allí completed
#
# Similarity estimations of almacenar completed
#
# Similarity estimations of almoloya completed
#
# Similarity estimations of alonso completed
#
# Similarity estimations of alpha completed
#
# Similarity estimations of alponte completed
#
# Similarity estimations of alpro completed
#
# Similarity estimations of alrededor completed
#
# Similarity estimations of alta completed
#
# Similarity estimations of altamirano completed
#
# Similarity estimations of altar completed
#
# Similarity estimations of altarcito completed
#
# Similarity estimations of alteración completed
#
# Similarity estimations of alterar completed
#
# Similarity estimations of alternar completed
#
# Similarity estimations of altibajos completed
#
# Similarity estimations of alto completed
#
# Similarity estimations of altoparlante completed
#
# Similarity estimations of altura completed
#
# Similarity estimations of altísimo completed
#
# Similarity estimations of alumno completed
#
# Similarity estimations of alvarado completed
#
# Similarity estimations of alvarez completed
#
# Similarity estimations of alvaro completed
#
# Similarity estimations of alza completed
#
# Similarity estimations of alzamiento completed
#
# Similarity estimations of amador completed
#
# Similarity estimations of amargo completed
#
# Similarity estimations of amarra completed
#
# Similarity estimations of amañar completed
#
# Similarity estimations of ambas completed
#
# Similarity estimations of ambicioso completed
#
# Similarity estimations of ambiente completed
#
# Similarity estimations of ambos completed
#
# Similarity estimations of amelia completed
#
# Similarity estimations of amenaza completed
#
# Similarity estimations of america completed
#
# Similarity estimations of americom completed
#
# Similarity estimations of amhym completed
#
# Similarity estimations of amib completed
#
# Similarity estimations of amiga completed
#
# Similarity estimations of amigo completed
#
# Similarity estimations of amor completed
#
# Similarity estimations of amortización completed
#
# Similarity estimations of amparo completed
#
# Similarity estimations of ampliamente completed
#
# Similarity estimations of ampliar completed
#
# Similarity estimations of amplio completed
#
# Similarity estimations of américa completed
#
# Similarity estimations of analista completed
#
# Similarity estimations of analizar completed
#
# Similarity estimations of analítico completed
#
# Similarity estimations of anarquía completed
#
# Similarity estimations of anciano completed
#
# Similarity estimations of andar completed
#
# Similarity estimations of andreessen completed
#
# Similarity estimations of andres completed
#
# Similarity estimations of andrés completed
#
# Similarity estimations of andrómeda completed
#
# Similarity estimations of ane completed
#
# Similarity estimations of anexo completed
#
# Similarity estimations of angel completed
#
# Similarity estimations of angeles completed
#
# Similarity estimations of angloamericanos completed
#
# Similarity estimations of angustia completed
#
# Similarity estimations of angustioso completed
# Similarity estimations of anhelar completed
#
# Similarity estimations of anillo completed
#
# Similarity estimations of aniversario completed
#
# Similarity estimations of anomalía completed
#
# Similarity estimations of anotar completed
#
# Similarity estimations of ansioso completed
#
# Similarity estimations of antagónico completed
#
# Similarity estimations of antaño completed
#
# Similarity estimations of antecesor completed
#
# Similarity estimations of antelmo completed
#
# Similarity estimations of anteproyecto completed
#
# Similarity estimations of anterior completed
#
# Similarity estimations of anteriormente completed
#
# Similarity estimations of anticipación completed
#
# Similarity estimations of anticipar completed
#
# Similarity estimations of anticonstitucionales completed
#
# Similarity estimations of antiguo completed
#
# Similarity estimations of antigüita completed
#
# Similarity estimations of antimigratoria completed
#
# Similarity estimations of antipatía completed
#
# Similarity estimations of antonio completed
#
# Similarity estimations of antorcha completed
#
# Similarity estimations of antuna completed
#
# Similarity estimations of anual completed
#
# Similarity estimations of anuencia completed
#
# Similarity estimations of anular completed
#
# Similarity estimations of anunciar completed
#
# Similarity estimations of anuncio completed
#
# Similarity estimations of anáhuac completed
#
# Similarity estimations of análisis completed
#
# Similarity estimations of apacible completed
#
# Similarity estimations of apaciguar completed
#
# Similarity estimations of apapacho completed
#
# Similarity estimations of aparato completed
#
# Similarity estimations of aparecer completed
#
# Similarity estimations of aparentemente completed
#
# Similarity estimations of aparición completed
#
# Similarity estimations of apartado completed
#
# Similarity estimations of apartar completed
#
# Similarity estimations of aparte completed
#
# Similarity estimations of apegar completed
#
# Similarity estimations of apego completed
#
# Similarity estimations of apelación completed
#
# Similarity estimations of apenas completed
#
# Similarity estimations of apertura completed
#
# Similarity estimations of aplicable completed
#
# Similarity estimations of aplicación completed
#
# Similarity estimations of aplicado completed
#
# Similarity estimations of aplicar completed
#
# Similarity estimations of apoderado completed
#
# Similarity estimations of apoderamientos completed
#
# Similarity estimations of apoderar completed
#
# Similarity estimations of aporrear completed
#
# Similarity estimations of aportar completed
#
# Similarity estimations of apostar completed
#
# Similarity estimations of apoteótica completed
#
# Similarity estimations of apoyar completed
#
# Similarity estimations of apoyo completed
#
# Similarity estimations of apple completed
#
# Similarity estimations of applets completed
#
# Similarity estimations of apreciación completed
#
# Similarity estimations of apreciar completed
#
# Similarity estimations of aprehensión completed
#
# Similarity estimations of aprender completed
#
# Similarity estimations of apresar completed
#
# Similarity estimations of apresta completed
#
# Similarity estimations of apresurar completed
#
# Similarity estimations of aprobación completed
#
# Similarity estimations of aprobar completed
#
# Similarity estimations of apropiado completed
#
# Similarity estimations of aprovechada completed
#
# Similarity estimations of aprovechamiento completed
#
# Similarity estimations of aprovechar completed
#
# Similarity estimations of aproximadamente completed
#
# Similarity estimations of aproximado completed
#
# Similarity estimations of aptitud completed
#
# Similarity estimations of apuntar completed
#
# Similarity estimations of aquejar completed
#
# Similarity estimations of aquel completed
#
# Similarity estimations of aquella completed
#
# Similarity estimations of aquello completed
#
# Similarity estimations of aquellos completed
#
# Similarity estimations of aquél completed
#
# Similarity estimations of aquí completed
#
# Similarity estimations of ara completed
#
# Similarity estimations of aragón completed
#
# Similarity estimations of arancel completed
#
# Similarity estimations of arbitral completed
#
# Similarity estimations of arbitrario completed
#
# Similarity estimations of arca completed
#
# Similarity estimations of archivo completed
#
# Similarity estimations of arco completed
#
# Similarity estimations of arder completed
#
# Similarity estimations of ardid completed
#
# Similarity estimations of arena completed
#
# Similarity estimations of argentina completed
#
# Similarity estimations of argumentar completed
#
# Similarity estimations of argumento completed
#
# Similarity estimations of aria completed
#
# Similarity estimations of arizmendi completed
#
# Similarity estimations of arma completed
#
# Similarity estimations of armada completed
#
# Similarity estimations of armado completed
#
# Similarity estimations of armando completed
#
# Similarity estimations of armonía completed
#
# Similarity estimations of armónicamente completed
#
# Similarity estimations of armónico completed
#
# Similarity estimations of arnault completed
#
# Similarity estimations of arqueológico completed
#
# Similarity estimations of arquitecto completed
#
# Similarity estimations of arquitectura completed
#
# Similarity estimations of arrancar completed
#
# Similarity estimations of arrastrar completed
#
# Similarity estimations of arreglo completed
#
# Similarity estimations of arrendadora completed
#
# Similarity estimations of arreola completed
#
# Similarity estimations of arresto completed
#
# Similarity estimations of arriba completed
#
# Similarity estimations of arribar completed
#
# Similarity estimations of arribo completed
#
# Similarity estimations of arrobaexcelsiorcommx completed
#
# Similarity estimations of arrojar completed
#
# Similarity estimations of arropar completed
#
# Similarity estimations of arroyo completed
#
# Similarity estimations of arte completed
#
# Similarity estimations of artificial completed
#
# Similarity estimations of artimaña completed
#
# Similarity estimations of artista completed
#
# Similarity estimations of arturo completed
#
# Similarity estimations of artículo completed
#
# Similarity estimations of arvizu completed
#
# Similarity estimations of arzobispo completed
#
# Similarity estimations of arzú completed
#
# Similarity estimations of asa completed
#
# Similarity estimations of asalariada completed
#
# Similarity estimations of asalariado completed
#
# Similarity estimations of asaltante completed
#
# Similarity estimations of asamblea completed
#
# Similarity estimations of asambleísta completed
#
# Similarity estimations of asambleístas completed
#
# Similarity estimations of ascender completed
#
# Similarity estimations of ascensión completed
#
# Similarity estimations of ascenso completed
#
# Similarity estimations of asegurar completed
#
# Similarity estimations of asentar completed
#
# Similarity estimations of asentir completed
#
# Similarity estimations of asequible completed
#
# Similarity estimations of asesinar completed
#
# Similarity estimations of asesinato completed
#
# Similarity estimations of asesino completed
#
# Similarity estimations of asesorar completed
#
# Similarity estimations of asesoría completed
# Similarity estimations of aseverar completed
#
# Similarity estimations of asfixia completed
#
# Similarity estimations of asfixiar completed
#
# Similarity estimations of asignación completed
#
# Similarity estimations of asignar completed
#
# Similarity estimations of asimilar completed
#
# Similarity estimations of asimismo completed
#
# Similarity estimations of asir completed
#
# Similarity estimations of asistencia completed
#
# Similarity estimations of asistencial completed
#
# Similarity estimations of asistente completed
#
# Similarity estimations of asistir completed
#
# Similarity estimations of asociación completed
#
# Similarity estimations of asociar completed
#
# Similarity estimations of aspecto completed
#
# Similarity estimations of aspiración completed
#
# Similarity estimations of aspirar completed
#
# Similarity estimations of astronauta completed
#
# Similarity estimations of astroso completed
#
# Similarity estimations of astucia completed
#
# Similarity estimations of asueto completed
#
# Similarity estimations of asumir completed
#
# Similarity estimations of asunto completed
#
# Similarity estimations of atacar completed
#
# Similarity estimations of atajar completed
#
# Similarity estimations of atar completed
#
# Similarity estimations of atención completed
#
# Similarity estimations of atender completed
#
# Similarity estimations of atentamente completed
#
# Similarity estimations of atentar completed
#
# Similarity estimations of aterrizaje completed
#
# Similarity estimations of aterrizar completed
#
# Similarity estimations of atinadamente completed
#
# Similarity estimations of atinado completed
#
# Similarity estimations of atisbar completed
#
# Similarity estimations of atlantis completed
#
# Similarity estimations of atoyac completed
#
# Similarity estimations of atracar completed
#
# Similarity estimations of atractivo completed
#
# Similarity estimations of atraer completed
#
# Similarity estimations of atraso completed
#
# Similarity estimations of atravesar completed
#
# Similarity estimations of através completed
#
# Similarity estimations of atribución completed
#
# Similarity estimations of audio completed
#
# Similarity estimations of auditar completed
#
# Similarity estimations of auditoria completed
#
# Similarity estimations of auditorias completed
#
# Similarity estimations of auditorio completed
#
# Similarity estimations of auditoría completed
#
# Similarity estimations of augusta completed
#
# Similarity estimations of aumentar completed
#
# Similarity estimations of aumento completed
#
# Similarity estimations of aun completed
#
# Similarity estimations of aunque completed
#
# Similarity estimations of auque completed
#
# Similarity estimations of aurora completed
#
# Similarity estimations of ausentismo completed
#
# Similarity estimations of auspiciar completed
#
# Similarity estimations of australia completed
#
# Similarity estimations of austria completed
#
# Similarity estimations of auto completed
#
# Similarity estimations of autobús completed
#
# Similarity estimations of autoconsumo completed
#
# Similarity estimations of autoinvasiones completed
#
# Similarity estimations of automática completed
#
# Similarity estimations of automáticamente completed
#
# Similarity estimations of automático completed
#
# Similarity estimations of automóvil completed
#
# Similarity estimations of autonomía completed
#
# Similarity estimations of autopista completed
#
# Similarity estimations of autor completed
#
# Similarity estimations of autoridad completed
#
# Similarity estimations of autoritarismo completed
#
# Similarity estimations of autorizar completed
#
# Similarity estimations of autotransporte completed
#
# Similarity estimations of autotransportes completed
#
# Similarity estimations of autrey completed
#
# Similarity estimations of auténtica completed
#
# Similarity estimations of auténtico completed
#
# Similarity estimations of autónomo completed
#
# Similarity estimations of auxiliar completed
#
# Similarity estimations of auxilio completed
#
# Similarity estimations of av completed
#
# Similarity estimations of avalúos completed
#
# Similarity estimations of avance completed
#
# Similarity estimations of avanzar completed
#
# Similarity estimations of avecinan completed
#
# Similarity estimations of avelar completed
#
# Similarity estimations of avenida completed
#
# Similarity estimations of averiguaciones completed
#
# Similarity estimations of averiguar completed
#
# Similarity estimations of aversión completed
#
# Similarity estimations of avila completed
#
# Similarity estimations of avisar completed
#
# Similarity estimations of aviso completed
#
# Similarity estimations of avión completed
#
# Similarity estimations of ayala completed
#
# Similarity estimations of ayer completed
#
# Similarity estimations of ayuda completed
#
# Similarity estimations of ayudar completed
#
# Similarity estimations of ayuno completed
#
# Similarity estimations of azcapotzalco completed
#
# Similarity estimations of azteca completed
#
# Similarity estimations of azul completed
#
# Similarity estimations of azúcar completed
#
# Similarity estimations of aéreo completed
#
# Similarity estimations of añadir completed
#
# Similarity estimations of año completed
#
# Similarity estimations of aún completed
#
# Similarity estimations of bache completed
#
# Similarity estimations of bah completed
#
# Similarity estimations of baile completed
#
# Similarity estimations of baja completed
#
# Similarity estimations of bajar completed
#
# Similarity estimations of bajo completed
#
# Similarity estimations of balance completed
#
# Similarity estimations of balanza completed
#
# Similarity estimations of baldenegro completed
#
# Similarity estimations of balneario completed
#
# Similarity estimations of balón completed
#
# Similarity estimations of banamex completed
#
# Similarity estimations of banc completed
#
# Similarity estimations of banca completed
#
# Similarity estimations of bancario completed
#
# Similarity estimations of bancarrota completed
#
# Similarity estimations of banco completed
#
# Similarity estimations of bancomer completed
#
# Similarity estimations of bandera completed
#
# Similarity estimations of bandido completed
#
# Similarity estimations of bando completed
#
# Similarity estimations of banjidal completed
#
# Similarity estimations of banobras completed
#
# Similarity estimations of banquero completed
#
# Similarity estimations of banqueta completed
#
# Similarity estimations of banrural completed
#
# Similarity estimations of banxico completed
#
# Similarity estimations of baranda completed
#
# Similarity estimations of barato completed
#
# Similarity estimations of barba completed
#
# Similarity estimations of barca completed
#
# Similarity estimations of barco completed
#
# Similarity estimations of barra completed
#
# Similarity estimations of barragán completed
#
# Similarity estimations of barreda completed
#
# Similarity estimations of barrio completed
#
# Similarity estimations of bartola completed
#
# Similarity estimations of basar completed
#
# Similarity estimations of base completed
#
# Similarity estimations of bastante completed
#
# Similarity estimations of bastar completed
#
# Similarity estimations of basura completed
#
# Similarity estimations of baño completed
#
# Similarity estimations of bdem completed
# Similarity estimations of beach completed
#
# Similarity estimations of bebida completed
#
# Similarity estimations of beca completed
#
# Similarity estimations of becerril completed
#
# Similarity estimations of bell completed
#
# Similarity estimations of beltrones completed
#
# Similarity estimations of belén completed
#
# Similarity estimations of bendecir completed
#
# Similarity estimations of bendición completed
#
# Similarity estimations of beneficiar completed
#
# Similarity estimations of beneficiario completed
#
# Similarity estimations of beneficios completed
#
# Similarity estimations of benito completed
#
# Similarity estimations of benévolo completed
#
# Similarity estimations of berdejo completed
#
# Similarity estimations of bernal completed
#
# Similarity estimations of besar completed
#
# Similarity estimations of bezanilla completed
#
# Similarity estimations of bianual completed
#
# Similarity estimations of bicicleta completed
#
# Similarity estimations of bien completed
#
# Similarity estimations of bienestar completed
#
# Similarity estimations of bienintencionado completed
#
# Similarity estimations of bienvenidos completed
#
# Similarity estimations of bill completed
#
# Similarity estimations of billete completed
#
# Similarity estimations of bimestre completed
#
# Similarity estimations of biofísicos completed
#
# Similarity estimations of biológico completed
#
# Similarity estimations of bla completed
#
# Similarity estimations of blaha completed
#
# Similarity estimations of blanca completed
#
# Similarity estimations of blanco completed
#
# Similarity estimations of blando completed
#
# Similarity estimations of blanquiazul completed
#
# Similarity estimations of blemas completed
#
# Similarity estimations of bloquear completed
#
# Similarity estimations of bmv completed
#
# Similarity estimations of bobo completed
#
# Similarity estimations of boca completed
#
# Similarity estimations of bodrios completed
#
# Similarity estimations of boeing completed
#
# Similarity estimations of bolita completed
#
# Similarity estimations of bolsa completed
#
# Similarity estimations of bolseros completed
#
# Similarity estimations of bombardear completed
#
# Similarity estimations of bonhomía completed
#
# Similarity estimations of bonos completed
#
# Similarity estimations of boom completed
#
# Similarity estimations of borde completed
#
# Similarity estimations of bordo completed
#
# Similarity estimations of borghese completed
#
# Similarity estimations of borja completed
#
# Similarity estimations of borrego completed
#
# Similarity estimations of bosque completed
#
# Similarity estimations of botín completed
#
# Similarity estimations of bours completed
#
# Similarity estimations of brasil completed
#
# Similarity estimations of braun completed
#
# Similarity estimations of brecha completed
#
# Similarity estimations of bretaña completed
#
# Similarity estimations of brete completed
#
# Similarity estimations of breve completed
#
# Similarity estimations of breves completed
#
# Similarity estimations of brindar completed
#
# Similarity estimations of brito completed
#
# Similarity estimations of británica completed
#
# Similarity estimations of brote completed
#
# Similarity estimations of brusco completed
#
# Similarity estimations of brutal completed
#
# Similarity estimations of bruto completed
#
# Similarity estimations of buena completed
#
# Similarity estimations of bueno completed
#
# Similarity estimations of bulevar completed
#
# Similarity estimations of burla completed
#
# Similarity estimations of burlar completed
#
# Similarity estimations of bursátil completed
#
# Similarity estimations of busca completed
#
# Similarity estimations of buscar completed
#
# Similarity estimations of butírica completed
#
# Similarity estimations of buzonsímbolo completed
#
# Similarity estimations of básicamente completed
#
# Similarity estimations of básico completed
#
# Similarity estimations of búfalo completed
#
# Similarity estimations of búho completed
#
# Similarity estimations of búsqueda completed
#
# Similarity estimations of cabal completed
#
# Similarity estimations of caballero completed
#
# Similarity estimations of caballeroso completed
#
# Similarity estimations of cabalmente completed
#
# Similarity estimations of caber completed
#
# Similarity estimations of cabeza completed
#
# Similarity estimations of cabezal completed
#
# Similarity estimations of cabida completed
#
# Similarity estimations of cabildo completed
#
# Similarity estimations of cabina completed
#
# Similarity estimations of cabo completed
#
# Similarity estimations of cabrera completed
#
# Similarity estimations of cada completed
#
# Similarity estimations of cadena completed
#
# Similarity estimations of caer completed
#
# Similarity estimations of café completed
#
# Similarity estimations of caifás completed
#
# Similarity estimations of cairo completed
#
# Similarity estimations of caj completed
#
# Similarity estimations of cajb completed
#
# Similarity estimations of cajero completed
#
# Similarity estimations of calabozo completed
#
# Similarity estimations of calado completed
#
# Similarity estimations of calcular completed
#
# Similarity estimations of caldaria completed
#
# Similarity estimations of caldera completed
#
# Similarity estimations of calderón completed
#
# Similarity estimations of calidad completed
#
# Similarity estimations of calificación completed
#
# Similarity estimations of calificar completed
#
# Similarity estimations of california completed
#
# Similarity estimations of californianas completed
#
# Similarity estimations of calle completed
#
# Similarity estimations of callejón completed
#
# Similarity estimations of calley completed
#
# Similarity estimations of callista completed
#
# Similarity estimations of calor completed
#
# Similarity estimations of calumnia completed
#
# Similarity estimations of cama completed
#
# Similarity estimations of camacho completed
#
# Similarity estimations of cambiar completed
#
# Similarity estimations of cambiaria completed
#
# Similarity estimations of cambiario completed
#
# Similarity estimations of cambio completed
#
# Similarity estimations of caminar completed
#
# Similarity estimations of camino completed
#
# Similarity estimations of camioneras completed
#
# Similarity estimations of camioneta completed
#
# Similarity estimations of campa completed
#
# Similarity estimations of campamento completed
#
# Similarity estimations of campaña completed
#
# Similarity estimations of campesina completed
#
# Similarity estimations of campesinado completed
#
# Similarity estimations of campesino completed
#
# Similarity estimations of campestre completed
#
# Similarity estimations of campion completed
#
# Similarity estimations of campo completed
#
# Similarity estimations of canacintra completed
#
# Similarity estimations of canaco completed
#
# Similarity estimations of canadiense completed
#
# Similarity estimations of canadá completed
#
# Similarity estimations of canal completed
#
# Similarity estimations of canalizar completed
#
# Similarity estimations of cancelar completed
#
# Similarity estimations of cancino completed
#
# Similarity estimations of cancún completed
#
# Similarity estimations of candado completed
#
# Similarity estimations of candidato completed
#
# Similarity estimations of candidatura completed
# Similarity estimations of cano completed
#
# Similarity estimations of cansancio completed
#
# Similarity estimations of cantar completed
#
# Similarity estimations of cantidad completed
#
# Similarity estimations of cantinflas completed
#
# Similarity estimations of canto completed
#
# Similarity estimations of capacidad completed
#
# Similarity estimations of capacitación completed
#
# Similarity estimations of capital completed
#
# Similarity estimations of capitalino completed
#
# Similarity estimations of capitalismo completed
#
# Similarity estimations of capitalización completed
#
# Similarity estimations of capitalizar completed
#
# Similarity estimations of capricho completed
#
# Similarity estimations of captación completed
#
# Similarity estimations of captar completed
#
# Similarity estimations of cara completed
#
# Similarity estimations of caracterizado completed
#
# Similarity estimations of caracterizar completed
#
# Similarity estimations of característica completed
#
# Similarity estimations of carantoña completed
#
# Similarity estimations of cardenismo completed
#
# Similarity estimations of cardenista completed
#
# Similarity estimations of cardiaca completed
#
# Similarity estimations of cardiología completed
#
# Similarity estimations of cardona completed
#
# Similarity estimations of carecer completed
#
# Similarity estimations of carencia completed
#
# Similarity estimations of carga completed
#
# Similarity estimations of cargar completed
#
# Similarity estimations of cargo completed
#
# Similarity estimations of caribe completed
#
# Similarity estimations of carlos completed
#
# Similarity estimations of carne completed
#
# Similarity estimations of caro completed
#
# Similarity estimations of carpio completed
#
# Similarity estimations of carranza completed
#
# Similarity estimations of carrera completed
#
# Similarity estimations of carretera completed
#
# Similarity estimations of carretero completed
#
# Similarity estimations of carruseles completed
#
# Similarity estimations of carso completed
#
# Similarity estimations of carta completed
#
# Similarity estimations of cartera completed
#
# Similarity estimations of cartulina completed
#
# Similarity estimations of carácter completed
#
# Similarity estimations of casa completed
#
# Similarity estimations of casanova completed
#
# Similarity estimations of casar completed
#
# Similarity estimations of casi completed
#
# Similarity estimations of casilla completed
#
# Similarity estimations of caso completed
#
# Similarity estimations of castellano completed
#
# Similarity estimations of castigar completed
#
# Similarity estimations of castigo completed
#
# Similarity estimations of castillo completed
#
# Similarity estimations of catalizador completed
#
# Similarity estimations of catar completed
#
# Similarity estimations of catastrófico completed
#
# Similarity estimations of catorcena completed
#
# Similarity estimations of catálogo completed
#
# Similarity estimations of catástrofe completed
#
# Similarity estimations of católica completed
#
# Similarity estimations of católico completed
#
# Similarity estimations of cauce completed
#
# Similarity estimations of caudillesca completed
#
# Similarity estimations of caudillo completed
#
# Similarity estimations of causa completed
#
# Similarity estimations of causante completed
#
# Similarity estimations of causar completed
#
# Similarity estimations of cautivo completed
#
# Similarity estimations of caída completed
#
# Similarity estimations of caído completed
#
# Similarity estimations of cañaveral completed
#
# Similarity estimations of cañedo completed
#
# Similarity estimations of caótico completed
#
# Similarity estimations of cce completed
#
# Similarity estimations of cdiez completed
#
# Similarity estimations of cdrom completed
#
# Similarity estimations of ceder completed
#
# Similarity estimations of ceesp completed
#
# Similarity estimations of celebración completed
#
# Similarity estimations of celebrar completed
#
# Similarity estimations of cemex completed
#
# Similarity estimations of cen completed
#
# Similarity estimations of cena completed
#
# Similarity estimations of ceniza completed
#
# Similarity estimations of censura completed
#
# Similarity estimations of censurar completed
#
# Similarity estimations of centavo completed
#
# Similarity estimations of centenar completed
#
# Similarity estimations of central completed
#
# Similarity estimations of centro completed
#
# Similarity estimations of centroamericana completed
#
# Similarity estimations of ceoic completed
#
# Similarity estimations of cepal completed
#
# Similarity estimations of cerca completed
#
# Similarity estimations of cercano completed
#
# Similarity estimations of cercanía completed
#
# Similarity estimations of cerda completed
#
# Similarity estimations of cerdo completed
#
# Similarity estimations of ceremonia completed
#
# Similarity estimations of ceremonial completed
#
# Similarity estimations of cero completed
#
# Similarity estimations of cerrado completed
#
# Similarity estimations of cerrar completed
#
# Similarity estimations of certidumbre completed
#
# Similarity estimations of certificación completed
#
# Similarity estimations of cesarman completed
#
# Similarity estimations of cese completed
#
# Similarity estimations of cete completed
#
# Similarity estimations of cfe completed
#
# Similarity estimations of chabacano completed
#
# Similarity estimations of chacona completed
#
# Similarity estimations of chapa completed
#
# Similarity estimations of chapopote completed
#
# Similarity estimations of chargoy completed
#
# Similarity estimations of charros completed
#
# Similarity estimations of charter completed
#
# Similarity estimations of charters completed
#
# Similarity estimations of cheque completed
#
# Similarity estimations of chiapaneca completed
#
# Similarity estimations of chiapaneco completed
#
# Similarity estimations of chiapas completed
#
# Similarity estimations of chico completed
#
# Similarity estimations of chicomuselo completed
#
# Similarity estimations of chile completed
#
# Similarity estimations of chilton completed
#
# Similarity estimations of china completed
#
# Similarity estimations of chino completed
#
# Similarity estimations of chirinos completed
#
# Similarity estimations of chis completed
#
# Similarity estimations of chiste completed
#
# Similarity estimations of chivo completed
#
# Similarity estimations of chocante completed
#
# Similarity estimations of chofer completed
#
# Similarity estimations of choque completed
#
# Similarity estimations of chovinismo completed
#
# Similarity estimations of churubuscoal completed
#
# Similarity estimations of chávez completed
#
# Similarity estimations of chéquelo completed
#
# Similarity estimations of ciberespacio completed
#
# Similarity estimations of ciberlectores completed
#
# Similarity estimations of ciclo completed
#
# Similarity estimations of cien completed
#
# Similarity estimations of ciencia completed
#
# Similarity estimations of cienfuegos completed
#
# Similarity estimations of ciento completed
#
# Similarity estimations of científica completed
#
# Similarity estimations of científico completed
#
# Similarity estimations of cierne completed
#
# Similarity estimations of cierre completed
#
# Similarity estimations of ciertamente completed
#
# Similarity estimations of cierto completed
# Similarity estimations of cifra completed
#
# Similarity estimations of cifrián completed
#
# Similarity estimations of cihmech completed
#
# Similarity estimations of cima completed
#
# Similarity estimations of cimentaciones completed
#
# Similarity estimations of cimentar completed
#
# Similarity estimations of cimiento completed
#
# Similarity estimations of cinco completed
#
# Similarity estimations of cine completed
#
# Similarity estimations of cinematografistas completed
#
# Similarity estimations of cinematográfico completed
#
# Similarity estimations of cinescopios completed
#
# Similarity estimations of cinturón completed
#
# Similarity estimations of cioac completed
#
# Similarity estimations of circuito completed
#
# Similarity estimations of circulación completed
#
# Similarity estimations of circulante completed
#
# Similarity estimations of circular completed
#
# Similarity estimations of circunstancia completed
#
# Similarity estimations of cirugía completed
#
# Similarity estimations of cita completed
#
# Similarity estimations of citadino completed
#
# Similarity estimations of citar completed
#
# Similarity estimations of citroen completed
#
# Similarity estimations of ciudad completed
#
# Similarity estimations of ciudadano completed
#
# Similarity estimations of civil completed
#
# Similarity estimations of civilizado completed
#
# Similarity estimations of clandestino completed
#
# Similarity estimations of clara completed
#
# Similarity estimations of claramente completed
#
# Similarity estimations of claremont completed
#
# Similarity estimations of clark completed
#
# Similarity estimations of claro completed
#
# Similarity estimations of claroscuro completed
#
# Similarity estimations of clase completed
#
# Similarity estimations of clasificación completed
#
# Similarity estimations of clave completed
#
# Similarity estimations of clavícula completed
#
# Similarity estimations of clemencia completed
#
# Similarity estimations of clero completed
#
# Similarity estimations of cliente completed
#
# Similarity estimations of clienteservidor completed
#
# Similarity estimations of clifford completed
#
# Similarity estimations of clima completed
#
# Similarity estimations of clásico completed
#
# Similarity estimations of cláusula completed
#
# Similarity estimations of clérigo completed
#
# Similarity estimations of cna completed
#
# Similarity estimations of cnbv completed
#
# Similarity estimations of cnc completed
#
# Similarity estimations of cniv completed
#
# Similarity estimations of cnpi completed
#
# Similarity estimations of co completed
#
# Similarity estimations of coalcomán completed
#
# Similarity estimations of coalición completed
#
# Similarity estimations of cobarde completed
#
# Similarity estimations of cobertura completed
#
# Similarity estimations of cobrar completed
#
# Similarity estimations of cocoyoc completed
#
# Similarity estimations of coexistir completed
#
# Similarity estimations of coger completed
#
# Similarity estimations of coicidieron completed
#
# Similarity estimations of coincidente completed
#
# Similarity estimations of coincidir completed
#
# Similarity estimations of col completed
#
# Similarity estimations of colaborar completed
#
# Similarity estimations of colbeth completed
#
# Similarity estimations of colchón completed
#
# Similarity estimations of coleccionar completed
#
# Similarity estimations of colección completed
#
# Similarity estimations of colectivo completed
#
# Similarity estimations of colega completed
#
# Similarity estimations of colegiado completed
#
# Similarity estimations of colegiatura completed
#
# Similarity estimations of colgado completed
#
# Similarity estimations of colgar completed
#
# Similarity estimations of college completed
#
# Similarity estimations of colmo completed
#
# Similarity estimations of colocar completed
#
# Similarity estimations of colombia completed
#
# Similarity estimations of colombiano completed
#
# Similarity estimations of colonia completed
#
# Similarity estimations of colonial completed
#
# Similarity estimations of colonización completed
#
# Similarity estimations of color completed
#
# Similarity estimations of colorido completed
#
# Similarity estimations of colosio completed
#
# Similarity estimations of colosismo completed
#
# Similarity estimations of colosista completed
#
# Similarity estimations of colosistas completed
#
# Similarity estimations of columna completed
#
# Similarity estimations of comandado completed
#
# Similarity estimations of comandante completed
#
# Similarity estimations of comando completed
#
# Similarity estimations of combate completed
#
# Similarity estimations of combatiente completed
#
# Similarity estimations of combatir completed
#
# Similarity estimations of combatividad completed
#
# Similarity estimations of combinación completed
#
# Similarity estimations of combinado completed
#
# Similarity estimations of combustible completed
#
# Similarity estimations of comentar completed
#
# Similarity estimations of comentario completed
#
# Similarity estimations of comenzar completed
#
# Similarity estimations of comer completed
#
# Similarity estimations of comercial completed
#
# Similarity estimations of comercialización completed
#
# Similarity estimations of comercializar completed
#
# Similarity estimations of comercio completed
#
# Similarity estimations of cometer completed
#
# Similarity estimations of cometido completed
#
# Similarity estimations of comisionado completed
#
# Similarity estimations of comisionar completed
#
# Similarity estimations of comisión completed
#
# Similarity estimations of comité completed
#
# Similarity estimations of compactaciones completed
#
# Similarity estimations of compacto completed
#
# Similarity estimations of companías completed
#
# Similarity estimations of compaq completed
#
# Similarity estimations of comparación completed
#
# Similarity estimations of comparar completed
#
# Similarity estimations of comparecencias completed
#
# Similarity estimations of compareciente completed
#
# Similarity estimations of compartir completed
#
# Similarity estimations of compasión completed
#
# Similarity estimations of compatible completed
#
# Similarity estimations of compatriota completed
#
# Similarity estimations of compañero completed
#
# Similarity estimations of compañía completed
#
# Similarity estimations of compensar completed
#
# ...
#
# Similarity estimations of tranquilo completed
#
# Similarity estimations of transacción completed
#
# Similarity estimations of transbordador completed
#
# Similarity estimations of transcripción completed
#
# Similarity estimations of transformación completed
#
# Similarity estimations of transformar completed
#
# Similarity estimations of transmisión completed
#
# Similarity estimations of transmitir completed
#
# Similarity estimations of transparente completed
#
# Similarity estimations of transporte completed
#
# Similarity estimations of tras completed
#
# Similarity estimations of trascendente completed
#
# Similarity estimations of trasferencia completed
#
# Similarity estimations of trasladar completed
#
# Similarity estimations of traslado completed
#
# Similarity estimations of trasnferencia completed
#
# Similarity estimations of traspasar completed
#
# Similarity estimations of trastocar completed
#
# Similarity estimations of trata completed
#
# Similarity estimations of tratado completed
#
# Similarity estimations of tratamiento completed
#
# Similarity estimations of tratar completed
#
# Similarity estimations of trato completed
#
# Similarity estimations of través completed
#
# Similarity estimations of trayectoria completed
#
# Similarity estimations of treinta completed
#
# Similarity estimations of trejo completed
#
# Similarity estimations of tremendo completed
#
# Similarity estimations of tren completed
#
# Similarity estimations of tres completed
#
# Similarity estimations of triada completed
#
# Similarity estimations of tribal completed
#
# Similarity estimations of tribuna completed
#
# Similarity estimations of tribunal completed
#
# Similarity estimations of trilogía completed
#
# Similarity estimations of trimestre completed
#
# Similarity estimations of tripulación completed
#
# Similarity estimations of triste completed
#
# Similarity estimations of triunfal completed
#
# Similarity estimations of triunfante completed
#
# Similarity estimations of triunfar completed
#
# Similarity estimations of triunfo completed
#
# Similarity estimations of tronar completed
#
# Similarity estimations of tropa completed
#
# Similarity estimations of tropel completed
#
# Similarity estimations of truncado completed
#
# Similarity estimations of trámite completed
#
# Similarity estimations of tránsito completed
#
# Similarity estimations of tula completed
#
# Similarity estimations of tumbalá completed
#
# Similarity estimations of turbiedad completed
#
# Similarity estimations of turismo completed
#
# Similarity estimations of turista completed
#
# Similarity estimations of tutor completed
#
# Similarity estimations of tutto completed
#
# Similarity estimations of técnica completed
#
# Similarity estimations of técnico completed
#
# Similarity estimations of término completed
#
# Similarity estimations of tímido completed
#
# Similarity estimations of tío completed
#
# Similarity estimations of títere completed
# Similarity estimations of título completed
#
# Similarity estimations of tónica completed
#
# Similarity estimations of tótem completed
#
# Similarity estimations of u completed
#
# Similarity estimations of uanl completed
#
# Similarity estimations of ubicar completed
#
# Similarity estimations of ubre completed
#
# Similarity estimations of uc completed
#
# Similarity estimations of ucabe completed
#
# Similarity estimations of udi completed
#
# Similarity estimations of udis completed
#
# Similarity estimations of udla completed
#
# Similarity estimations of ugocp completed
#
# Similarity estimations of ulloa completed
#
# Similarity estimations of ultimar completed
#
# Similarity estimations of ultrapasteurizada completed
#
# Similarity estimations of un completed
#
# Similarity estimations of unam completed
#
# Similarity estimations of unaágina completed
#
# Similarity estimations of unicamente completed
#
# Similarity estimations of unico completed
#
# Similarity estimations of unidad completed
#
# Similarity estimations of unido completed
#
# Similarity estimations of uniformidad completed
#
# Similarity estimations of unir completed
#
# Similarity estimations of unitario completed
#
# Similarity estimations of universal completed
#
# Similarity estimations of universidad completed
#
# Similarity estimations of universo completed
#
# Similarity estimations of unión completed
#
# Similarity estimations of unióncremi completed
#
# Similarity estimations of unocero completed
#
# Similarity estimations of unísono completed
#
# Similarity estimations of urbana completed
#
# Similarity estimations of urbano completed
#
# Similarity estimations of urbe completed
#
# Similarity estimations of urgencia completed
#
# Similarity estimations of urgente completed
#
# Similarity estimations of urgentemente completed
#
# Similarity estimations of urgir completed
#
# Similarity estimations of uribe completed
#
# Similarity estimations of urng completed
#
# Similarity estimations of us completed
#
# Similarity estimations of usado completed
#
# Similarity estimations of usar completed
#
# Similarity estimations of usdec completed
#
# Similarity estimations of uso completed
#
# Similarity estimations of ussachev completed
#
# Similarity estimations of usted completed
#
# Similarity estimations of ustedes completed
#
# Similarity estimations of usuario completed
#
# Similarity estimations of utilidad completed
#
# Similarity estimations of utilización completed
#
# Similarity estimations of utilizar completed
#
# Similarity estimations of utopía completed
#
# Similarity estimations of utópico completed
#
# Similarity estimations of vaca completed
#
# Similarity estimations of vacacional completed
#
# Similarity estimations of vacacionalúnico completed
#
# Similarity estimations of vacacionar completed
#
# Similarity estimations of vacacionistas completed
#
# Similarity estimations of vacación completed
#
# Similarity estimations of vacante completed
#
# Similarity estimations of vacío completed
#
# Similarity estimations of vado completed
#
# Similarity estimations of vaivén completed
#
# Similarity estimations of valderrama completed
#
# Similarity estimations of valdovinos completed
#
# Similarity estimations of valencia completed
#
# Similarity estimations of valenzuela completed
#
# Similarity estimations of valer completed
#
# Similarity estimations of valida completed
#
# Similarity estimations of validar completed
#
# Similarity estimations of validará completed
#
# Similarity estimations of validarán completed
#
# Similarity estimations of valioso completed
#
# Similarity estimations of valle completed
#
# Similarity estimations of valor completed
#
# Similarity estimations of valorar completed
#
# Similarity estimations of valuación completed
#
# Similarity estimations of vano completed
#
# Similarity estimations of variable completed
#
# Similarity estimations of variación completed
#
# Similarity estimations of variante completed
#
# Similarity estimations of variar completed
#
# Similarity estimations of varias completed
#
# Similarity estimations of variedad completed
#
# Similarity estimations of varios completed
#
# Similarity estimations of vasconcelos completed
#
# Similarity estimations of vasquez completed
#
# Similarity estimations of vauchers completed
#
# Similarity estimations of vecinal completed
#
# Similarity estimations of vecino completed
#
# Similarity estimations of vega completed
#
# Similarity estimations of vegetal completed
#
# Similarity estimations of vehicular completed
#
# Similarity estimations of vehículo completed
#
# Similarity estimations of velada completed
#
# Similarity estimations of velasco completed
#
# Similarity estimations of velazco completed
#
# Similarity estimations of veleidad completed
#
# Similarity estimations of velocidad completed
#
# Similarity estimations of velorio completed
#
# Similarity estimations of velázquez completed
#
# Similarity estimations of vencer completed
#
# Similarity estimations of vencida completed
#
# Similarity estimations of vencimiento completed
#
# Similarity estimations of vencimientos completed
#
# Similarity estimations of vendedor completed
#
# Similarity estimations of vendedora completed
#
# Similarity estimations of vender completed
#
# Similarity estimations of venecia completed
#
# Similarity estimations of venegas completed
#
# Similarity estimations of venir completed
#
# Similarity estimations of venta completed
#
# Similarity estimations of ventura completed
#
# Similarity estimations of venustiano completed
#
# Similarity estimations of ver completed
#
# Similarity estimations of veracruz completed
#
# Similarity estimations of veracruzana completed
#
# Similarity estimations of veracruzano completed
#
# Similarity estimations of veracruzanos completed
#
# Similarity estimations of verano completed
#
# Similarity estimations of veras completed
#
# Similarity estimations of verbal completed
#
# Similarity estimations of verdad completed
#
# Similarity estimations of verdadero completed
#
# Similarity estimations of verde completed
#
# Similarity estimations of verdura completed
#
# Similarity estimations of veredicto completed
#
# Similarity estimations of vereoconferencias completed
#
# Similarity estimations of vergonzoso completed
#
# Similarity estimations of vergüenza completed
#
# Similarity estimations of verificación completed
#
# Similarity estimations of verificar completed
#
# Similarity estimations of veronica completed
#
# Similarity estimations of versar completed
#
# Similarity estimations of versión completed
#
# Similarity estimations of verso completed
#
# Similarity estimations of vertical completed
#
# Similarity estimations of vertiginoso completed
#
# Similarity estimations of verónica completed
#
# Similarity estimations of vestido completed
#
# Similarity estimations of vestidura completed
#
# Similarity estimations of vestir completed
#
# Similarity estimations of vez completed
#
# Similarity estimations of viabilidad completed
#
# Similarity estimations of viable completed
#
# Similarity estimations of viacrucis completed
#
# Similarity estimations of viajar completed
#
# Similarity estimations of viaje completed
#
# Similarity estimations of viajero completed
#
# Similarity estimations of vicente completed
#
# Similarity estimations of vicepresidente completed
#
# Similarity estimations of vicio completed
# Similarity estimations of victimario completed
#
# Similarity estimations of victoria completed
#
# Similarity estimations of vida completed
#
# Similarity estimations of videoconferencia completed
#
# Similarity estimations of videoconferencias completed
#
# Similarity estimations of videograbadoras completed
#
# Similarity estimations of vieja completed
#
# Similarity estimations of viejo completed
#
# Similarity estimations of viento completed
#
# Similarity estimations of viernes completed
#
# Similarity estimations of vietnam completed
#
# Similarity estimations of vietnamita completed
#
# Similarity estimations of vigencia completed
#
# Similarity estimations of vigente completed
#
# Similarity estimations of vigilancia completed
#
# Similarity estimations of vigilante completed
#
# Similarity estimations of vigilar completed
#
# Similarity estimations of vigoroso completed
#
# Similarity estimations of vii completed
#
# Similarity estimations of viii completed
#
# Similarity estimations of villa completed
#
# Similarity estimations of villafuerte completed
#
# Similarity estimations of villarreal completed
#
# Similarity estimations of villegas completed
#
# Similarity estimations of vilo completed
#
# Similarity estimations of vincular completed
#
# Similarity estimations of violación completed
#
# Similarity estimations of violar completed
#
# Similarity estimations of violencia completed
#
# Similarity estimations of violento completed
#
# Similarity estimations of virginia completed
#
# Similarity estimations of viril completed
#
# Similarity estimations of virtual completed
#
# Similarity estimations of virtualmente completed
#
# Similarity estimations of virtud completed
#
# Similarity estimations of virud completed
#
# Similarity estimations of visionario completed
#
# Similarity estimations of visita completed
#
# Similarity estimations of visitar completed
#
# Similarity estimations of visión completed
#
# Similarity estimations of vislumbrar completed
#
# Similarity estimations of vista completed
#
# Similarity estimations of visto completed
#
# Similarity estimations of vital completed
#
# Similarity estimations of vitrales completed
#
# Similarity estimations of vitro completed
#
# Similarity estimations of vituperio completed
#
# Similarity estimations of viuda completed
#
# Similarity estimations of viva completed
#
# Similarity estimations of vive completed
#
# Similarity estimations of viven completed
#
# Similarity estimations of vividor completed
#
# Similarity estimations of vivienda completed
#
# Similarity estimations of viviente completed
#
# Similarity estimations of viviento completed
#
# Similarity estimations of vivir completed
#
# Similarity estimations of vocación completed
#
# Similarity estimations of vocal completed
#
# Similarity estimations of vocero completed
#
# Similarity estimations of volante completed
#
# Similarity estimations of volatilidad completed
#
# Similarity estimations of volumen completed
#
# Similarity estimations of voluntad completed
#
# Similarity estimations of voluntario completed
#
# Similarity estimations of volver completed
#
# Similarity estimations of volátil completed
#
# Similarity estimations of votación completed
#
# Similarity estimations of votante completed
#
# Similarity estimations of votar completed
#
# Similarity estimations of voto completed
#
# Similarity estimations of vouchers completed
#
# Similarity estimations of voz completed
#
# Similarity estimations of vuelo completed
#
# Similarity estimations of vulgar completed
#
# Similarity estimations of vulgo completed
#
# Similarity estimations of válido completed
#
# Similarity estimations of vázquez completed
#
# Similarity estimations of vía completed
#
# Similarity estimations of víctima completed
#
# Similarity estimations of víctor completed
#
# Similarity estimations of vínculo completed
#
# Similarity estimations of warlain completed
#
# Similarity estimations of washington completed
#
# Similarity estimations of wb completed
#
# Similarity estimations of web completed
#
# Similarity estimations of wide completed
#
# Similarity estimations of wilhelmy completed
#
# Similarity estimations of william completed
#
# Similarity estimations of wilson completed
#
# Similarity estimations of workshop completed
#
# Similarity estimations of world completed
#
# Similarity estimations of wozniak completed
#
# Similarity estimations of www completed
#
# Similarity estimations of wwwexcelsiorcommx completed
#
# Similarity estimations of xenofóbicos completed
#
# Similarity estimations of xii completed
#
# Similarity estimations of xochicalco completed
#
# Similarity estimations of xx completed
#
# Similarity estimations of xxi completed
#
# Similarity estimations of yacer completed
#
# Similarity estimations of yllanes completed
#
# Similarity estimations of york completed
#
# Similarity estimations of yuri completed
#
# Similarity estimations of zacatecas completed
#
# Similarity estimations of zapata completed
#
# Similarity estimations of zapatismo completed
#
# Similarity estimations of zapato completed
#
# Similarity estimations of zavala completed
#
# Similarity estimations of zea completed
#
# Similarity estimations of zedillista completed
#
# Similarity estimations of zedillo completed
#
# Similarity estimations of zepeda completed
#
# Similarity estimations of zona completed
#
# Similarity estimations of zutano completed
#
# Similarity estimations of zócalo completed
#
# Similarity estimations of ámbito completed
#
# Similarity estimations of ánimo completed
#
# Similarity estimations of áprivada completed
#
# Similarity estimations of área completed
#
# Similarity estimations of áócfel completed
#
# Similarity estimations of época completed
#
# Similarity estimations of ése completed
#
# Similarity estimations of ésta completed
#
# Similarity estimations of éste completed
#
# Similarity estimations of ésto completed
#
# Similarity estimations of étnico completed
#
# Similarity estimations of éxito completed
#
# Similarity estimations of éxodo completed
#
# Similarity estimations of ídolo completed
#
# Similarity estimations of índice completed
#
# Similarity estimations of índole completed
#
# Similarity estimations of íntegro completed
#
# Similarity estimations of óptimo completed
#
# Similarity estimations of órbita completed
#
# Similarity estimations of órgano completed
#
# Similarity estimations of último completed
#
# Similarity estimations of únicamente completed
#
# Similarity estimations of único completed

# %% [markdown]
# #### Word associations from preprocessed text with sentence tokens

# %%
contexts_s = get_contexts_sents(vocabulary, preprocessed_text_sents)
vectors_s = get_probabilities(vocabulary, contexts_s)
for w in vocabulary:
    try:
        similar_words(w, vectors_s, aux_path = '_by_sents', dot_product = True, cosine = True)
        print('Similarity estimations of \033[1m' + w + '\033[0m completed\n')
    except Exception as e:
        print('An error has occured: ' + e + ' in word ' + w)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20928\67276752.py:36: RuntimeWarning: invalid value encountered in double_scalars
#   similarities[w] = np.dot(v, v2) / (np.linalg.norm(v) * np.linalg.norm(v2))
# Similarity estimations of abandonar completed
#
# Similarity estimations of abandono completed
#
# Similarity estimations of abarcar completed
#
# Similarity estimations of abarrotar completed
#
# Similarity estimations of abascal completed
#
# Similarity estimations of abasto completed
#
# Similarity estimations of abatir completed
#
# Similarity estimations of abbasso completed
#
# Similarity estimations of abdicar completed
#
# Similarity estimations of aberrantes completed
#
# Similarity estimations of abierto completed
#
# Similarity estimations of abitia completed
#
# Similarity estimations of abono completed
#
# Similarity estimations of abordaje completed
#
# Similarity estimations of aborigen completed
#
# Similarity estimations of abraham completed
#
# Similarity estimations of abrego completed
#
# Similarity estimations of abril completed
#
# Similarity estimations of abrir completed
#
# Similarity estimations of absalón completed
#
# Similarity estimations of absoluto completed
#
# Similarity estimations of absuelto completed
#
# Similarity estimations of absurdamente completed
#
# Similarity estimations of absurdo completed
#
# Similarity estimations of abuelo completed
#
# Similarity estimations of abundante completed
#
# Similarity estimations of abundar completed
#
# Similarity estimations of aburto completed
#
# Similarity estimations of abusar completed
#
# Similarity estimations of abuso completed
#
# Similarity estimations of ac completed
#
# Similarity estimations of acabado completed
#
# Similarity estimations of acabar completed
#
# Similarity estimations of acaparar completed
#
# Similarity estimations of acapulco completed
#
# Similarity estimations of acarreo completed
#
# Similarity estimations of acaso completed
#
# Similarity estimations of accesible completed
#
# Similarity estimations of acceso completed
#
# Similarity estimations of accidente completed
#
# Similarity estimations of accionar completed
#
# Similarity estimations of accionista completed
#
# Similarity estimations of acción completed
#
# Similarity estimations of acelerar completed
#
# Similarity estimations of acento completed
#
# Similarity estimations of acentuado completed
#
# Similarity estimations of aceptabilidad completed
#
# Similarity estimations of aceptar completed
#
# Similarity estimations of acercar completed
#
# Similarity estimations of acero completed
#
# Similarity estimations of acertado completed
#
# Similarity estimations of acierto completed
#
# Similarity estimations of aclaración completed
#
# Similarity estimations of aclarar completed
#
# Similarity estimations of acompañado completed
#
# Similarity estimations of acompañamiento completed
#
# Similarity estimations of acompañar completed
#
# Similarity estimations of aconsejable completed
#
# Similarity estimations of aconsejar completed
#
# Similarity estimations of acontecimiento completed
#
# Similarity estimations of acopio completed
#
# Similarity estimations of acoplamiento completed
#
# Similarity estimations of acoplar completed
#
# Similarity estimations of acorde completed
#
# Similarity estimations of acotar completed
#
# Similarity estimations of acrecentar completed
#
# Similarity estimations of acreditar completed
#
# Similarity estimations of acreedor completed
#
# Similarity estimations of actitud completed
#
# Similarity estimations of activar completed
#
# Similarity estimations of actividad completed
#
# Similarity estimations of activo completed
#
# Similarity estimations of acto completed
#
# Similarity estimations of actor completed
#
# Similarity estimations of actriz completed
#
# Similarity estimations of actuación completed
#
# Similarity estimations of actual completed
#
# Similarity estimations of actualidad completed
#
# Similarity estimations of actualizar completed
#
# Similarity estimations of actualmente completed
#
# Similarity estimations of actuar completed
#
# Similarity estimations of acudir completed
#
# Similarity estimations of acuerdo completed
#
# Similarity estimations of acumulación completed
#
# Similarity estimations of acumular completed
#
# Similarity estimations of acusación completed
#
# Similarity estimations of acusado completed
#
# Similarity estimations of acusar completed
#
# Similarity estimations of adaptar completed
#
# Similarity estimations of adecuadamente completed
#
# Similarity estimations of adecuado completed
#
# Similarity estimations of adelante completed
#
# Similarity estimations of además completed
#
# Similarity estimations of ades completed
#
# Similarity estimations of adeudos completed
#
# Similarity estimations of adicional completed
#
# Similarity estimations of adición completed
#
# Similarity estimations of adjudicar completed
#
# Similarity estimations of adjunta completed
#
# Similarity estimations of adjunto completed
#
# Similarity estimations of administración completed
#
# Similarity estimations of administrador completed
#
# Similarity estimations of administradora completed
#
# Similarity estimations of administrativa completed
#
# Similarity estimations of administrativo completed
#
# Similarity estimations of admirar completed
#
# Similarity estimations of admitir completed
#
# Similarity estimations of adolf completed
#
# Similarity estimations of adolfo completed
#
# Similarity estimations of adoptar completed
#
# Similarity estimations of adornar completed
#
# Similarity estimations of adquirir completed
#
# Similarity estimations of adquisición completed
#
# Similarity estimations of adquisitivo completed
#
# Similarity estimations of adreessen completed
#
# Similarity estimations of adrián completed
#
# Similarity estimations of aducir completed
#
# Similarity estimations of adulto completed
#
# Similarity estimations of advenedizo completed
#
# Similarity estimations of advenimiento completed
#
# Similarity estimations of adverso completed
#
# Similarity estimations of advertencia completed
#
# Similarity estimations of advertir completed
#
# Similarity estimations of advirtiótambién completed
#
# Similarity estimations of aedpch completed
#
# Similarity estimations of aerolíneas completed
#
# Similarity estimations of aeronave completed
#
# Similarity estimations of aeroportuarias completed
#
# Similarity estimations of aeropuerto completed
#
# Similarity estimations of afectado completed
#
# Similarity estimations of afectar completed
#
# Similarity estimations of aferrar completed
#
# Similarity estimations of afiliar completed
#
# Similarity estimations of afirmación completed
#
# Similarity estimations of afirmar completed
#
# Similarity estimations of afore completed
#
# Similarity estimations of afores completed
#
# Similarity estimations of aforismo completed
#
# Similarity estimations of aforo completed
#
# Similarity estimations of afortunado completed
#
# Similarity estimations of afrancisco completed
#
# Similarity estimations of africa completed
#
# Similarity estimations of afrontar completed
#
# Similarity estimations of afuera completed
#
# Similarity estimations of afán completed
#
# Similarity estimations of agencia completed
#
# Similarity estimations of agenda completed
#
# Similarity estimations of agente completed
#
# Similarity estimations of agilidad completed
#
# Similarity estimations of agilizar completed
#
# Similarity estimations of agobiar completed
#
# Similarity estimations of agonía completed
# Similarity estimations of agosto completed
#
# Similarity estimations of agotar completed
#
# Similarity estimations of agradecer completed
#
# Similarity estimations of agradezgo completed
#
# Similarity estimations of agrario completed
#
# Similarity estimations of agrarismo completed
#
# Similarity estimations of agraristas completed
#
# Similarity estimations of agraviado completed
#
# Similarity estimations of agreden completed
#
# Similarity estimations of agregado completed
#
# Similarity estimations of agregar completed
#
# Similarity estimations of agremiados completed
#
# Similarity estimations of agricultor completed
#
# Similarity estimations of agro completed
#
# Similarity estimations of agropecuario completed
#
# Similarity estimations of agrupación completed
#
# Similarity estimations of agrupar completed
#
# Similarity estimations of agrícola completed
#
# Similarity estimations of agua completed
#
# Similarity estimations of aguascalientes completed
#
# Similarity estimations of agudización completed
#
# Similarity estimations of agudizar completed
#
# Similarity estimations of agudo completed
#
# Similarity estimations of aguilar completed
#
# Similarity estimations of aguinaco completed
#
# Similarity estimations of aguirre completed
#
# Similarity estimations of agustin completed
#
# Similarity estimations of ahogada completed
#
# Similarity estimations of ahogar completed
#
# Similarity estimations of ahondar completed
#
# Similarity estimations of ahora completed
#
# Similarity estimations of ahorita completed
#
# Similarity estimations of ahorrador completed
#
# Similarity estimations of ahorradores completed
#
# Similarity estimations of ahorro completed
#
# Similarity estimations of ahuyentar completed
#
# Similarity estimations of ahí completed
#
# Similarity estimations of aicm completed
#
# Similarity estimations of aicn completed
#
# Similarity estimations of aire completed
#
# Similarity estimations of aislado completed
#
# Similarity estimations of ajustar completed
#
# Similarity estimations of ajuste completed
#
# Similarity estimations of ala completed
#
# Similarity estimations of alabat completed
#
# Similarity estimations of alarcón completed
#
# Similarity estimations of alargamiento completed
#
# Similarity estimations of alarmante completed
#
# Similarity estimations of alberto completed
#
# Similarity estimations of albino completed
#
# Similarity estimations of albor completed
#
# Similarity estimations of alcalde completed
#
# Similarity estimations of alcance completed
#
# Similarity estimations of alcanzar completed
#
# Similarity estimations of alcayaga completed
#
# Similarity estimations of alcista completed
#
# Similarity estimations of alcohólica completed
#
# Similarity estimations of aldf completed
#
# Similarity estimations of alegar completed
#
# Similarity estimations of alegre completed
#
# Similarity estimations of alejandro completed
#
# Similarity estimations of alejar completed
#
# Similarity estimations of alemania completed
#
# Similarity estimations of alemanista completed
#
# Similarity estimations of alemán completed
#
# Similarity estimations of alentador completed
#
# Similarity estimations of alerta completed
#
# Similarity estimations of alertar completed
#
# Similarity estimations of alfa completed
#
# Similarity estimations of alfaro completed
#
# Similarity estimations of alfonso completed
#
# Similarity estimations of alfredo completed
#
# Similarity estimations of alférez completed
#
# Similarity estimations of alguien completed
#
# Similarity estimations of alguna completed
#
# Similarity estimations of alguno completed
#
# Similarity estimations of algún completed
#
# Similarity estimations of aliado completed
#
# Similarity estimations of alianza completed
#
# Similarity estimations of alice completed
#
# Similarity estimations of alimentación completed
#
# Similarity estimations of alimentario completed
#
# Similarity estimations of alimenticio completed
#
# Similarity estimations of alimento completed
#
# Similarity estimations of allegada completed
#
# Similarity estimations of allende completed
#
# Similarity estimations of alliance completed
#
# Similarity estimations of allora completed
#
# Similarity estimations of allá completed
#
# Similarity estimations of allí completed
#
# Similarity estimations of almacenar completed
#
# Similarity estimations of almoloya completed
#
# Similarity estimations of alonso completed
#
# Similarity estimations of alpha completed
#
# Similarity estimations of alponte completed
#
# Similarity estimations of alpro completed
#
# Similarity estimations of alrededor completed
#
# Similarity estimations of alta completed
#
# Similarity estimations of altamirano completed
#
# Similarity estimations of altar completed
#
# Similarity estimations of altarcito completed
#
# Similarity estimations of alteración completed
#
# Similarity estimations of alterar completed
#
# Similarity estimations of alternar completed
#
# Similarity estimations of altibajos completed
#
# Similarity estimations of alto completed
#
# Similarity estimations of altoparlante completed
#
# Similarity estimations of altura completed
#
# Similarity estimations of altísimo completed
#
# Similarity estimations of alumno completed
#
# Similarity estimations of alvarado completed
#
# Similarity estimations of alvarez completed
#
# Similarity estimations of alvaro completed
#
# Similarity estimations of alza completed
#
# Similarity estimations of alzamiento completed
#
# Similarity estimations of amador completed
#
# Similarity estimations of amargo completed
#
# Similarity estimations of amarra completed
#
# Similarity estimations of amañar completed
#
# Similarity estimations of ambas completed
#
# Similarity estimations of ambicioso completed
#
# Similarity estimations of ambiente completed
#
# Similarity estimations of ambos completed
#
# Similarity estimations of amelia completed
#
# Similarity estimations of amenaza completed
#
# Similarity estimations of america completed
#
# Similarity estimations of americom completed
#
# Similarity estimations of amhym completed
#
# Similarity estimations of amib completed
#
# Similarity estimations of amiga completed
#
# Similarity estimations of amigo completed
#
# Similarity estimations of amor completed
#
# Similarity estimations of amortización completed
#
# Similarity estimations of amparo completed
#
# Similarity estimations of ampliamente completed
#
# Similarity estimations of ampliar completed
#
# Similarity estimations of amplio completed
#
# Similarity estimations of américa completed
#
# Similarity estimations of analista completed
#
# Similarity estimations of analizar completed
#
# Similarity estimations of analítico completed
#
# Similarity estimations of anarquía completed
#
# Similarity estimations of anciano completed
#
# Similarity estimations of andar completed
#
# Similarity estimations of andreessen completed
#
# Similarity estimations of andres completed
#
# Similarity estimations of andrés completed
#
# Similarity estimations of andrómeda completed
#
# Similarity estimations of ane completed
#
# Similarity estimations of anexo completed
#
# Similarity estimations of angel completed
#
# Similarity estimations of angeles completed
#
# Similarity estimations of angloamericanos completed
#
# Similarity estimations of angustia completed
#
# Similarity estimations of angustioso completed
# Similarity estimations of anhelar completed
#
# Similarity estimations of anillo completed
#
# Similarity estimations of aniversario completed
#
# Similarity estimations of anomalía completed
#
# Similarity estimations of anotar completed
#
# Similarity estimations of ansioso completed
#
# Similarity estimations of antagónico completed
#
# Similarity estimations of antaño completed
#
# Similarity estimations of antecesor completed
#
# Similarity estimations of antelmo completed
#
# Similarity estimations of anteproyecto completed
#
# Similarity estimations of anterior completed
#
# Similarity estimations of anteriormente completed
#
# Similarity estimations of anticipación completed
#
# Similarity estimations of anticipar completed
#
# Similarity estimations of anticonstitucionales completed
#
# Similarity estimations of antiguo completed
#
# Similarity estimations of antigüita completed
#
# Similarity estimations of antimigratoria completed
#
# Similarity estimations of antipatía completed
#
# Similarity estimations of antonio completed
#
# Similarity estimations of antorcha completed
#
# Similarity estimations of antuna completed
#
# Similarity estimations of anual completed
#
# Similarity estimations of anuencia completed
#
# Similarity estimations of anular completed
#
# Similarity estimations of anunciar completed
#
# Similarity estimations of anuncio completed
#
# Similarity estimations of anáhuac completed
#
# Similarity estimations of análisis completed
#
# Similarity estimations of apacible completed
#
# Similarity estimations of apaciguar completed
#
# Similarity estimations of apapacho completed
#
# Similarity estimations of aparato completed
#
# Similarity estimations of aparecer completed
#
# Similarity estimations of aparentemente completed
#
# Similarity estimations of aparición completed
#
# Similarity estimations of apartado completed
#
# Similarity estimations of apartar completed
#
# Similarity estimations of aparte completed
#
# Similarity estimations of apegar completed
#
# Similarity estimations of apego completed
#
# Similarity estimations of apelación completed
#
# Similarity estimations of apenas completed
#
# Similarity estimations of apertura completed
#
# Similarity estimations of aplicable completed
#
# Similarity estimations of aplicación completed
#
# Similarity estimations of aplicado completed
#
# Similarity estimations of aplicar completed
#
# Similarity estimations of apoderado completed
#
# Similarity estimations of apoderamientos completed
#
# Similarity estimations of apoderar completed
#
# Similarity estimations of aporrear completed
#
# Similarity estimations of aportar completed
#
# Similarity estimations of apostar completed
#
# Similarity estimations of apoteótica completed
#
# Similarity estimations of apoyar completed
#
# Similarity estimations of apoyo completed
#
# Similarity estimations of apple completed
#
# Similarity estimations of applets completed
#
# Similarity estimations of apreciación completed
#
# Similarity estimations of apreciar completed
#
# Similarity estimations of aprehensión completed
#
# Similarity estimations of aprender completed
#
# Similarity estimations of apresar completed
#
# Similarity estimations of apresta completed
#
# Similarity estimations of apresurar completed
#
# Similarity estimations of aprobación completed
#
# Similarity estimations of aprobar completed
#
# Similarity estimations of apropiado completed
#
# Similarity estimations of aprovechada completed
#
# Similarity estimations of aprovechamiento completed
#
# Similarity estimations of aprovechar completed
#
# Similarity estimations of aproximadamente completed
#
# Similarity estimations of aproximado completed
#
# Similarity estimations of aptitud completed
#
# Similarity estimations of apuntar completed
#
# Similarity estimations of aquejar completed
#
# Similarity estimations of aquel completed
#
# Similarity estimations of aquella completed
#
# Similarity estimations of aquello completed
#
# Similarity estimations of aquellos completed
#
# Similarity estimations of aquél completed
#
# Similarity estimations of aquí completed
#
# Similarity estimations of ara completed
#
# Similarity estimations of aragón completed
#
# Similarity estimations of arancel completed
#
# Similarity estimations of arbitral completed
#
# Similarity estimations of arbitrario completed
#
# Similarity estimations of arca completed
#
# Similarity estimations of archivo completed
#
# Similarity estimations of arco completed
#
# Similarity estimations of arder completed
#
# Similarity estimations of ardid completed
#
# Similarity estimations of arena completed
#
# Similarity estimations of argentina completed
#
# Similarity estimations of argumentar completed
#
# Similarity estimations of argumento completed
#
# Similarity estimations of aria completed
#
# Similarity estimations of arizmendi completed
#
# Similarity estimations of arma completed
#
# Similarity estimations of armada completed
#
# Similarity estimations of armado completed
#
# Similarity estimations of armando completed
#
# Similarity estimations of armonía completed
#
# Similarity estimations of armónicamente completed
#
# Similarity estimations of armónico completed
#
# Similarity estimations of arnault completed
#
# Similarity estimations of arqueológico completed
#
# Similarity estimations of arquitecto completed
#
# Similarity estimations of arquitectura completed
#
# Similarity estimations of arrancar completed
#
# Similarity estimations of arrastrar completed
#
# Similarity estimations of arreglo completed
#
# Similarity estimations of arrendadora completed
#
# Similarity estimations of arreola completed
#
# Similarity estimations of arresto completed
#
# Similarity estimations of arriba completed
#
# Similarity estimations of arribar completed
#
# Similarity estimations of arribo completed
#
# Similarity estimations of arrobaexcelsiorcommx completed
#
# Similarity estimations of arrojar completed
#
# Similarity estimations of arropar completed
#
# Similarity estimations of arroyo completed
#
# Similarity estimations of arte completed
#
# Similarity estimations of artificial completed
#
# Similarity estimations of artimaña completed
#
# Similarity estimations of artista completed
#
# Similarity estimations of arturo completed
#
# Similarity estimations of artículo completed
#
# Similarity estimations of arvizu completed
#
# Similarity estimations of arzobispo completed
#
# Similarity estimations of arzú completed
#
# Similarity estimations of asa completed
#
# Similarity estimations of asalariada completed
#
# Similarity estimations of asalariado completed
#
# Similarity estimations of asaltante completed
#
# Similarity estimations of asamblea completed
#
# Similarity estimations of asambleísta completed
#
# Similarity estimations of asambleístas completed
#
# Similarity estimations of ascender completed
#
# Similarity estimations of ascensión completed
#
# Similarity estimations of ascenso completed
#
# Similarity estimations of asegurar completed
#
# Similarity estimations of asentar completed
#
# Similarity estimations of asentir completed
#
# Similarity estimations of asequible completed
#
# Similarity estimations of asesinar completed
#
# Similarity estimations of asesinato completed
#
# Similarity estimations of asesino completed
#
# Similarity estimations of asesorar completed
#
# Similarity estimations of asesoría completed
# Similarity estimations of aseverar completed
#
# Similarity estimations of asfixia completed
#
# Similarity estimations of asfixiar completed
#
# Similarity estimations of asignación completed
#
# Similarity estimations of asignar completed
#
# Similarity estimations of asimilar completed
#
# Similarity estimations of asimismo completed
#
# Similarity estimations of asir completed
#
# Similarity estimations of asistencia completed
#
# Similarity estimations of asistencial completed
#
# Similarity estimations of asistente completed
#
# Similarity estimations of asistir completed
#
# Similarity estimations of asociación completed
#
# Similarity estimations of asociar completed
#
# Similarity estimations of aspecto completed
#
# Similarity estimations of aspiración completed
#
# Similarity estimations of aspirar completed
#
# Similarity estimations of astronauta completed
#
# Similarity estimations of astroso completed
#
# Similarity estimations of astucia completed
#
# Similarity estimations of asueto completed
#
# Similarity estimations of asumir completed
#
# Similarity estimations of asunto completed
#
# Similarity estimations of atacar completed
#
# Similarity estimations of atajar completed
#
# Similarity estimations of atar completed
#
# Similarity estimations of atención completed
#
# Similarity estimations of atender completed
#
# Similarity estimations of atentamente completed
#
# Similarity estimations of atentar completed
#
# Similarity estimations of aterrizaje completed
#
# Similarity estimations of aterrizar completed
#
# Similarity estimations of atinadamente completed
#
# Similarity estimations of atinado completed
#
# Similarity estimations of atisbar completed
#
# Similarity estimations of atlantis completed
#
# Similarity estimations of atoyac completed
#
# Similarity estimations of atracar completed
#
# Similarity estimations of atractivo completed
#
# Similarity estimations of atraer completed
#
# Similarity estimations of atraso completed
#
# Similarity estimations of atravesar completed
#
# Similarity estimations of através completed
#
# Similarity estimations of atribución completed
#
# Similarity estimations of audio completed
#
# Similarity estimations of auditar completed
#
# Similarity estimations of auditoria completed
#
# Similarity estimations of auditorias completed
#
# Similarity estimations of auditorio completed
#
# Similarity estimations of auditoría completed
#
# Similarity estimations of augusta completed
#
# Similarity estimations of aumentar completed
#
# Similarity estimations of aumento completed
#
# Similarity estimations of aun completed
#
# Similarity estimations of aunque completed
#
# Similarity estimations of auque completed
#
# Similarity estimations of aurora completed
#
# Similarity estimations of ausentismo completed
#
# Similarity estimations of auspiciar completed
#
# Similarity estimations of australia completed
#
# Similarity estimations of austria completed
#
# Similarity estimations of auto completed
#
# Similarity estimations of autobús completed
#
# Similarity estimations of autoconsumo completed
#
# Similarity estimations of autoinvasiones completed
#
# Similarity estimations of automática completed
#
# Similarity estimations of automáticamente completed
#
# Similarity estimations of automático completed
#
# Similarity estimations of automóvil completed
#
# Similarity estimations of autonomía completed
#
# Similarity estimations of autopista completed
#
# Similarity estimations of autor completed
#
# Similarity estimations of autoridad completed
#
# Similarity estimations of autoritarismo completed
#
# Similarity estimations of autorizar completed
#
# Similarity estimations of autotransporte completed
#
# Similarity estimations of autotransportes completed
#
# Similarity estimations of autrey completed
#
# Similarity estimations of auténtica completed
#
# Similarity estimations of auténtico completed
#
# Similarity estimations of autónomo completed
#
# Similarity estimations of auxiliar completed
#
# Similarity estimations of auxilio completed
#
# Similarity estimations of av completed
#
# Similarity estimations of avalúos completed
#
# Similarity estimations of avance completed
#
# Similarity estimations of avanzar completed
#
# Similarity estimations of avecinan completed
#
# Similarity estimations of avelar completed
#
# Similarity estimations of avenida completed
#
# Similarity estimations of averiguaciones completed
#
# Similarity estimations of averiguar completed
#
# Similarity estimations of aversión completed
#
# Similarity estimations of avila completed
#
# Similarity estimations of avisar completed
#
# Similarity estimations of aviso completed
#
# Similarity estimations of avión completed
#
# Similarity estimations of ayala completed
#
# Similarity estimations of ayer completed
#
# Similarity estimations of ayuda completed
#
# Similarity estimations of ayudar completed
#
# Similarity estimations of ayuno completed
#
# Similarity estimations of azcapotzalco completed
#
# Similarity estimations of azteca completed
#
# Similarity estimations of azul completed
#
# Similarity estimations of azúcar completed
#
# Similarity estimations of aéreo completed
#
# Similarity estimations of añadir completed
#
# Similarity estimations of año completed
#
# Similarity estimations of aún completed
#
# Similarity estimations of bache completed
#
# Similarity estimations of bah completed
#
# Similarity estimations of baile completed
#
# Similarity estimations of baja completed
#
# Similarity estimations of bajar completed
#
# Similarity estimations of bajo completed
#
# Similarity estimations of balance completed
#
# Similarity estimations of balanza completed
#
# Similarity estimations of baldenegro completed
#
# Similarity estimations of balneario completed
#
# Similarity estimations of balón completed
#
# Similarity estimations of banamex completed
#
# Similarity estimations of banc completed
#
# Similarity estimations of banca completed
#
# Similarity estimations of bancario completed
#
# Similarity estimations of bancarrota completed
#
# Similarity estimations of banco completed
#
# Similarity estimations of bancomer completed
#
# Similarity estimations of bandera completed
#
# Similarity estimations of bandido completed
#
# Similarity estimations of bando completed
#
# Similarity estimations of banjidal completed
#
# Similarity estimations of banobras completed
#
# Similarity estimations of banquero completed
#
# Similarity estimations of banqueta completed
#
# Similarity estimations of banrural completed
#
# Similarity estimations of banxico completed
#
# Similarity estimations of baranda completed
#
# Similarity estimations of barato completed
#
# Similarity estimations of barba completed
#
# Similarity estimations of barca completed
#
# Similarity estimations of barco completed
#
# Similarity estimations of barra completed
#
# Similarity estimations of barragán completed
#
# Similarity estimations of barreda completed
#
# Similarity estimations of barrio completed
#
# Similarity estimations of bartola completed
#
# Similarity estimations of basar completed
#
# Similarity estimations of base completed
#
# Similarity estimations of bastante completed
#
# Similarity estimations of bastar completed
#
# Similarity estimations of basura completed
#
# Similarity estimations of baño completed
#
# Similarity estimations of bdem completed
# Similarity estimations of beach completed
#
# Similarity estimations of bebida completed
#
# Similarity estimations of beca completed
#
# Similarity estimations of becerril completed
#
# Similarity estimations of bell completed
#
# Similarity estimations of beltrones completed
#
# Similarity estimations of belén completed
#
# Similarity estimations of bendecir completed
#
# Similarity estimations of bendición completed
#
# Similarity estimations of beneficiar completed
#
# Similarity estimations of beneficiario completed
#
# Similarity estimations of beneficios completed
#
# Similarity estimations of benito completed
#
# Similarity estimations of benévolo completed
#
# Similarity estimations of berdejo completed
#
# Similarity estimations of bernal completed
#
# Similarity estimations of besar completed
#
# Similarity estimations of bezanilla completed
#
# Similarity estimations of bianual completed
#
# Similarity estimations of bicicleta completed
#
# Similarity estimations of bien completed
#
# Similarity estimations of bienestar completed
#
# Similarity estimations of bienintencionado completed
#
# Similarity estimations of bienvenidos completed
#
# Similarity estimations of bill completed
#
# Similarity estimations of billete completed
#
# Similarity estimations of bimestre completed
#
# Similarity estimations of biofísicos completed
#
# Similarity estimations of biológico completed
#
# Similarity estimations of bla completed
#
# Similarity estimations of blaha completed
#
# Similarity estimations of blanca completed
#
# Similarity estimations of blanco completed
#
# Similarity estimations of blando completed
#
# Similarity estimations of blanquiazul completed
#
# Similarity estimations of blemas completed
#
# Similarity estimations of bloquear completed
#
# Similarity estimations of bmv completed
#
# Similarity estimations of bobo completed
#
# Similarity estimations of boca completed
#
# Similarity estimations of bodrios completed
#
# Similarity estimations of boeing completed
#
# Similarity estimations of bolita completed
#
# Similarity estimations of bolsa completed
#
# Similarity estimations of bolseros completed
#
# Similarity estimations of bombardear completed
#
# Similarity estimations of bonhomía completed
#
# Similarity estimations of bonos completed
#
# Similarity estimations of boom completed
#
# Similarity estimations of borde completed
#
# Similarity estimations of bordo completed
#
# Similarity estimations of borghese completed
#
# Similarity estimations of borja completed
#
# Similarity estimations of borrego completed
#
# Similarity estimations of bosque completed
#
# Similarity estimations of botín completed
#
# Similarity estimations of bours completed
#
# Similarity estimations of brasil completed
#
# Similarity estimations of braun completed
#
# Similarity estimations of brecha completed
#
# Similarity estimations of bretaña completed
#
# Similarity estimations of brete completed
#
# Similarity estimations of breve completed
#
# Similarity estimations of breves completed
#
# Similarity estimations of brindar completed
#
# Similarity estimations of brito completed
#
# Similarity estimations of británica completed
#
# Similarity estimations of brote completed
#
# Similarity estimations of brusco completed
#
# Similarity estimations of brutal completed
#
# Similarity estimations of bruto completed
#
# Similarity estimations of buena completed
#
# Similarity estimations of bueno completed
#
# Similarity estimations of bulevar completed
#
# Similarity estimations of burla completed
#
# Similarity estimations of burlar completed
#
# Similarity estimations of bursátil completed
#
# Similarity estimations of busca completed
#
# Similarity estimations of buscar completed
#
# Similarity estimations of butírica completed
#
# Similarity estimations of buzonsímbolo completed
#
# Similarity estimations of básicamente completed
#
# Similarity estimations of básico completed
#
# Similarity estimations of búfalo completed
#
# Similarity estimations of búho completed
#
# Similarity estimations of búsqueda completed
#
# Similarity estimations of cabal completed
#
# Similarity estimations of caballero completed
#
# Similarity estimations of caballeroso completed
#
# Similarity estimations of cabalmente completed
#
# Similarity estimations of caber completed
#
# Similarity estimations of cabeza completed
#
# Similarity estimations of cabezal completed
#
# Similarity estimations of cabida completed
#
# Similarity estimations of cabildo completed
#
# Similarity estimations of cabina completed
#
# Similarity estimations of cabo completed
#
# Similarity estimations of cabrera completed
#
# Similarity estimations of cada completed
#
# Similarity estimations of cadena completed
#
# Similarity estimations of caer completed
#
# Similarity estimations of café completed
#
# Similarity estimations of caifás completed
#
# Similarity estimations of cairo completed
#
# Similarity estimations of caj completed
#
# Similarity estimations of cajb completed
#
# Similarity estimations of cajero completed
#
# Similarity estimations of calabozo completed
#
# Similarity estimations of calado completed
#
# Similarity estimations of calcular completed
#
# Similarity estimations of caldaria completed
#
# Similarity estimations of caldera completed
#
# Similarity estimations of calderón completed
#
# Similarity estimations of calidad completed
#
# Similarity estimations of calificación completed
#
# Similarity estimations of calificar completed
#
# Similarity estimations of california completed
#
# Similarity estimations of californianas completed
#
# Similarity estimations of calle completed
#
# Similarity estimations of callejón completed
#
# Similarity estimations of calley completed
#
# Similarity estimations of callista completed
#
# Similarity estimations of calor completed
#
# Similarity estimations of calumnia completed
#
# Similarity estimations of cama completed
#
# Similarity estimations of camacho completed
#
# Similarity estimations of cambiar completed
#
# Similarity estimations of cambiaria completed
#
# Similarity estimations of cambiario completed
#
# Similarity estimations of cambio completed
#
# Similarity estimations of caminar completed
#
# Similarity estimations of camino completed
#
# Similarity estimations of camioneras completed
#
# Similarity estimations of camioneta completed
#
# Similarity estimations of campa completed
#
# Similarity estimations of campamento completed
#
# Similarity estimations of campaña completed
#
# Similarity estimations of campesina completed
#
# Similarity estimations of campesinado completed
#
# Similarity estimations of campesino completed
#
# Similarity estimations of campestre completed
#
# Similarity estimations of campion completed
#
# Similarity estimations of campo completed
#
# Similarity estimations of canacintra completed
#
# Similarity estimations of canaco completed
#
# Similarity estimations of canadiense completed
#
# Similarity estimations of canadá completed
#
# Similarity estimations of canal completed
#
# Similarity estimations of canalizar completed
#
# Similarity estimations of cancelar completed
#
# Similarity estimations of cancino completed
#
# Similarity estimations of cancún completed
#
# Similarity estimations of candado completed
#
# Similarity estimations of candidato completed
#
# Similarity estimations of candidatura completed
# Similarity estimations of cano completed
#
# Similarity estimations of cansancio completed
#
# Similarity estimations of cantar completed
#
# Similarity estimations of cantidad completed
#
# Similarity estimations of cantinflas completed
#
# Similarity estimations of canto completed
#
# Similarity estimations of capacidad completed
#
# Similarity estimations of capacitación completed
#
# Similarity estimations of capital completed
#
# Similarity estimations of capitalino completed
#
# Similarity estimations of capitalismo completed
#
# Similarity estimations of capitalización completed
#
# Similarity estimations of capitalizar completed
#
# Similarity estimations of capricho completed
#
# Similarity estimations of captación completed
#
# Similarity estimations of captar completed
#
# Similarity estimations of cara completed
#
# Similarity estimations of caracterizado completed
#
# Similarity estimations of caracterizar completed
#
# Similarity estimations of característica completed
#
# Similarity estimations of carantoña completed
#
# Similarity estimations of cardenismo completed
#
# Similarity estimations of cardenista completed
#
# Similarity estimations of cardiaca completed
#
# Similarity estimations of cardiología completed
#
# Similarity estimations of cardona completed
#
# Similarity estimations of carecer completed
#
# Similarity estimations of carencia completed
#
# Similarity estimations of carga completed
#
# Similarity estimations of cargar completed
#
# Similarity estimations of cargo completed
#
# Similarity estimations of caribe completed
#
# Similarity estimations of carlos completed
#
# Similarity estimations of carne completed
#
# Similarity estimations of caro completed
#
# Similarity estimations of carpio completed
#
# Similarity estimations of carranza completed
#
# Similarity estimations of carrera completed
#
# Similarity estimations of carretera completed
#
# Similarity estimations of carretero completed
#
# Similarity estimations of carruseles completed
#
# Similarity estimations of carso completed
#
# Similarity estimations of carta completed
#
# Similarity estimations of cartera completed
#
# Similarity estimations of cartulina completed
#
# Similarity estimations of carácter completed
#
# Similarity estimations of casa completed
#
# Similarity estimations of casanova completed
#
# Similarity estimations of casar completed
#
# Similarity estimations of casi completed
#
# Similarity estimations of casilla completed
#
# Similarity estimations of caso completed
#
# Similarity estimations of castellano completed
#
# Similarity estimations of castigar completed
#
# Similarity estimations of castigo completed
#
# Similarity estimations of castillo completed
#
# Similarity estimations of catalizador completed
#
# Similarity estimations of catar completed
#
# Similarity estimations of catastrófico completed
#
# Similarity estimations of catorcena completed
#
# Similarity estimations of catálogo completed
#
# Similarity estimations of catástrofe completed
#
# Similarity estimations of católica completed
#
# Similarity estimations of católico completed
#
# Similarity estimations of cauce completed
#
# Similarity estimations of caudillesca completed
#
# Similarity estimations of caudillo completed
#
# Similarity estimations of causa completed
#
# Similarity estimations of causante completed
#
# Similarity estimations of causar completed
#
# Similarity estimations of cautivo completed
#
# Similarity estimations of caída completed
#
# Similarity estimations of caído completed
#
# Similarity estimations of cañaveral completed
#
# Similarity estimations of cañedo completed
#
# Similarity estimations of caótico completed
#
# Similarity estimations of cce completed
#
# Similarity estimations of cdiez completed
#
# Similarity estimations of cdrom completed
#
# Similarity estimations of ceder completed
#
# Similarity estimations of ceesp completed
#
# Similarity estimations of celebración completed
#
# Similarity estimations of celebrar completed
#
# Similarity estimations of cemex completed
#
# Similarity estimations of cen completed
#
# Similarity estimations of cena completed
#
# Similarity estimations of ceniza completed
#
# Similarity estimations of censura completed
#
# Similarity estimations of censurar completed
#
# Similarity estimations of centavo completed
#
# Similarity estimations of centenar completed
#
# Similarity estimations of central completed
#
# Similarity estimations of centro completed
#
# Similarity estimations of centroamericana completed
#
# Similarity estimations of ceoic completed
#
# Similarity estimations of cepal completed
#
# Similarity estimations of cerca completed
#
# Similarity estimations of cercano completed
#
# Similarity estimations of cercanía completed
#
# Similarity estimations of cerda completed
#
# Similarity estimations of cerdo completed
#
# Similarity estimations of ceremonia completed
#
# Similarity estimations of ceremonial completed
#
# Similarity estimations of cero completed
#
# Similarity estimations of cerrado completed
#
# Similarity estimations of cerrar completed
#
# Similarity estimations of certidumbre completed
#
# Similarity estimations of certificación completed
#
# Similarity estimations of cesarman completed
#
# Similarity estimations of cese completed
#
# Similarity estimations of cete completed
#
# Similarity estimations of cfe completed
#
# Similarity estimations of chabacano completed
#
# Similarity estimations of chacona completed
#
# Similarity estimations of chapa completed
#
# Similarity estimations of chapopote completed
#
# Similarity estimations of chargoy completed
#
# Similarity estimations of charros completed
#
# Similarity estimations of charter completed
#
# Similarity estimations of charters completed
#
# Similarity estimations of cheque completed
#
# Similarity estimations of chiapaneca completed
#
# Similarity estimations of chiapaneco completed
#
# Similarity estimations of chiapas completed
#
# Similarity estimations of chico completed
#
# Similarity estimations of chicomuselo completed
#
# Similarity estimations of chile completed
#
# Similarity estimations of chilton completed
#
# Similarity estimations of china completed
#
# Similarity estimations of chino completed
#
# Similarity estimations of chirinos completed
#
# Similarity estimations of chis completed
#
# Similarity estimations of chiste completed
#
# Similarity estimations of chivo completed
#
# Similarity estimations of chocante completed
#
# Similarity estimations of chofer completed
#
# Similarity estimations of choque completed
#
# Similarity estimations of chovinismo completed
#
# Similarity estimations of churubuscoal completed
#
# Similarity estimations of chávez completed
#
# Similarity estimations of chéquelo completed
#
# Similarity estimations of ciberespacio completed
#
# Similarity estimations of ciberlectores completed
#
# Similarity estimations of ciclo completed
#
# Similarity estimations of cien completed
#
# Similarity estimations of ciencia completed
#
# Similarity estimations of cienfuegos completed
#
# Similarity estimations of ciento completed
#
# Similarity estimations of científica completed
#
# Similarity estimations of científico completed
#
# Similarity estimations of cierne completed
#
# Similarity estimations of cierre completed
#
# Similarity estimations of ciertamente completed
#
# Similarity estimations of cierto completed
# Similarity estimations of cifra completed
#
# Similarity estimations of cifrián completed
#
# Similarity estimations of cihmech completed
#
# Similarity estimations of cima completed
#
# Similarity estimations of cimentaciones completed
#
# Similarity estimations of cimentar completed
#
# Similarity estimations of cimiento completed
#
# Similarity estimations of cinco completed
#
# Similarity estimations of cine completed
#
# Similarity estimations of cinematografistas completed
#
# Similarity estimations of cinematográfico completed
#
# Similarity estimations of cinescopios completed
#
# Similarity estimations of cinturón completed
#
# Similarity estimations of cioac completed
#
# Similarity estimations of circuito completed
#
# Similarity estimations of circulación completed
#
# Similarity estimations of circulante completed
#
# Similarity estimations of circular completed
#
# Similarity estimations of circunstancia completed
#
# Similarity estimations of cirugía completed
#
# Similarity estimations of cita completed
#
# Similarity estimations of citadino completed
#
# Similarity estimations of citar completed
#
# Similarity estimations of citroen completed
#
# Similarity estimations of ciudad completed
#
# Similarity estimations of ciudadano completed
#
# Similarity estimations of civil completed
#
# Similarity estimations of civilizado completed
#
# Similarity estimations of clandestino completed
#
# Similarity estimations of clara completed
#
# Similarity estimations of claramente completed
#
# Similarity estimations of claremont completed
#
# Similarity estimations of clark completed
#
# Similarity estimations of claro completed
#
# Similarity estimations of claroscuro completed
#
# Similarity estimations of clase completed
#
# Similarity estimations of clasificación completed
#
# Similarity estimations of clave completed
#
# Similarity estimations of clavícula completed
#
# Similarity estimations of clemencia completed
#
# Similarity estimations of clero completed
#
# Similarity estimations of cliente completed
#
# Similarity estimations of clienteservidor completed
#
# Similarity estimations of clifford completed
#
# Similarity estimations of clima completed
#
# Similarity estimations of clásico completed
#
# Similarity estimations of cláusula completed
#
# Similarity estimations of clérigo completed
#
# Similarity estimations of cna completed
#
# Similarity estimations of cnbv completed
#
# Similarity estimations of cnc completed
#
# Similarity estimations of cniv completed
#
# Similarity estimations of cnpi completed
#
# Similarity estimations of co completed
#
# Similarity estimations of coalcomán completed
#
# Similarity estimations of coalición completed
#
# Similarity estimations of cobarde completed
#
# Similarity estimations of cobertura completed
#
# Similarity estimations of cobrar completed
#
# Similarity estimations of cocoyoc completed
#
# Similarity estimations of coexistir completed
#
# Similarity estimations of coger completed
#
# Similarity estimations of coicidieron completed
#
# Similarity estimations of coincidente completed
#
# Similarity estimations of coincidir completed
#
# Similarity estimations of col completed
#
# Similarity estimations of colaborar completed
#
# Similarity estimations of colbeth completed
#
# Similarity estimations of colchón completed
#
# Similarity estimations of coleccionar completed
#
# Similarity estimations of colección completed
#
# Similarity estimations of colectivo completed
#
# Similarity estimations of colega completed
#
# Similarity estimations of colegiado completed
#
# Similarity estimations of colegiatura completed
#
# Similarity estimations of colgado completed
#
# Similarity estimations of colgar completed
#
# Similarity estimations of college completed
#
# Similarity estimations of colmo completed
#
# Similarity estimations of colocar completed
#
# Similarity estimations of colombia completed
#
# Similarity estimations of colombiano completed
#
# Similarity estimations of colonia completed
#
# Similarity estimations of colonial completed
#
# Similarity estimations of colonización completed
#
# Similarity estimations of color completed
#
# Similarity estimations of colorido completed
#
# Similarity estimations of colosio completed
#
# Similarity estimations of colosismo completed
#
# Similarity estimations of colosista completed
#
# Similarity estimations of colosistas completed
#
# Similarity estimations of columna completed
#
# Similarity estimations of comandado completed
#
# Similarity estimations of comandante completed
#
# Similarity estimations of comando completed
#
# Similarity estimations of combate completed
#
# Similarity estimations of combatiente completed
#
# Similarity estimations of combatir completed
#
# Similarity estimations of combatividad completed
#
# Similarity estimations of combinación completed
#
# Similarity estimations of combinado completed
#
# Similarity estimations of combustible completed
#
# Similarity estimations of comentar completed
#
# Similarity estimations of comentario completed
#
# Similarity estimations of comenzar completed
#
# Similarity estimations of comer completed
#
# Similarity estimations of comercial completed
#
# Similarity estimations of comercialización completed
#
# Similarity estimations of comercializar completed
#
# Similarity estimations of comercio completed
#
# Similarity estimations of cometer completed
#
# Similarity estimations of cometido completed
#
# Similarity estimations of comisionado completed
#
# Similarity estimations of comisionar completed
#
# Similarity estimations of comisión completed
#
# Similarity estimations of comité completed
#
# Similarity estimations of compactaciones completed
#
# Similarity estimations of compacto completed
#
# Similarity estimations of companías completed
#
# Similarity estimations of compaq completed
#
# Similarity estimations of comparación completed
#
# Similarity estimations of comparar completed
#
# Similarity estimations of comparecencias completed
#
# Similarity estimations of compareciente completed
#
# Similarity estimations of compartir completed
#
# Similarity estimations of compasión completed
#
# Similarity estimations of compatible completed
#
# ...
#
# Similarity estimations of tranquilo completed
#
# Similarity estimations of transacción completed
#
# Similarity estimations of transbordador completed
#
# Similarity estimations of transcripción completed
#
# Similarity estimations of transformación completed
#
# Similarity estimations of transformar completed
#
# Similarity estimations of transmisión completed
#
# Similarity estimations of transmitir completed
#
# Similarity estimations of transparente completed
#
# Similarity estimations of transporte completed
#
# Similarity estimations of tras completed
#
# Similarity estimations of trascendente completed
#
# Similarity estimations of trasferencia completed
#
# Similarity estimations of trasladar completed
#
# Similarity estimations of traslado completed
#
# Similarity estimations of trasnferencia completed
#
# Similarity estimations of traspasar completed
#
# Similarity estimations of trastocar completed
#
# Similarity estimations of trata completed
#
# Similarity estimations of tratado completed
#
# Similarity estimations of tratamiento completed
#
# Similarity estimations of tratar completed
#
# Similarity estimations of trato completed
#
# Similarity estimations of través completed
#
# Similarity estimations of trayectoria completed
#
# Similarity estimations of treinta completed
#
# Similarity estimations of trejo completed
#
# Similarity estimations of tremendo completed
#
# Similarity estimations of tren completed
#
# Similarity estimations of tres completed
#
# Similarity estimations of triada completed
#
# Similarity estimations of tribal completed
#
# Similarity estimations of tribuna completed
#
# Similarity estimations of tribunal completed
#
# Similarity estimations of trilogía completed
#
# Similarity estimations of trimestre completed
#
# Similarity estimations of tripulación completed
#
# Similarity estimations of triste completed
#
# Similarity estimations of triunfal completed
#
# Similarity estimations of triunfante completed
#
# Similarity estimations of triunfar completed
#
# Similarity estimations of triunfo completed
#
# Similarity estimations of tronar completed
#
# Similarity estimations of tropa completed
#
# Similarity estimations of tropel completed
#
# Similarity estimations of truncado completed
#
# Similarity estimations of trámite completed
#
# Similarity estimations of tránsito completed
#
# Similarity estimations of tula completed
#
# Similarity estimations of tumbalá completed
#
# Similarity estimations of turbiedad completed
#
# Similarity estimations of turismo completed
#
# Similarity estimations of turista completed
#
# Similarity estimations of tutor completed
#
# Similarity estimations of tutto completed
#
# Similarity estimations of técnica completed
#
# Similarity estimations of técnico completed
#
# Similarity estimations of término completed
#
# Similarity estimations of tímido completed
#
# Similarity estimations of tío completed
#
# Similarity estimations of títere completed
#
# Similarity estimations of título completed
#
# Similarity estimations of tónica completed
#
# Similarity estimations of tótem completed
#
# Similarity estimations of u completed
#
# Similarity estimations of uanl completed
#
# Similarity estimations of ubicar completed
#
# Similarity estimations of ubre completed
#
# Similarity estimations of uc completed
#
# Similarity estimations of ucabe completed
#
# Similarity estimations of udi completed
#
# Similarity estimations of udis completed
# Similarity estimations of udla completed
#
# Similarity estimations of ugocp completed
#
# Similarity estimations of ulloa completed
#
# Similarity estimations of ultimar completed
#
# Similarity estimations of ultrapasteurizada completed
#
# Similarity estimations of un completed
#
# Similarity estimations of unam completed
#
# Similarity estimations of unaágina completed
#
# Similarity estimations of unicamente completed
#
# Similarity estimations of unico completed
#
# Similarity estimations of unidad completed
#
# Similarity estimations of unido completed
#
# Similarity estimations of uniformidad completed
#
# Similarity estimations of unir completed
#
# Similarity estimations of unitario completed
#
# Similarity estimations of universal completed
#
# Similarity estimations of universidad completed
#
# Similarity estimations of universo completed
#
# Similarity estimations of unión completed
#
# Similarity estimations of unióncremi completed
#
# Similarity estimations of unocero completed
#
# Similarity estimations of unísono completed
#
# Similarity estimations of urbana completed
#
# Similarity estimations of urbano completed
#
# Similarity estimations of urbe completed
#
# Similarity estimations of urgencia completed
#
# Similarity estimations of urgente completed
#
# Similarity estimations of urgentemente completed
#
# Similarity estimations of urgir completed
#
# Similarity estimations of uribe completed
#
# Similarity estimations of urng completed
#
# Similarity estimations of us completed
#
# Similarity estimations of usado completed
#
# Similarity estimations of usar completed
#
# Similarity estimations of usdec completed
#
# Similarity estimations of uso completed
#
# Similarity estimations of ussachev completed
#
# Similarity estimations of usted completed
#
# Similarity estimations of ustedes completed
#
# Similarity estimations of usuario completed
#
# Similarity estimations of utilidad completed
#
# Similarity estimations of utilización completed
#
# Similarity estimations of utilizar completed
#
# Similarity estimations of utopía completed
#
# Similarity estimations of utópico completed
#
# Similarity estimations of vaca completed
#
# Similarity estimations of vacacional completed
#
# Similarity estimations of vacacionalúnico completed
#
# Similarity estimations of vacacionar completed
#
# Similarity estimations of vacacionistas completed
#
# Similarity estimations of vacación completed
#
# Similarity estimations of vacante completed
#
# Similarity estimations of vacío completed
#
# Similarity estimations of vado completed
#
# Similarity estimations of vaivén completed
#
# Similarity estimations of valderrama completed
#
# Similarity estimations of valdovinos completed
#
# Similarity estimations of valencia completed
#
# Similarity estimations of valenzuela completed
#
# Similarity estimations of valer completed
#
# Similarity estimations of valida completed
#
# Similarity estimations of validar completed
#
# Similarity estimations of validará completed
#
# Similarity estimations of validarán completed
#
# Similarity estimations of valioso completed
#
# Similarity estimations of valle completed
#
# Similarity estimations of valor completed
#
# Similarity estimations of valorar completed
#
# Similarity estimations of valuación completed
#
# Similarity estimations of vano completed
#
# Similarity estimations of variable completed
#
# Similarity estimations of variación completed
#
# Similarity estimations of variante completed
#
# Similarity estimations of variar completed
#
# Similarity estimations of varias completed
#
# Similarity estimations of variedad completed
#
# Similarity estimations of varios completed
#
# Similarity estimations of vasconcelos completed
#
# Similarity estimations of vasquez completed
#
# Similarity estimations of vauchers completed
#
# Similarity estimations of vecinal completed
#
# Similarity estimations of vecino completed
#
# Similarity estimations of vega completed
#
# Similarity estimations of vegetal completed
#
# Similarity estimations of vehicular completed
#
# Similarity estimations of vehículo completed
#
# Similarity estimations of velada completed
#
# Similarity estimations of velasco completed
#
# Similarity estimations of velazco completed
#
# Similarity estimations of veleidad completed
#
# Similarity estimations of velocidad completed
#
# Similarity estimations of velorio completed
#
# Similarity estimations of velázquez completed
#
# Similarity estimations of vencer completed
#
# Similarity estimations of vencida completed
#
# Similarity estimations of vencimiento completed
#
# Similarity estimations of vencimientos completed
#
# Similarity estimations of vendedor completed
#
# Similarity estimations of vendedora completed
#
# Similarity estimations of vender completed
#
# Similarity estimations of venecia completed
#
# Similarity estimations of venegas completed
#
# Similarity estimations of venir completed
#
# Similarity estimations of venta completed
#
# Similarity estimations of ventura completed
#
# Similarity estimations of venustiano completed
#
# Similarity estimations of ver completed
#
# Similarity estimations of veracruz completed
#
# Similarity estimations of veracruzana completed
#
# Similarity estimations of veracruzano completed
#
# Similarity estimations of veracruzanos completed
#
# Similarity estimations of verano completed
#
# Similarity estimations of veras completed
#
# Similarity estimations of verbal completed
#
# Similarity estimations of verdad completed
#
# Similarity estimations of verdadero completed
#
# Similarity estimations of verde completed
#
# Similarity estimations of verdura completed
#
# Similarity estimations of veredicto completed
#
# Similarity estimations of vereoconferencias completed
#
# Similarity estimations of vergonzoso completed
#
# Similarity estimations of vergüenza completed
#
# Similarity estimations of verificación completed
#
# Similarity estimations of verificar completed
#
# Similarity estimations of veronica completed
#
# Similarity estimations of versar completed
#
# Similarity estimations of versión completed
#
# Similarity estimations of verso completed
#
# Similarity estimations of vertical completed
#
# Similarity estimations of vertiginoso completed
#
# Similarity estimations of verónica completed
#
# Similarity estimations of vestido completed
#
# Similarity estimations of vestidura completed
#
# Similarity estimations of vestir completed
#
# Similarity estimations of vez completed
#
# Similarity estimations of viabilidad completed
#
# Similarity estimations of viable completed
#
# Similarity estimations of viacrucis completed
#
# Similarity estimations of viajar completed
#
# Similarity estimations of viaje completed
#
# Similarity estimations of viajero completed
#
# Similarity estimations of vicente completed
#
# Similarity estimations of vicepresidente completed
#
# Similarity estimations of vicio completed
#
# Similarity estimations of victimario completed
#
# Similarity estimations of victoria completed
#
# Similarity estimations of vida completed
#
# Similarity estimations of videoconferencia completed
#
# Similarity estimations of videoconferencias completed
#
# Similarity estimations of videograbadoras completed
#
# Similarity estimations of vieja completed
#
# Similarity estimations of viejo completed
#
# Similarity estimations of viento completed
#
# Similarity estimations of viernes completed
#
# Similarity estimations of vietnam completed
# Similarity estimations of vietnamita completed
#
# Similarity estimations of vigencia completed
#
# Similarity estimations of vigente completed
#
# Similarity estimations of vigilancia completed
#
# Similarity estimations of vigilante completed
#
# Similarity estimations of vigilar completed
#
# Similarity estimations of vigoroso completed
#
# Similarity estimations of vii completed
#
# Similarity estimations of viii completed
#
# Similarity estimations of villa completed
#
# Similarity estimations of villafuerte completed
#
# Similarity estimations of villarreal completed
#
# Similarity estimations of villegas completed
#
# Similarity estimations of vilo completed
#
# Similarity estimations of vincular completed
#
# Similarity estimations of violación completed
#
# Similarity estimations of violar completed
#
# Similarity estimations of violencia completed
#
# Similarity estimations of violento completed
#
# Similarity estimations of virginia completed
#
# Similarity estimations of viril completed
#
# Similarity estimations of virtual completed
#
# Similarity estimations of virtualmente completed
#
# Similarity estimations of virtud completed
#
# Similarity estimations of virud completed
#
# Similarity estimations of visionario completed
#
# Similarity estimations of visita completed
#
# Similarity estimations of visitar completed
#
# Similarity estimations of visión completed
#
# Similarity estimations of vislumbrar completed
#
# Similarity estimations of vista completed
#
# Similarity estimations of visto completed
#
# Similarity estimations of vital completed
#
# Similarity estimations of vitrales completed
#
# Similarity estimations of vitro completed
#
# Similarity estimations of vituperio completed
#
# Similarity estimations of viuda completed
#
# Similarity estimations of viva completed
#
# Similarity estimations of vive completed
#
# Similarity estimations of viven completed
#
# Similarity estimations of vividor completed
#
# Similarity estimations of vivienda completed
#
# Similarity estimations of viviente completed
#
# Similarity estimations of viviento completed
#
# Similarity estimations of vivir completed
#
# Similarity estimations of vocación completed
#
# Similarity estimations of vocal completed
#
# Similarity estimations of vocero completed
#
# Similarity estimations of volante completed
#
# Similarity estimations of volatilidad completed
#
# Similarity estimations of volumen completed
#
# Similarity estimations of voluntad completed
#
# Similarity estimations of voluntario completed
#
# Similarity estimations of volver completed
#
# Similarity estimations of volátil completed
#
# Similarity estimations of votación completed
#
# Similarity estimations of votante completed
#
# Similarity estimations of votar completed
#
# Similarity estimations of voto completed
#
# Similarity estimations of vouchers completed
#
# Similarity estimations of voz completed
#
# Similarity estimations of vuelo completed
#
# Similarity estimations of vulgar completed
#
# Similarity estimations of vulgo completed
#
# Similarity estimations of válido completed
#
# Similarity estimations of vázquez completed
#
# Similarity estimations of vía completed
#
# Similarity estimations of víctima completed
#
# Similarity estimations of víctor completed
#
# Similarity estimations of vínculo completed
#
# Similarity estimations of warlain completed
#
# Similarity estimations of washington completed
#
# Similarity estimations of wb completed
#
# Similarity estimations of web completed
#
# Similarity estimations of wide completed
#
# Similarity estimations of wilhelmy completed
#
# Similarity estimations of william completed
#
# Similarity estimations of wilson completed
#
# Similarity estimations of workshop completed
#
# Similarity estimations of world completed
#
# Similarity estimations of wozniak completed
#
# Similarity estimations of www completed
#
# Similarity estimations of wwwexcelsiorcommx completed
#
# Similarity estimations of xenofóbicos completed
#
# Similarity estimations of xii completed
#
# Similarity estimations of xochicalco completed
#
# Similarity estimations of xx completed
#
# Similarity estimations of xxi completed
#
# Similarity estimations of yacer completed
#
# Similarity estimations of yllanes completed
#
# Similarity estimations of york completed
#
# Similarity estimations of yuri completed
#
# Similarity estimations of zacatecas completed
#
# Similarity estimations of zapata completed
#
# Similarity estimations of zapatismo completed
#
# Similarity estimations of zapato completed
#
# Similarity estimations of zavala completed
#
# Similarity estimations of zea completed
#
# Similarity estimations of zedillista completed
#
# Similarity estimations of zedillo completed
#
# Similarity estimations of zepeda completed
#
# Similarity estimations of zona completed
#
# Similarity estimations of zutano completed
#
# Similarity estimations of zócalo completed
#
# Similarity estimations of ámbito completed
#
# Similarity estimations of ánimo completed
#
# Similarity estimations of áprivada completed
#
# Similarity estimations of área completed
#
# Similarity estimations of áócfel completed
#
# Similarity estimations of época completed
#
# Similarity estimations of ése completed
#
# Similarity estimations of ésta completed
#
# Similarity estimations of éste completed
#
# Similarity estimations of ésto completed
#
# Similarity estimations of étnico completed
#
# Similarity estimations of éxito completed
#
# Similarity estimations of éxodo completed
#
# Similarity estimations of ídolo completed
#
# Similarity estimations of índice completed
#
# Similarity estimations of índole completed
#
# Similarity estimations of íntegro completed
#
# Similarity estimations of óptimo completed
#
# Similarity estimations of órbita completed
#
# Similarity estimations of órgano completed
#
# Similarity estimations of último completed
#
# Similarity estimations of únicamente completed
#
# Similarity estimations of único completed
