# %% [markdown]
# # Preprocessing and Topic Distribution with Gensim

# %% [markdown]
# On this notebook is developed the preprocessing and the topic mining process helped by the gensim library, that will be applied to our corpus made by newspaper texts.

# %% [markdown]
# ## Preprocessing: Initial Normalization
#
# First, we are going to define our functions to prepare our data before looking for the hidden topics inside them.

# %%
import nltk
from bs4 import BeautifulSoup
import re

# %%
def tokenize_by_words(text):
    words = text.split()
    alphabetic_words = list()
    
    for word in words:
        token = []
        for character in word:
            if re.match(r'^[a-záéíóúñü+$]', character):
                token.append(character)
        token = ''.join(token)
        if token != '':
            alphabetic_words.append(token)
    
    return alphabetic_words

def tokenize_by_sents(text):
    tokens = nltk.data.load("tokenizers/punkt/spanish.pickle") 
    sents = tokens.tokenize(text)
    alphabetic_sents = list()
    
    for sent in sents:
        sent_token = tokenize_by_words(sent)
        alphabetic_sents.append(sent_token)
    
    return alphabetic_sents

# %%
def remove_stop_words_from_sents(sents, path = './stopwords_es.txt'):
    with open(path, encoding = 'utf-8') as f:
        stop_words = f.readlines()
        stop_words = [w.strip() for w in stop_words]
        
    clean_sents = list()
    for sent in sents:
        clean_sent = [word for word in sent if word not in stop_words]
        clean_sents.append(clean_sent)
    
    return clean_sents

# %%
def lemmatize_from_sents(text, path = './generate.txt'):
    
    lemmas = dict()
    with open(path, encoding = 'latin1') as file:
        lines = file.readlines()
        for line in lines:
            line = line.strip()
            if line != '':
                words = line.split()
                token = words[0].strip()
                token = token.replace('#', '')
                lemma = words[-1].strip()
                tag = words[-2].strip()
                tag = tag[0].lower()
                lemmas[(token, tag)] = (lemma, tag)
    
    lemmatized_text = list()
    for sent in text:
        lemmatized_sent = list()
        for word in sent:
            if word in lemmas.keys():
                lemmatized_sent.append(lemmas[word])
            else:
                lemmatized_sent.append(word)
        
        lemmatized_text.append(lemmatized_sent)

    return lemmatized_text

# %% [markdown]
# ## Articles and Titles Extraction

# %% [markdown]
# Below are established the functions that will help us to extract the articles and titles from each newspaper file.

# %%
def is_title(text):
    lower = 0
    upper = 0
    for c in text:
        if c.isalpha():
            if c.isupper():
                upper += 1
            else:
                lower += 1
    if lower > upper:
        return True
    return False


def get_titles(path_origin = './../EXCELSIOR_100_files/', path_destiny = './topic_mining/titles/', no_page = 0):
    corpus = nltk.corpus.PlaintextCorpusReader(path_origin, '.*')
    file_list = corpus.fileids()
    titles = list()
    with open(path_origin + file_list[no_page], encoding = 'utf-8') as rfile:
        text = rfile.read()
    soup = BeautifulSoup(text, 'lxml')
    sents = soup.find_all('h3')
    for sent in sents:
        txt = sent.get_text()
        if is_title(txt):
            if txt != ' ':
                titles.append(txt.lower())
    with open(path_destiny + "titles_" + file_list[no_page][:11] + '.txt', 'w', encoding = 'utf-8') as wfile:
        wfile.writelines(titles)
    return titles

def get_articles(path_origin = './../EXCELSIOR_100_files/', no_page = 0):
    corpus = nltk.corpus.PlaintextCorpusReader(path_origin, '.*')
    file_list = corpus.fileids()
    with open(path_origin + file_list[no_page], encoding = 'utf-8') as rfile:
        text = rfile.read()
    arts = text.split("\n\n\n")[1:]
    new_arts = arts[1::2]
    clean_arts = list()
    for art in new_arts:
        clean_arts.append(clean_articles(art))
    return clean_arts

def clean_articles(txt):
    # Remove HTML tags
    soup = BeautifulSoup(txt, 'lxml')
    clean_text = soup.get_text()
    # Apply the function lower to the text
    clean_text = clean_text.lower()
    # Save the file
    return clean_text

# %%
titles = get_titles('./../EXCELSIOR_100_files/', './topic_mining/titles/', 0)

# %%
articles = get_articles('./../EXCELSIOR_100_files/', 0)

# %% [markdown]
# #### Normalization of articles

# %%
articles
# Out:
# ['\n\nmartes 02 de abril de 1996\n\nmonstruosa diferencia\n\ncolosistas y colosismo\n\nluis gutierrez y gonzalez\n\na luis gutiérrez sotomayor y a federico arreola, colosistas cabales, según me dijo su amigo luis donaldo.\nciertamente, el nombre y las circunstancias de luis donaldo colosio han llenado insistentemente los volúmenes y los espacios de los medios de comunicación. pero su renovada actualidad ha padecido un frenético vaivén de ficciones judiciales y políticas que integran y disgregan metafísicas más metafísicas aún que las que luis donaldo desprende —o se envuelve con ellas— al otro lado del espejo.\ndos años eternos de insolvencias, dale que dale a la fantasía, a la magia de dónde quedó la bolita, le han traído al pueblo hastío y cansancio. en la inminencia se percibe el váyanse al diablo del quórum nacional, que antes se veía decidido a instalar sécula seculórum sus demandas de justicia.\npero en el segundo aniversario del asesinato, el colosismo con su astroso luto protagónico ha intentado empapar el drama colosista con espesas y negras lágrimas de llorona profesional en velorio a la antigüita, diciéndose heredero de las ideas y los derechos por supuesto del paradigma.\n*\n¡que trampa le tendió el esotérico colosismo al presidente zedillo ponce de león! a su amigo y líder que fue, el mandatario dedica culto y seguimiento espirituales, dándole satisfacción a los compromisos políticos que aquel contrajo. su actitud moral propició la trampa. fulano y zutano se dijeron discípulos, hermanos, compañeros de lucha y asesores del caído. y quienes habían sido todo eso de veras, se hicieron a un lado cuando vieron cargar sobre don ernesto el tropel de búfalos.\nel que no llora, no mama. los colosistas no supieron o no quisieron, por vergüenza de ser confundidos, pegarse a la ubre. ¡qué mal hicieron! el colosismo se repartió las mercedes presidenciales.\nhay un parteaguas; una brecha insondable, separando a los colosistas del colosismo. a los bandos luis donaldo los llamaba —a mí me lo dijo— con los nombres respectivos de cabales y de oportunistas.\nen la efeméride dolorosa el colosismo intentó constituirse en dogma, en doctrina, en credo político. allá en magdalena, leyendo de este lumpen histriónico, viendo sus protagonismos, don luis colosio venció la garruda presencia a la hilaridad incontenible.\n¿colosismo?, ¡bah!\n\neditorial -\nnota siguiente\n\nhttp://www.excelsior.com.mx/9604/960401/art02.html',
#  '\n\nmartes 02 de abril de 1996\n\nscalfaro entre nosotros\n\nde aquí y más allá\n\njuan maria alponte\n\nel 19 de julio de 1943, en la villa gagia, benito mussolini recibía a adolf hitler que viajara en tren, a italia, para someter al dictador italiano a una larga y furiosa requisitoria sobre el comportamiento ("manifiestamente malo", le dice) de las tropas italianas. los alemanes se sienten heridos: el 12 de julio, en sicilia, donde han desembarcado ya los angloamericanos, la base militar de augusta se ha rendido. hitler, exasperado, no quiere aceptar que los italianos no quieren combatir. al mediodía de ese
\n7- la crisis modificó la distribución del ingreso de tal forma que creció la proporción de trabajadores con menos ingresos y bajó la participación de empleados con mayores niveles salariales. por ejemplo, el porcentaje de la población ocupada con ingresos menores a un salario mínimo pasó de 7.3% en diciembre de 1994, a 11.5% en agosto de 1995. en ese mismo periodo los trabajadores ocupados que ganan de uno hasta dos salarios mínimos, aumentó de 33.1% a 34.4%. por el contrario, quienes ganan más de dos y hasta cinco salarios mínimos bajó de 31.1% a 32.8%. (10) es decir, a raíz de la crisis que enfrenta el país son más los trabajadores que ganan menos y menos los que ganan más.\n8- el abandono del proyecto agropecuario por el estado en las últimas décadas ocasionó que después de haber sido un país exportador de granos, ahora hemos perdido la seguridad alimentaria y nos hemos convertido en una nación importadora de miles de toneladas anuales de alimentos. esto generó que el nivel de produc ...

# %%
tokenized_articles = list()
for article in articles:
    tokenized_articles.append(tokenize_by_sents(article))

clean_articles = list()
for tk_art in tokenized_articles:
    clean_articles.append(remove_stop_words_from_sents(tk_art))
    
lemmatized_articles = list()
for cl_art in clean_articles:
    lemmatized_articles.append(lemmatize_from_sents(text = cl_art))

# %%
lemmatized_articles
# Out:
# [[['martes',
#    'abril',
#    'monstruosa',
#    'diferencia',
#    'colosistas',
#    'colosismo',
#    'luis',
#    'gutierrez',
#    'gonzalez',
#    'luis',
#    'gutiérrez',
#    'sotomayor',
#    'federico',
#    'arreola',
#    'colosistas',
#    'cabales',
#    'según',
#    'dijo',
#    'amigo',
#    'luis',
#    'donaldo'],
#   ['ciertamente',
#    'nombre',
#    'circunstancias',
#    'luis',
#    'donaldo',
#    'colosio',
#    'llenado',
#    'insistentemente',
#    'volúmenes',
#    'espacios',
#    'medios',
#    'comunicación'],
#   ['renovada',
#    'actualidad',
#    'padecido',
#    'frenético',
#    'vaivén',
#    'ficciones',
#    'judiciales',
#    'políticas',
#    'integran',
#    'disgregan',
#    'metafísicas',
#    'metafísicas',
#    'aún',
#    'luis',
#    'donaldo',
#    'desprende',
#    'envuelve',
#    'lado',
#    'espejo'],
#   ['dos',
#    'años',
#    'eternos',
#    'insolvencias',
#    'dale',
#    'dale',
#    'fantasía',
#    'magia',
#    'dónde',
#    'quedó',
#    'bolita',
#    'traído',
#    'pueblo',
#    'hastío',
#    'cansancio'],
#   ['inminencia',
#    'percibe',
#    'váyanse',
#    'diablo',
#    'quórum',
#    'nacional',
#    'veía',
#    'decidido',
#    'instalar',
#    'sécula',
#    'seculórum',
#    'demandas',
#    'justicia'],
#   ['segundo',
#    'aniversario',
#    'asesinato',
#    'colosismo',
#    'astroso',
#    'luto',
#    'protagónico',
#    'intentado',
#    'empapar',
#    'drama',
#    'colosista',
#    'espesas',
#    'negras',
#    'lágrimas',
#    'llorona',
#    'profesional',
#    'velorio',
#    'antigüita',
#    'diciéndose',
#    'heredero',
#    'ideas',
#    'derechos',
#    'supuesto',
#    'paradigma'],
#   ['trampa',
#    'tendió',
#    'esotérico',
#    'colosismo',
#    'presidente',
#    'zedillo',
#    'ponce',
#    'león'],
#   ['amigo',
#    'líder',
#    'mandatario',
#    'dedica',
#    'culto',
#    'seguimiento',
#    'espirituales',
#    'dándole',
#    'satisfacción',
#    'compromisos',
#    'políticos',
#    'aquel',
#    'contrajo'],
#   ['actitud', 'moral', 'propició', 'trampa'],
#   ['fulano',
#    'zutano',
#    'dijeron',
#    'discípulos',
#    'hermanos',
#    'compañeros',
#    'lucha',
#    'asesores',
#    'caído'],
#   ['veras',
#    'hicieron',
#    'lado',
#    'vieron',
#    'cargar',
#    'don',
#    'ernesto',
#    'tropel',
#    'búfalos'],
#   ['llora', 'mama'],
#   ['colosistas',
#    'supieron',
#    'quisieron',
#    'vergüenza',
#    'confundidos',
#    'pegarse',
#    'ubre'],
#   ['mal', 'hicieron'],
#   ['colosismo', 'repartió', 'mercedes', 'presidenciales'],
#   ['parteaguas',
#    'brecha',
#    'insondable',
#    'separando',
#    'colosistas',
#    'colosismo'],
#   ['bandos',
#    'luis',
#    'donaldo',
#    'llamaba',
#    'dijo',
#    'nombres',
#    'respectivos',
#    'cabales',
#    'oportunistas'],
#   ['efeméride',
#    'dolorosa',
#    'colosismo',
#    'intentó',
#    'constituirse',
#    'dogma',
#    'doctrina',
#    'credo',
#    'político'],
#   ['allá',
#    'magdalena',
#    'leyendo',
#    'lumpen',
#    'histriónico',
#    'viendo',
#    'protagonismos',
#    'don',
#    'luis',
#    'colosio',
#    'venció',
#    'garruda',
#    'presencia',
#    'hilaridad',
#    'incontenible'],
#   ['colosismo', 'bah'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxarthtml']],
#  [['martes',
#    'abril',
#    'scalfaro',
#    'aquí',
#    'allá',
#    'juan',
#    'maria',
#    'alponte',
#    'julio',
#    'villa',
#    'gagia',
#    'benito',
#    'mussolini',
#    'recibía',
#    'adolf',
#    'hitler',
#    'viajara',
#    'tren',
#    'italia',
#    'someter',
#    'dictador',
#    'italiano',
#    'larga',
#    'furiosa',
#    'requisitoria',
#    'comportamiento',
#    'manifiestamente',
#    'malo',
#    'dice',
#    'tropas',
#    'italianas'],
#   ['alemanes',
#    'sienten',
#    'heridos',
#    'julio',
#    'sicilia',
#    'desembarcado',
#    'angloamericanos',
#    'base',
#    'militar',
#    'augusta',
#    'rendido'],
#   ['hitler',
#    'exasperado',
#    'quiere',
#    'aceptar',
#    'italianos',
#    'quieren',
#    'combatir'],
#   ['mediodía', 'día', 'entrevista', 'cortada', 'secretario', 'duce'],
#   ['portaba', 'telegrama'],
#   ['voz',
#    'emocionada',
#    'mussolini',
#    'traduce',
#    'alemán',
#    'momento',
#    'enemigo',
#    'bombardea',
#    'roma'],
#   ['muertos', 'heridos'],
#   ['julio',
#    'palacio',
#    'venecia',
#    'produjo',
#    'partir',
#    'cinco',
#    'tarde',
#    'aquel',
#    'sábado',
#    'sombrío',
#    'acontecimientos',
#    'insólitos',
#    'viera',
#    'italia'],
#   ['día',
#    'duce',
#    'preside',
#    'así',
#    'cree',
#    'reunión',
#    'rutina',
#    'gran',
#    'consejo',
#    'fascista'],
#   ['rutina'],
#   ['gran',
#    'consejo',
#    'aprobará',
#    'moción',
#    'extraordinaria',
#    'moción',
#    'grandi',
#    'dejándole',
#    'minoría',
#    'pidiendo',
#    'poderes',
#    'posee',
#    'duce',
#    'traspasen',
#    'rey'],
#   ['día',
#    'siguiente',
#    'domingo',
#    'mussolini',
#    'acude',
#    'palacio',
#    'real',
#    'mientras',
#    'escucha',
#    'calles',
#    'abbasso',
#    'mussolini'],
#   ['rey', 'alertado', 'desposee', 'poderes', 'momento', 'duro', 'blando'],
#   ['dice', 'monarca', 'allora', 'tutto', 'finito'],
#   ['sera', 'della', 'mia', 'famiglia'],
#   ['comporta', 'piccolo', 'borghese'],
#   ['grandeza', 'advenedizo', 'poder'],
#   ['ustedes', 'saben'],
#   ['italia', 'mussolini', 'pasaría', 'aliados', 'alemanes'],
#   ['duce', 'apresado', 'partisanos', 'fusilado', 'huida'],
#   ['junio',
#    'país',
#    'referéndum',
#    'elegía',
#    'instituciones',
#    'italianos',
#    'votaron',
#    'república',
#    'monarquía',
#    'consagrara',
#    'marcia',
#    'roma',
#    'famosa',
#    'marcha',
#    'roma',
#    'mussolini',
#    'fascios',
#    'combate',
#    'convirtiéndole',
#    'jefe',
#    'gobierno'],
#   ['comenzaba',
#    'italia',
#    'edad',
#    'partidos',
#    'consagrando',
#    'democracia',
#    'cristiana',
#    'partido',
#    'mayoritario',
#    'mayoría',
#    'relativa'],
#   ['formarían', 'coaliciones', 'gubernamentales', 'tempestades', 'posguerra'],
#   ['nación',
#    'italiana',
#    'pese',
#    'fragilidad',
#    'gobiernos',
#    'realizaría',
#    'hazañas',
#    'notables',
#    'económicas',
#    'industriales',
#    'mundo',
#    'actual'],
#   ['convertido', 'siete', 'grandes'],
#   ['millones',
#    'habitantes',
#    'crecimiento',
#    'demográfico',
#    'ingreso',
#    'persona',
#    'dólares',
#    'exportaciones',
#    'alcanzaron',
#    'impresionante',
#    'suma',
#    'millones',
#    'dólares',
#    'importaciones',
#    'millones'],
#   ['unas',
#    'elecciones',
#    'históricas',
#    'derrumbaba',
#    'régimen',
#    'partitocrazia',
#    'entrarse',
#    'verdadera',
#    'definición',
#    'estabilidad',
#    'enterraba',
#    'pasado',
#    'presente',
#    'fortalecido'],
#   ['presidente',
#    'oscar',
#    'luigi',
#    'scalfaro',
#    'extraordinaria',
#    'inteligencia',
#    'mesura',
#    'dirigido',
#    'periodo',
#    'complejo',
#    'gobierno',
#    'apresta',
#    'elecciones',
#    'decisivas',
#    'próximo',
#    'mes',
#    'abril'],
#   ['ello',
#    'momento',
#    'mismo',
#    'italia',
#    'ocupa',
#    'presidencia',
#    'rotativa',
#    'seis',
#    'meses',
#    'europa',
#    'scalfaro',
#    'hoy',
#    'asciende',
#    'nivel',
#    'hombres',
#    'crear',
#    'cenizas',
#    'primera',
#    'república',
#    'cimientos',
#    'segunda'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxarthtml']],
#  [['martes',
#    'abril',
#    'jabón',
#    'olor',
#    'suprema',
#    'lavamanos',
#    'javier',
#    'romero',
#    'cada',
#    'habla',
#    'feria',
#    'según',
#    'va'],
#   ['tan', 'socorrido', 'refrán', 'eleva', 'veces', 'cimas', 'políticas'],
#   ['quién',
#    'definitiva',
#    'favoreció',
#    'fallo',
#    'corte',
#    'suprema',
#    'diferendo',
#    'gobernador',
#    'tabasco',
#    'procurador',
#    'república'],
#   ['juzgar',
#    'reacciones',
#    'cada',
#    'habla',
#    'según',
#    'intereses',
#    'simpatías',
#    'antipatías',
#    'políticas',
#    'mismo',
#    'dice',
#    'madrazo',
#    'seco',
#    'madrazo',
#    'salió',
#    'bien',
#    'librado',
#    'declara',
#    'empate'],
#   ['cierto',
#    'asunto',
#    'originó',
#    'ardid',
#    'aporreado',
#    'gobernador',
#    'esperaba',
#    'diera',
#    'pie',
#    'verso',
#    'forzado',
#    'ir',
#    'dilucidando',
#    'papel',
#    'corte',
#    'tribunal',
#    'legalidad'],
#   ['queda', 'aún', 'veremos'],
#   ['sobreseimiento', 'esencial', 'suprema', 'eludió', 'fondo', 'intríngulis'],
#   ['vulgar',
#    'mil',
#    'veces',
#    'dijo',
#    'pasado',
#    'supremos',
#    'juristas',
#    'optaron',
#    'lavarse',
#    'manos'],
#   ['aunque',
#    'ahora',
#    'despidan',
#    'olor',
#    'jabón',
#    'fino',
#    'atisbaron',
#    'palangana',
#    'través',
#    'grietas',
#    'procedimiento'],
#   ['dijérase',
#    'aferran',
#    'tesis',
#    'viejos',
#    'constituyentes',
#    'deseaban',
#    'corte',
#    'impoluta',
#    'nunca',
#    'manchada',
#    'mezquindades',
#    'sucia',
#    'política',
#    'pese',
#    'vivirse',
#    'tiempo',
#    'pide',
#    'canta',
#    'real',
#    'vigencia',
#    'triada',
#    'poderes',
#    'constitucionales',
#    'sometimientos'],
#   ['hace',
#    'buen',
#    'titipuchal',
#    'años',
#    'mero',
#    'presidente',
#    'además',
#    'caudillo',
#    'obregón',
#    'puso',
#    'suprema',
#    'brete'],
#   ['antecesor',
#    'huerta',
#    'dejado',
#    'efecto',
#    'desconocimiento',
#    'gobernador',
#    'michoacán',
#    'decretado',
#    'senado',
#    'evidentes',
#    'trampas'],
#   ['obregón',
#    'quiso',
#    'embarcar',
#    'corte',
#    'pidió',
#    'dilucidar',
#    'embrollo',
#    'seguro',
#    'seguiría',
#    'aversión',
#    'múgica'],
#   ['suprema',
#    'enjabonada',
#    'dijo',
#    'incompetente',
#    'dejar',
#    'desafío',
#    'fuerza',
#    'caudillesca'],
#   ['duraron', 'aquellos', 'tenues', 'arrestos', 'autonomía'],
#   ['prudente',
#    'día',
#    'pleno',
#    'maximato',
#    'callista',
#    'suprema',
#    'dio',
#    'baño',
#    'cuerpo',
#    'entero',
#    'evadió',
#    'escándalo',
#    'demandaba',
#    'intervenir',
#    'destierro',
#    'luis',
#    'cabrera',
#    'reo',
#    'conferencia',
#    'crítica'],
#   ['célebre',
#    'rasgo',
#    'pundonor',
#    'ministro',
#    'alberto',
#    'vázquez',
#    'mercado',
#    'tiró',
#    'toga',
#    'hacerse',
#    'cómplice',
#    'prudencia',
#    'miedo'],
#   ['dudé',
#    'celebrada',
#    'nueva',
#    'independencia',
#    'informe',
#    'zedillo',
#    'observé',
#    'nunca',
#    'vistas',
#    'jamás',
#    'oídas',
#    'carantoñas',
#    'presidente',
#    'suprema',
#    'don',
#    'aguinaco',
#    'prodigaba',
#    'supremo',
#    'señor',
#    'lambiscón',
#    'diputados'],
#   ['pensé',
#    'acaso',
#    'emilio',
#    'rabasa',
#    'negaba',
#    'judicial',
#    'carácter',
#    'poder',
#    'reducía',
#    'departamento',
#    'jurídico'],
#   ['parece',
#    'resucitar',
#    'ahora',
#    'fallo',
#    'salomónico',
#    'aforismo',
#    'leguleyos',
#    'corte',
#    'vence',
#    'convence'],
#   ['esperemos', 'mejores', 'pruebas'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxarthtml']],
#  [['martes', 'abril', 'dinero', 'banqueros', 'santiago', 'genoves'],
#   ['pena',
#    'mala',
#    'pena',
#    'quisiera',
#    'quitara',
#    'vino',
#    'vienen',
#    'saber',
#    'dónde',
#    'agua',
#    'mares',
#    'flores',
#    'mayo',
#    'vientos',
#    'bosque',
#    'vino',
#    'quedado',
#    'corazón',
#    'amargo',
#    'corteza',
#    'verde',
#    'verde',
#    'limón'],
#   ['respeto',
#    'elevada',
#    'investidura',
#    'parece',
#    'hombre',
#    'bueno',
#    'honesto',
#    'bienintencionado',
#    'trabajador',
#    'siento',
#    'simpatía',
#    'hacia',
#    'señor',
#    'presidente',
#    'zedillo'],
#   ['vámonos',
#    'hacia',
#    'pasado',
#    'ex',
#    'salinas',
#    'apenas',
#    'si',
#    'tardíamente',
#    'llegó',
#    'bordes',
#    'chiapas'],
#   ['unas',
#    'horas',
#    'sólo',
#    'decimos',
#    'méxico',
#    'taparle',
#    'ojo',
#    'macho',
#    'salía',
#    'inmediato',
#    'suiza',
#    'gran',
#    'reunión',
#    'banqueros'],
#   ['allí',
#    'pues',
#    'pretendía',
#    'aunque',
#    'viento',
#    'marea',
#    'pasar',
#    'presidente',
#    'omc'],
#   ['poderoso',
#    'caballero',
#    'don',
#    'dinero',
#    'ayer',
#    'dijo',
#    'pascual',
#    'si',
#    'casó',
#    'inés',
#    'interés',
#    'sino',
#    'capital'],
#   ['presidente', 'zedillo', 'europa'],
#   ['fundamentalmente', 'trató', 'aspectos', 'económicofinancieros'],
#   ['hace', 'unas', 'semanas', 'lix', 'convención', 'banca', 'cancún'],
#   ['así', 'pasada', 'convención', 'chiapas', 'ezln'],
#   [],
#   [],
#   ['dice',
#    'querida',
#    'amiga',
#    'rosario',
#    'guerra',
#    'excelsior',
#    'si',
#    'truena',
#    'sistema',
#    'financiero',
#    'tronamos'],
#   ['amiga',
#    'rosario',
#    'si',
#    'rompe',
#    'puente',
#    'podemos',
#    'atravesarlo',
#    'remo',
#    'barca',
#    'panga'],
#   ['manera', 'actuar', 'quebraron', 'miles', 'medianas', 'micro', 'empresas'],
#   ['quedaron', 'trabajo', 'cientos', 'miles', 'mexicanos'],
#   ['salvó', 'navío', 'casi', 'nadie', 'viva'],
#   ['convención',
#    'cancún',
#    'sólo',
#    'banqueros',
#    'economistas',
#    'financieros',
#    'políticos',
#    'disponiendo',
#    'vidas'],
#   ['sociólogos',
#    'psicólogos',
#    'filósofos',
#    'etcétera',
#    'allí',
#    'lugar',
#    'tratándose',
#    'trató',
#    'fondo',
#    'vida',
#    'social',
#    'méxico'],
#   ['zea', 'gonzález', 'casanova', 'sánchez', 'sosa', 'etcétera', 'decir'],
#   ['creo', 'mayor', 'parte'],
#   ['ésta', 'pena'],
#   ['pena', 'dinero', 'dinero', 'dinero'],
#   ['chiapas', 'apenas', 'si', 'cuenta'],
#   ['cuenta', 'convención', 'banqueros'],
#   ['allí',
#    'debió',
#    'sobrio',
#    'sabio',
#    'sergio',
#    'peña',
#    'historia',
#    'capitalismo',
#    'méxico'],
#   ['erradísimo', 'error'],
#   ['ello'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxarthtml']],
#  [['martes',
#    'abril',
#    'nacionalista',
#    'natalio',
#    'vázquez',
#    'pallares',
#    'oscar',
#    'gonzalez',
#    'lopez',
#    'marzo',
#    'hace',
#    'quince',
#    'años',
#    'brusca',
#    'intempestivamente',
#    'terminó',
#    'fecunda',
#    'vida',
#    'mexicano',
#    'excepcional',
#    'nacido',
#    'coalcomán',
#    'población',
#    'tarasca',
#    'cuna',
#    'compatriota',
#    'ilustre',
#    'ricardo',
#    'torres',
#    'gaytán',
#    'relación',
#    'estrecha',
#    'fructífera',
#    'michoacán',
#    'patria'],
#   ['llamó',
#    'llama',
#    'natalio',
#    'vázquez',
#    'pallares',
#    'cardenista',
#    'años',
#    'máximo',
#    'fulgor',
#    'revolución',
#    'mexicana',
#    'cardenista',
#    'después',
#    'cardenista',
#    'siempre'],
#   ['natalio', 'combatiente', 'lúcido', 'tenaz', 'últimos', 'días'],
#   ['páginas',
#    'editoriales',
#    'excelsior',
#    'dejó',
#    'claras',
#    'enseñanzas',
#    'historia',
#    'patria',
#    'sobradas',
#    'muestras',
#    'capacidad',
#    'teórica',
#    'crear',
#    'desarrollar',
#    'tesis',
#    'fundamentales',
#    'proyecto',
#    'constitucional',
#    'desarrollo',
#    'febrero',
#    'nacionalismo',
#    'revolucionario',
#    'reconquista',
#    'méxico',
#    'delineadas',
#    'textos',
#    'originales',
#    'artículos',
#    'tercero',
#    'carta',
#    'magana',
#    'elaborada',
#    'representantes',
#    'pueblo',
#    'armas',
#    'triunfante',
#    'formidable',
#    'insurrección',
#    'dictadura',
#    'porfirista',
#    'siniestro',
#    'renuevo',
#    'golpistas',
#    'febrero',
#    'polichinelas',
#    'henry',
#    'lane',
#    'wilson',
#    'embajador',
#    'imperio',
#    'generales',
#    'bien',
#    'vistos',
#    'buenas',
#    'conciencias',
#    'jerarquía',
#    'católica'],
#   ['natalio',
#    'surgió',
#    'dirigente',
#    'juvenil',
#    'legendario',
#    'mítico',
#    'frente',
#    'estudiantil',
#    'socialista',
#    'occidente'],
#   ['luego',
#    'convergencia',
#    'primaveral',
#    'confederación',
#    'jóvenes',
#    'méxico'],
#   ['ingresó',
#    'gusto',
#    'orgullo',
#    'partido',
#    'revolución',
#    'mexicana',
#    'renovación',
#    'espléndida',
#    'pnr',
#    'callista'],
#   ['instinto',
#    'popular',
#    'advirtió',
#    'transformación',
#    'prm',
#    'pri',
#    'significaba',
#    'advenimiento',
#    'pandilla',
#    'contrarrevolucionaria',
#    'enemiga',
#    'agraristas',
#    'corrientes',
#    'sindicales',
#    'comunista',
#    'lombardista',
#    'pandilla',
#    'alemanista'],
#   ['fuerza',
#    'incontrastable',
#    'cardenismo',
#    'presente',
#    'junio',
#    'llevó',
#    'pesar',
#    'encono',
#    'grupo',
#    'comandado',
#    'jarocho',
#    'sayula',
#    'candidatura',
#    'diputación',
#    'federal',
#    'primavera',
#    'triunfó',
#    'ampliamente',
#    'necesidad',
#    'casillas',
#    'zapato',
#    'acarreo',
#    'votantes',
#    'carruseles',
#    'taqueos',
#    'compra',
#    'votos'],
#   ['hoy',
#    'quince',
#    'años',
#    'partida',
#    'física',
#    'natalio',
#    'recordamos',
#    'conducta',
#    'viril',
#    'gallarda',
#    'actitud',
#    'diputado',
#    'federal',
#    'denunciar',
#    'calidad',
#    'presidente',
#    'comisión',
#    'petróleo',
#    'cámara',
#    'diputados',
#    'firma',
#    'contratos',
#    'riesgo',
#    'pemex',
#    'compañías',
#    'privadas',
#    'estadunidenses'],
#   ['artículos',
#    'memorables',
#    'escritos',
#    'verano',
#    'aportó',
#    'legó',
#    'tarea',
#    'patriótica',
#    'rango',
#    'histórico'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxarthtml']],
#  [['martes',
#    'abril',
#    'medios',
#    'educación',
#    'pasa',
#    'allí',
#    'margarita',
#    'michelena',
#    'casi',
#    'mismo',
#    'tiempo',
#    'contribuyentes',
#    'descubríamos',
#    'hermanita',
#    'procurador',
#    'lozano',
#    'gracia',
#    'anda',
#    'paseando',
#    'protegida',
#    'escolta',
#    'guaruras',
#    'mientras',
#    'humildes',
#    'ciudadanos',
#    'despanzurra',
#    'delincuente',
#    'cualquier',
#    'esquina',
#    'doctor',
#    'zedillo',
#    'decía',
#    'claro',
#    'medios',
#    'debían',
#    'vehículos',
#    'educación',
#    'moralización',
#    'pueblo'],
#   ['tan', 'cierto'],
#   ['hablemos', 'ahora', 'medios', 'particularmente', 'televisión', 'radio'],
#   ['televisión',
#    'ir',
#    'ahora',
#    'dañoso',
#    'hace',
#    'sino',
#    'atentar',
#    'valores',
#    'moral',
#    'inteligencia'],
#   ['ahí',
#    'ir',
#    'lejos',
#    'programas',
#    'deleznables',
#    'hoy',
#    'daniela',
#    'suelen',
#    'presentarse',
#    'individuillos',
#    'toda',
#    'laya'],
#   ['días',
#    'apareció',
#    'pantalla',
#    'golfales',
#    'importación',
#    'llamada',
#    'martha',
#    'sánchez',
#    'ningún',
#    'respeto',
#    'público',
#    'relató',
#    'chiste',
#    'soez',
#    'todas',
#    'letras',
#    'cuya',
#    'causa',
#    'todavía',
#    'arden',
#    'muchas',
#    'orejas'],
#   ['violación',
#    'ley',
#    'federal',
#    'radio',
#    'televisión',
#    'bastado',
#    'tiempos',
#    'programa',
#    'cosa',
#    'llaman',
#    'programa',
#    'saliera',
#    'aire',
#    'ipso',
#    'facto'],
#   ['toda',
#    'televisión',
#    'buena',
#    'parte',
#    'radio',
#    'invadidas',
#    'cosas',
#    'inmundas',
#    'intimamente',
#    'shanik',
#    'cada',
#    'vez',
#    'abundantes',
#    'programas',
#    'nota',
#    'roja'],
#   ['digan',
#    'si',
#    'toda',
#    'basura',
#    'solo',
#    'programa',
#    'informe',
#    'cultive',
#    'salvo',
#    'programas',
#    'noticiosos'],
#   ['telenovelas',
#    'vehículo',
#    'seguro',
#    'llenar',
#    'masa',
#    'imbecilidades',
#    'ahí',
#    'va',
#    'premio',
#    'mayor',
#    'maría',
#    'barrio',
#    'dos',
#    'bodrios',
#    'debería',
#    'vergonzoso',
#    'transmitir'],
#   ['visto',
#    'existe',
#    'monitoreo',
#    'alguno',
#    'autoridad',
#    'competente',
#    'material',
#    'utilizado',
#    'televisión'],
#   ['manera', 'vergüenzas', 'públicas', 'llegarían', 'hogares', 'así'],
#   ['podría',
#    'hablar',
#    'competencias',
#    'refiriéndose',
#    'televisión',
#    'azteca',
#    'buena',
#    'ley',
#    'posible'],
#   ['compradores',
#    'privados',
#    'canales',
#    'hacen',
#    'sino',
#    'copiar',
#    'mal',
#    'televisa'],
#   ['dos',
#    'grandes',
#    'canales',
#    'pasan',
#    'material',
#    'calidad',
#    'veces',
#    'maravillosa',
#    'gracia',
#    'pues',
#    'trata',
#    'frecuencias',
#    'pagadas',
#    'gobierno',
#    'medios',
#    'masivos',
#    'comunicación',
#    'refería',
#    'presidente',
#    'día',
#    'cumplía',
#    'años',
#    'organización',
#    'televisión',
#    'iberoamericana',
#    'oti',
#    'señor',
#    'cañedo',
#    'trató',
#    'aprovechar',
#    'viaje',
#    'toro',
#    'arrancar',
#    'presidente',
#    'elogios',
#    'funesta',
#    'obra',
#    'televisión',
#    'privada'],
#   ['cierto',
#    'público',
#    'necesita',
#    'entretenimiento',
#    'confundir',
#    'diversión',
#    'degradación',
#    'somete',
#    'auditorio',
#    'muchísimas',
#    'horas',
#    'diarias',
#    'presentándole',
#    'cosas',
#    'aberrantes',
#    'si',
#    'tratara',
#    'natural',
#    'correcto',
#    'mundo',
#    'sazonado',
#    'despropósitos',
#    'crean',
#    'falsos',
#    'ídolos',
#    'falsos',
#    'valores'],
#   ['vemos',
#    'forma',
#    'cumple',
#    'televisión',
#    'primero',
#    'cometidos',
#    'educar',
#    'cuenta',
#    'recursos',
#    'si',
#    'descontamos',
#    'talento'],
#   ['así',
#    'muestras',
#    'escatología',
#    'violencia',
#    'fomenta',
#    'conducta',
#    'delictuosa',
#    'sofocados'],
#   ['hora',
#    'pedir',
#    'cuentas',
#    'televisión',
#    'privada',
#    'fechorías',
#    'impunes',
#    'causas',
#    'ésta',
#    'contaminado',
#    'ambiente',
#    'moral',
#    'vamos',
#    'malviviendo',
#    'menos',
#    'momento'],
#   ['televisión', 'privada', 'funciona', 'concesiones', 'federales', 'dicho'],
#   ['correspondencia',
#    'apartado',
#    'postal',
#    'ciudad',
#    'número',
#    'fax',
#    'editorial',
#    'nota',
#    'siguiente',
#    'httpwwwexcelsiorcommxarthtml']],
#  [['martes',
#    'abril',
#    'camino',
#    'hambruna',
#    'tocar',
#    'fondo',
#    'fernando',
#    'cesarman',
#    'mazorca',
#    'dobla'],
#   ['frecuencia',
#    'escuchamos',
#    'discursos',
#    'economistas',
#    'políticos',
#    'tocamos',
#    'fondo'],
#   ['podemos', 'hundirnos', 'crisis'],
#   ['quién', 'sabe', 'tocar', 'fondo'],
#   ['hoy', 'vivimos', 'amenaza', 'brotes', 'hambruna'],
#   ['gravedad',
#    'crisis',
#    'económica',
#    'sumada',
#    'tremendas',
#    'sequías',
#    'norte',
#    'insuficiencia',
#    'producción',
#    'alimentos',
#    'erosión',
#    'tierra',
#    'muerte',
#    'ganado',
#    'falta',
#    'previsión',
#    'evitar',
#    'catástrofes',
#    'llevan',
#    'rincones',
#    'hambruna'],
#   ['cuándo', 'toca', 'fondo'],
#   ['terrible',
#    'despertarnos',
#    'noticia',
#    'sierra',
#    'tal',
#    'lugar',
#    'grupo',
#    'pobladores',
#    'comer',
#    'causa',
#    'sequía',
#    'condiciones',
#    'políticas',
#    'extrema',
#    'pobreza',
#    'deforestación',
#    'arroyos',
#    'secos',
#    'esqueletos',
#    'chivos',
#    'gente',
#    'hambre',
#    'niños',
#    'flacos',
#    'madres',
#    'huesudas',
#    'hombres',
#    'viejos',
#    'transparentes'],
#   ['hambrunas',
#    'brutales',
#    'sufren',
#    'profunda',
#    'vergüenza',
#    'pueblos',
#    'padecen'],
#   ['hambrunas', 'encuentran', 'extremo', 'espectro', 'ecocidio'],
#   ['suceden', 'desequilibrio', 'hombre', 'paisaje', 'total'],
#   ['destrozo', 'casa'],
#   ['final', 'utópica', 'fantasía', 'armonía', 'hombre', 'medio'],
#   ['fracaso', 'sociedad', 'fracaso', 'sistemas', 'políticos'],
#   ['fracaso', 'humillación', 'humanismo', 'contenido', 'proyectos', 'patria'],
#   ['sucedió', 'sierra', 'tarahumara', 'sigue', 'sucediendo'],
#   ['hace',
#    'dos',
#    'años',
#    'presenciamos',
#    'drama',
#    'hambre',
#    'sierra',
#    'pronta',
#    'reacción',
#    'autoridades'],
#   ['embargo', 'problema', 'continúa', 'regado', 'toda', 'superficie', 'país'],
#   ['rincón',
#    'escape',
#    'presencia',
#    'niños',
#    'adultos',
#    'desnutridos',
#    'padecen',
#    'hambre',
#    'crónica'],
#   ['aumento',
#    'precio',
#    'productos',
#    'alimenticios',
#    'básicos',
#    'leche',
#    'azúcar',
#    'ahora',
#    'tortilla',
#    'acelera',
#    'escasez',
#    'alimentos',
#    'habitantes',
#    'pobres'],
#   ['declaraciones',
#    'oficiales',
#    'justifican',
#    'aumentos',
#    'terminar',
#    'costosos',
#    'subsidios',
#    'pronto',
#    'después',
#    'años',
#    'dado',
#    'cuenta',
#    'regulan',
#    'precios',
#    'controlan',
#    'subsidios',
#    'subsidios',
#    'beneficiaban',
#    'salarios',
#    'adecuados',
#    'además',
#    'existía',
#    'corrupción',
#    'manejo'],
#   ['sabíamos',
#    'economistas',
#    'sino',
#    'sólo',
#    'tratamos',
#    'entender',
#    'dificultades',
#    'manejo',
#    'dinero',
#    'perspectivas',
#    'subsidios',
#    'regalo',
#    'población',
#    'sino',
#    'simplemente',
#    'forma',
#    'compensar',
#    'pésimos',
#    'salarios'],
#   ['así',
#    'malos',
#    'ingresos',
#    'podía',
#    'adquirir',
#    'cantidad',
#    'adecuada',
#    'productos',
#    'subsidiados',
#    'además',
#    'podían',
#    'utilizar',
#    'servicios',
#    'subsidiados',
#    'transporte'],
#   ['hoy',
#    'enfrentamos',
#    'grave',
#    'situación',
#    'subsidios',
#    'tienden',
#    'eliminados',
#    'sueldos',
#    'siguen',
#    'raquíticos',
#    'aún',
#    'deplorables',
#    'subida',
#    'precios',
#    'aquellos',
#    'insumos',
#    'subsidiados'],
#   ['constituye', 'catástrofe', 'ecológica'],
#   ['pobreza',
#    'signo',
#    'degradación',
#    'posibilidad',
#    'pueblo',
#    'conseguir',
#    'pobreza',
#    'escasez',
#    'productos',
#    'indispensables',
#    'subsistencia'],
#   ['grave', 'además', 'precios', 'predicciones', 'producción', 'granos'],
#   ['embargo', 'absurdamente', 'tranquilos'],
#   ['si', 'pasara'],
#   ['grave', 'vivir', 'geranios', 'tierra'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxarthtml']],
#  [['martes',
#    'abril',
#    'hace',
#    'años',
#    'abril',
#    'fuerzas',
#    'estadunidenses',
#    'británicas',
#    'registraron',
#    'casas',
#    'poblaciones',
#    'situadas',
#    'parte',
#    'occidental',
#    'alemania',
#    'austria',
#    'objeto',
#    'detener',
#    'cerca',
#    'mil',
#    'alemanes',
#    'sospecha',
#    'implicados',
#    'rebelión',
#    'nazi'],
#   ['ninguno', 'soldados', 'resultó', 'herido'],
#   ['sindicato',
#    'trabajadores',
#    'industria',
#    'cinematográfica',
#    'perdió',
#    'laudo',
#    'laboral',
#    'sindicato',
#    'encabezado',
#    'cantinflas',
#    'jorge',
#    'negrete',
#    'según',
#    'segunda',
#    'agrupación',
#    'podrá',
#    'filmar',
#    'películas',
#    'interpuso',
#    'recurso',
#    'obligó',
#    'juez',
#    'primero',
#    'distrito',
#    'administrativo',
#    'licenciado',
#    'ponciano',
#    'hernández',
#    'ortega',
#    'pedir',
#    'presidente',
#    'república',
#    'diga',
#    'si',
#    'opinión',
#    'emitida',
#    'respecto',
#    'conflicto',
#    'cinematografistas',
#    'simple',
#    'opinión',
#    'decir',
#    'si',
#    'características',
#    'fallo',
#    'arbitral'],
#   ['ello',
#    'dependerá',
#    'justicia',
#    'federal',
#    'decida',
#    'si',
#    'amparo',
#    'promovido',
#    'stic',
#    'laudo',
#    'procedente'],
#   ['vez',
#    'organizados',
#    'legalmente',
#    'concluida',
#    'estructura',
#    'administrativa',
#    'partidos',
#    'políticos',
#    'sólo',
#    'quedan',
#    'candidatos',
#    'presidenciales',
#    'fuerza',
#    'debidamente',
#    'organizada',
#    'licenciados',
#    'miguel',
#    'alemán',
#    'ezequiel',
#    'padilla'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxarthtml']],
#  [['martes',
#    'abril',
#    'hace',
#    'años',
#    'teniente',
#    'william',
#    'calley',
#    'sentenciado',
#    'cadena',
#    'perpetua',
#    'tribunal',
#    'militar',
#    'juzgó',
#    'considerarlo',
#    'culpable',
#    'asesinato',
#    'menos',
#    'hombres',
#    'mujeres',
#    'niños',
#    'vietnamitas',
#    'my',
#    'lai',
#    'hace',
#    'tres',
#    'años'],
#   ['apelación',
#    'automática',
#    'trámite',
#    'puede',
#    'demorar',
#    'varios',
#    'meses'],
#   ['presidente',
#    'tribunal',
#    'coronel',
#    'reid',
#    'kennedy',
#    'dijo',
#    'jurados',
#    'leer',
#    'veredicto',
#    'comprendo',
#    'señores',
#    'agonía',
#    'debieron',
#    'haber',
#    'pasado',
#    'ustedes',
#    'mismos',
#    'oficiales'],
#   ['agradezco'],
#   ['luego',
#    'ordenó',
#    'escribano',
#    'lectura',
#    'veredicto',
#    'teniente',
#    'william',
#    'calley',
#    'presidente',
#    'corte',
#    'deber',
#    'informarle',
#    'tribunal',
#    'condena',
#    'encarcelado',
#    'trabajos',
#    'forzados',
#    'tiempo',
#    'dure',
#    'vida',
#    'natural',
#    'dado',
#    'baja',
#    'ejército',
#    'privado',
#    'haberes',
#    'indemnizaciones'],
#   ['calley',
#    'puesto',
#    'pie',
#    'cuadró',
#    'militarmente',
#    'escuchar',
#    'sentencia'],
#   ['reacción',
#    'cadena',
#    'caracterizó',
#    'campañas',
#    'anulado',
#    'veredicto',
#    'elevación',
#    'protesta',
#    'funcionarios',
#    'así',
#    'solicitudes',
#    'formales',
#    'clemencia',
#    'militares',
#    'ex',
#    'soldados',
#    'personas',
#    'hijos',
#    'peleando',
#    'vietnam'],
#   ['parte',
#    'hombre',
#    'nueva',
#    'york',
#    'envió',
#    'telegrama',
#    'decía',
#    'cuelguen',
#    'calley'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxarthtml']],
#  [['martes',
#    'abril',
#    'ningún',
#    'caso',
#    'modificaré',
#    'rumbo',
#    'cuentos',
#    'políticos',
#    'francisco',
#    'martin',
#    'moreno',
#    'señor',
#    'respondió',
#    'coro',
#    'unísono',
#    'si',
#    'echamos',
#    'andar',
#    'economía',
#    'aun',
#    'lograrlo',
#    'aumentar',
#    'índices',
#    'inflación',
#    'podría',
#    'aumentar',
#    'peligrosamente',
#    'efervescencia',
#    'social'],
#   ['podemos', 'señor', 'tener', 'disciplina', 'nación', 'desarrollada'],
#   ['requiere',
#    'encontrar',
#    'dosis',
#    'término',
#    'medio',
#    'crecer',
#    'ir',
#    'dominando',
#    'gradualmente',
#    'inflación'],
#   ['ningún', 'caso', 'variaré', 'rumbo'],
#   ['señor',
#    'vivimos',
#    'estanflación',
#    'mezcla',
#    'explosiva',
#    'estancamiento',
#    'económico',
#    'inflación'],
#   ['peor', 'dos', 'mundos'],
#   ['empresas',
#    'difícilmente',
#    'podrán',
#    'resistir',
#    'tiempo',
#    'oxígeno',
#    'crédito',
#    'ventas',
#    'recuperación',
#    'cartera'],
#   ['escasamente', 'hacen', 'negocios'],
#   ['pocos', 'pocos', 'dinero'],
#   ['pocos',
#    'pocos',
#    'cumplen',
#    'obligaciones',
#    'bancarias',
#    'fiscales',
#    'insuficiencia',
#    'financiera',
#    'generan',
#    'utilidades',
#    'ende',
#    'causan',
#    'impuestos'],
#   ['empresas', 'pobres', 'fisco', 'pobre', 'país', 'pobre', 'señor'],
#   ['inaplazable',
#    'gaste',
#    'gobierno',
#    'acertada',
#    'medianía',
#    'empezar',
#    'crecer',
#    'ningún',
#    'caso',
#    'variaré',
#    'rumbo'],
#   ['señor',
#    'usted',
#    'razonable',
#    'correcto',
#    'hacer',
#    'cualquier',
#    'esfuerzo',
#    'tal',
#    'detener',
#    'inflación',
#    'dañar',
#    'altísimo',
#    'impuesto',
#    'social',
#    'comunidad'],
#   ['sólo',
#    'empresas',
#    'sólo',
#    'contratan',
#    'nadie',
#    'sino',
#    'despiden',
#    'masivamente',
#    'personal',
#    'tal',
#    'sobrevivir'],
#   ['gente',
#    'pierde',
#    'empleos',
#    'asfixia',
#    'económica',
#    'impotencia',
#    'financiera',
#    'extremo',
#    'poder',
#    'pagar',
#    'colegiatura',
#    'hijos',
#    'constituye',
#    'duda',
#    'invitación',
#    'violencia'],
#   ['pronto',
#    'escoger',
#    'control',
#    'inflación',
#    'manifestaciones',
#    'urbanas',
#    'ciudadanos',
#    'dispuestos',
#    'familias',
#    'perezcan',
#    'hambre'],
#   ['ningún', 'caso', 'variaré', 'rumbo'],
#   ['suelte',
#    'gasto',
#    'señor',
#    'suéltelo',
#    'aun',
#    'conceder',
#    'aumentos',
#    'salariales',
#    'suframos',
#    'nuevos',
#    'incrementos',
#    'precios',
#    'bienes',
#    'servicios',
#    'presta'],
#   ['menos',
#    'parálisis',
#    'estancamiento',
#    'postración',
#    'nacional',
#    'encontramos'],
#   ['ahí', 'sale', 'bueno', 'señor'],
#   ['alejémonos',
#    'libros',
#    'texto',
#    'alejémonos',
#    'tesis',
#    'doctorado',
#    'pensemos',
#    'hombre'],
#   ['hagamos', 'detenernos', 'teoría', 'económica'],
#   ['sequía',
#    'financiera',
#    'promueve',
#    'banco',
#    'méxico',
#    'demoledora',
#    'inhumana',
#    'incendiaria'],
#   ['éxito',
#    'aplicación',
#    'fascista',
#    'entonces',
#    'mexicanos',
#    'demostrarle',
#    'catastróficos',
#    'errores',
#    'señor',
#    'ningún',
#    'caso',
#    'variaré',
#    'rumbo'],
#   ['paciente', 'sed', 'señor'],
#   ['démosle', 'agua', 'muera'],
#   ['sobra', 'sabemos', 'conveniente', 'señor', 'muerte'],
#   ['salvémosle', 'vida'],
#   ['disminución',
#    'circulante',
#    'coyuntura',
#    'económica',
#    'equivale',
#    'cerrar',
#    'llave',
#    'oxígeno',
#    'enfermo'],
#   ['desesperación',
#    'social',
#    'puede',
#    'desbordarse',
#    'cualquier',
#    'momento',
#    'produciendo',
#    'mal',
#    'mayor',
#    'quiere',
#    'evitar',
#    'semejante',
#    'política',
#    'económica'],
#   ['escuche',
#    'usted',
#    'señor',
#    'si',
#    'usted',
#    'desea',
#    'controlar',
#    'inflación',
#    'afectar',
#    'aún',
#    'marginados',
#    'logrará',
#    'posición',
#    'extremista',
#    'fanático',
#    'frenazo',
#    'lastimar',
#    'precisamente',
#    'usted',
#    'pretende',
#    'ayudar',
#    'toda',
#    'justicia'],
#   ['ningún', 'caso', 'variaré', 'rumbo'],
#   ['puede', 'haber', 'alzamientos', 'regionales'],
#   ['ningún', 'caso', 'variaré', 'rumbo'],
#   ['puede', 'haber', 'violencia', 'hambre', 'desesperación'],
#   ['corremos', 'peligro', 'injustificado'],
#   ['ningún', 'caso', 'variaré', 'rumbo', 'variaré', 'rumbo', 'aun', 'final'],
#   ['aun',
#    'final',
#    'ningún',
#    'caso',
#    'variaré',
#    'rumbo',
#    'cualquier',
#    'asunto',
#    'relacionado',
#    'autor',
#    'columna',
#    'favor',
#    'enviar',
#    'comunicación',
#    'fax',
#    'editorial',
#    'httpwwwexcelsiorcommxedihtml']],
#  [['lunes',
#    'abril',
#    'volatilidad',
#    'nociva',
#    'economía',
#    'mexicana',
#    'sigue',
#    'lograr',
#    'sistema',
#    'financiero',
#    'elimine',
#    'altos',
#    'niveles',
#    'volatilidad'],
#   ['según',
#    'centro',
#    'estudios',
#    'económicos',
#    'sector',
#    'privado',
#    'ceesp',
#    'problemas',
#    'sector',
#    'originaron',
#    'sólo',
#    'febrero',
#    'salieran',
#    'país',
#    'millones',
#    'dólares',
#    'cifra',
#    'equivalente',
#    'casi',
#    'millones',
#    'dólares',
#    'ingresado',
#    'enero',
#    'través',
#    'mercado',
#    'dinero',
#    'bolsa',
#    'valores'],
#   ['organismo',
#    'destaca',
#    'problemas',
#    'eslabón',
#    'débil',
#    'conflictivo',
#    'méxico'],
#   ['sistema',
#    'financiero',
#    'continúa',
#    'arrastrando',
#    'planta',
#    'productiva',
#    'hacia',
#    'contracción',
#    'endeudamiento',
#    'extremo'],
#   ['peor',
#    'aún',
#    'altas',
#    'tasas',
#    'interés',
#    'empujan',
#    'hacia',
#    'insolvencia',
#    'desempleo'],
#   ['hecho',
#    'encarecimiento',
#    'escasez',
#    'crédito',
#    'mayor',
#    'obstáculo',
#    'reactivación',
#    'desarrollo',
#    'país'],
#   ['sentido',
#    'estimaciones',
#    'ceesp',
#    'advierten',
#    'horizonte',
#    'económico',
#    'propicio',
#    'salgamos',
#    'crisis'],
#   ['datos',
#    'pronostica',
#    'después',
#    'abril',
#    'tasas',
#    'interés',
#    'reanuden',
#    'tendencia',
#    'baja'],
#   ['fenómeno',
#    'va',
#    'traducir',
#    'forzosamente',
#    'retraso',
#    'tan',
#    'anunciado',
#    'repunte',
#    'económico'],
#   ['además',
#    'reconoció',
#    'si',
#    'bien',
#    'valor',
#    'real',
#    'producto',
#    'interno',
#    'bruto',
#    'igualará',
#    'nivel',
#    'dentro',
#    'par',
#    'años',
#    'inversión',
#    'consumo',
#    'privado',
#    'requerirán',
#    'periodo',
#    'prolongado',
#    'recuperarse'],
#   ['lamentable',
#    'todavía',
#    'alturas',
#    'país',
#    'logre',
#    'abatir',
#    'desequilibrios',
#    'estructurales',
#    'economía',
#    'ello',
#    'crece',
#    'peligro',
#    'grave',
#    'crisis',
#    'social'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxedihtml']],
#  [['lunes',
#    'abril',
#    'larios',
#    'necesario',
#    'devaluar',
#    'considera',
#    'presidente',
#    'consejo',
#    'coordinador',
#    'empresarial',
#    'héctor',
#    'larios',
#    'santillán',
#    'reducción',
#    'mitad',
#    'servicio',
#    'deuda',
#    'externa',
#    'año',
#    'permitirá',
#    'empresas',
#    'disponer',
#    'mayores',
#    'recursos',
#    'económicos',
#    'invertir'],
#   ['punto',
#    'vista',
#    'puede',
#    'resultar',
#    'acertado',
#    'verse',
#    'empresas',
#    'inviertan'],
#   ['ahora',
#    'sólo',
#    'dicho',
#    'van',
#    'disponer',
#    'mayores',
#    'recursos',
#    'si',
#    'llegan',
#    'conseguirlos',
#    'empresarios',
#    'temen',
#    'mismo',
#    'gobierno',
#    'reprochan',
#    'poner',
#    'circular',
#    'dinero'],
#   ['máxime',
#    'aconsejable',
#    'sobrevaluación',
#    'peso',
#    'devaluación',
#    'menos',
#    'lenta',
#    'impone'],
#   ['larios',
#    'estima',
#    'debe',
#    'hacer',
#    'corregir',
#    'cifras',
#    'balanza',
#    'comercial',
#    'calcula',
#    'segundo',
#    'semestre',
#    'año',
#    'paridad',
#    'pesodólar',
#    'pasará',
#    'ó',
#    'unidad'],
#   ['sector',
#    'empresarial',
#    'pendiente',
#    'prefieren',
#    'conservar',
#    'dólares',
#    'invertir',
#    'pesos',
#    'nuevas',
#    'empresas'],
#   ['además',
#    'sector',
#    'cae',
#    'especulación',
#    'mismo',
#    'gobierno',
#    'pequeño',
#    'ahorrador',
#    'sabe',
#    'hacer'],
#   ['persiste', 'desconfianza'],
#   ['mientras', 'generan', 'nuevas', 'fuentes', 'empleo'],
#   ['cce',
#    'prevé',
#    'año',
#    'producto',
#    'interno',
#    'bruto',
#    'elevarse',
#    'inflación',
#    'aproximadamente',
#    'mitad',
#    'respecto',
#    'año',
#    'anterior'],
#   ['ojalá',
#    'cumpla',
#    'pues',
#    'viendo',
#    'cómo',
#    'aumentan',
#    'carencias',
#    'pueblo',
#    'crece',
#    'pobreza',
#    'llega',
#    'situaciones',
#    'críticas'],
#   ['debemos', 'pesimistas', 'tampoco', 'engañarnos', 'cosas', 'van', 'mejor'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxedihtml']],
#  [['lunes',
#    'abril',
#    'regaño',
#    'episcopal',
#    'caso',
#    'buenos',
#    'cristianos',
#    'semana',
#    'santa',
#    'mejor',
#    'dicho',
#    'debiera',
#    'motivo',
#    'honda',
#    'reflexión',
#    'sentido',
#    'crucifixión',
#    'muerte',
#    'jesús',
#    'pretexto',
#    'holganza',
#    'excesos',
#    'toda',
#    'índole'],
#   ['partir',
#    'ayer',
#    'domingo',
#    'ramos',
#    'ojalá',
#    'prevalecieran',
#    'humildad',
#    'virtudes',
#    'lamentablemente',
#    'olvidadas'],
#   ['sentido',
#    'arzobispo',
#    'méxico',
#    'pida',
#    'políticos',
#    'empresarios',
#    'líderes',
#    'sociales',
#    'mexicanos',
#    'debió',
#    'decir',
#    'mensaje',
#    'aunque',
#    'mayoría',
#    'pueda',
#    'atenderlo',
#    'dejar',
#    'lado',
#    'ostentación',
#    'prepotencia',
#    'lujos',
#    'innecesarios',
#    'ofenden',
#    'miseria',
#    'agobia',
#    'cientos',
#    'miles',
#    'familias'],
#   ['arzobispo',
#    'norberto',
#    'rivera',
#    'carrera',
#    'secundaron',
#    'obispos',
#    'felipe',
#    'arizmendi',
#    'javier',
#    'lozano',
#    'aprovecha',
#    'oportunidad',
#    'atacar',
#    'gobierno',
#    'hoy',
#    'moda',
#    'hagan',
#    'empresarios',
#    'hace',
#    'apoyaban',
#    'tono',
#    'impropio',
#    'dijo',
#    'sociedad',
#    'deben',
#    'lavarse',
#    'manos',
#    'tomar',
#    'decisiones',
#    'perversas',
#    'débiles',
#    'lesionen',
#    'realidad',
#    'millones',
#    'pobres',
#    'hambrientos',
#    'viven',
#    'largo',
#    'territorio',
#    'nacional'],
#   ['prelado',
#    'dice',
#    'debió',
#    'decir',
#    'gobierno',
#    'pues',
#    'sociedad',
#    'forma',
#    'parte',
#    'aquél'],
#   ['hecha',
#    'aclaración',
#    'cabe',
#    'preguntar',
#    'arzobispo',
#    'decisiones',
#    'perversas',
#    'pueden',
#    'tomar',
#    'tomado',
#    'gobierno',
#    'sociedad',
#    'perjuicio',
#    'pobres'],
#   ['quiere', 'decir', 'señalar', 'autoridades', 'deben', 'lavarse', 'manos'],
#   ['ahora',
#    'moda',
#    'clérigos',
#    'critiquen',
#    'poder',
#    'público',
#    'menos',
#    'debe',
#    'pedírsele',
#    'precisión',
#    'acusaciones'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxedihtml']],
#  [['lunes',
#    'abril',
#    'desalojos',
#    'violencia',
#    'prosiguen',
#    'chiapas',
#    'violencia',
#    'desalojos',
#    'invasiones',
#    'tierra',
#    'abuso',
#    'campesinado'],
#   ['terminarse',
#    'acuerdo',
#    'agrario',
#    'dotación',
#    'tierras',
#    'régimen',
#    'perdió',
#    'herramienta',
#    'control'],
#   ['últimos',
#    'dos',
#    'años',
#    'calcula',
#    'gobierno',
#    'estatal',
#    'destinado',
#    'debido',
#    'levantamiento',
#    'ezln',
#    'millones',
#    'pesos',
#    'compra',
#    'tierras',
#    'adjudicarlas',
#    'organizaciones',
#    'campesinas',
#    'apegadas',
#    'gobierno'],
#   ['detectado',
#    'muchas',
#    'irregularidades',
#    'aplicación',
#    'política',
#    'advierte',
#    'uso',
#    'mano',
#    'dura',
#    'tratan',
#    'apoderarse',
#    'pedazo',
#    'tierra',
#    'poder',
#    'vivir'],
#   ['problema',
#    'tierra',
#    'terminará',
#    'mientras',
#    'aplique',
#    'adecuadamente',
#    'justa',
#    'distribución',
#    'campos',
#    'miras',
#    'riqueza',
#    'producto',
#    'cultivo',
#    'equitativamente',
#    'distribuida'],
#   ['asignaciones',
#    'fondos',
#    'indemnizaciones',
#    'mal',
#    'controlados',
#    'convierten',
#    'recurso',
#    'enriquecimiento',
#    'ilegal',
#    'funcionarios'],
#   ['negocios', 'surgen', 'socaire', 'subvenciones'],
#   ['pagan', 'tierra'],
#   ['dan', 'muestras', 'mansedumbre', 'política', 'reciben', 'terreno'],
#   ['peor', 'represión', 'brutal', 'sigue', 'aumentando', 'lista', 'crímenes'],
#   ['enfrentamientos',
#    'impiden',
#    'adecuada',
#    'conciliación',
#    'intereses',
#    'diálogo',
#    'fructífero',
#    'establecer',
#    'firmemente',
#    'sistema',
#    'favorezca',
#    'sufridos',
#    'indígenas'],
#   ['respetar',
#    'propietarios',
#    'haciendas',
#    'respeto',
#    'merece',
#    'hambre',
#    'desventurados'],
#   ['editorial', 'nota', 'siguiente', 'httpwwwexcelsiorcommxexehtml']],
#  [['lunes',
#    'abril',
#    'salieron',
#    'país',
#    'millones',
#    'dls',
#    'febrero',
#    'ceesp',
#    'significan',
#    'casi',
#    'captado',
#    'enero',
#    'volatilidad',
#    'desequilibrios',
#    'financieros',
#    'extendieron',
#    'trimestre',
#    'después',
#    'abril',
#    'reanudarán',
#    'tasas',
#    'interés',
#    'tendencia',
#    'baja',
#    'prevé',
#    'apenas',
#    'valor',
#    'real',
#    'pib',
#    'igualará',
#    'nivel',
#    'logrado',
#    'embargo',
#    'inversión',
#    'consumo',
#    'privado',
#    'tardarán',
#    'tiempo',
#    'recuperarse',
#    'abatir',
#    'inflación',
#    'inducir',
#    'comportamiento',
#    'congruente',
#    'tipo',
#    'cambio',
#    'urge',
#    'fortalecer',
#    'actividades',
#    'productivas',
#    'gasto',
#    'puede',
#    'afectar',
#    'macroeconomía',
#    'resulta',
#    'pequeña',
#    'influencia',
#    'ejerce',
#    'aplicación',
#    'presupuesto',
#    'público',
#    'afirma',
#    'pide',
#    'reducir',
#    'carga',
#    'fiscal',
#    'fomento',
#    'industrial',
#    'mayor',
#    'impulso',
#    'exportaciones',
#    'alberto',
#    'navarrete',
#    'volatilidad',
#    'desequilibrios',
#    'financieros',
#    'primer',
#    'trimestre',
#    'año',
#    'originaron',
#    'sólo',
#    'febrero',
#    'salieran',
#    'país',
#    'millones',
#    'dólares',
#    'cifra',
#    'equivale',
#    'casi',
#    'ciento',
#    'millones',
#    'dólares',
#    'ingresado',
#    'enero',
#    'medio',
#    'mercado',
#    'dinero',
#    'bolsa',
#    'valores',
#    'reveló',
#    'centro',
#    'estudios',
#    'económicos',
#    'sector',
#    'privado',
#    'ceesp'],
#   ['reporte',
#    'información',
#    'básica',
#    'toma',
#    'decisiones',
#    'documento',
#    'carácter',
#    'restringido',
#    'organismo',
#    'iniciativa',
#    'privada',
#    'señaló',
#    'después',
#    'abril',
#    'tasas',
#    'intereses',
#    'reanuden',
#    'tendencia',
#    'baja'],
#   ['materia',
#    'crecimiento',
#    'económico',
#    'reconoció',
#    'si',
#    'bien',
#    'valor',
#    'real',
#    'producto',
#    'interno',
#    'bruto',
#    'igualará',
#    'nivel',
#    'dentro',
#    'par',
#    'años',
#    'inversión',
#    'consumo',
#    'privado',
#    'requerirán',
#    'periodo',
#    'prologado',
#    'recuperarse'],
#   ['ello',
#    'virtud',
#    'consumo',
#    'privado',
#    'decreció',
#    'ciento',
#    'significa',
#    'caída',
#    'veces',
#    'registrada',
#    'pib',
#    'mismo',
#    'año',
#    'comparación',
#    'parte',
#    'inversión',
#    'total',
#    'año',
#    'pasado',
#    'ciento',
#    'baja',
#    'hecho',
#    'situó',
#    'niveles',
#    'similares',
#    'significó',
#    'retroceso',
#    'cinco',
#    'años'],
#   ['acuerdo',
#    'organismo',
#    'análisis',
#    'empresarial',
#    'perspectivas',
#    'recuperación',
#    'económica',
#    'año',
#    'enfrentan',
#    'problemas',
#    'específicos'],
#   ['reto', 'actual', 'política', 'económica', 'doble'],
#   ['parte',
#    'dice',
#    'imprescindible',
#    'consolidar',
#    'estabilidad',
#    'principales',
#    'variables',
#    'financieras',
#    'abatir',
#    'presiones',
#    'inflacionarias',
#    'inducir',
#    'comportamiento',
#    'congruente',
#    'tipo',
#    'cambio',
#    'igualmente',
#    'urgente',
#    'actividades',
#    'productivas',
#    'fortalezcan',
#    'implicaría',
#    'utilizar',
#    'instrumentos',
#    'expansión',
#    'gasto',
#    'agregado',
#    'podrían',
#    'alterar',
#    'precario',
#    'equilibrio',
#    'macroeconómico'],
#   ['junto',
#    'tema',
#    'rezgo',
#    'aplicación',
#    'gasto',
#    'público',
#    'órgano',
#    'análisis',
#    'cúpula',
#    'empresarial',
#    'desmitifica',
#    'alcance',
#    'mismo',
#    'recursos',
#    'públicos'],
#   ['si',
#    'bien',
#    'gasto',
#    'público',
#    'puede',
#    'operar',
#    'disparador',
#    'catalizador',
#    'recuperación',
#    'influencia',
#    'desempeño',
#    'general',
#    'economía',
#    'pequeña',
#    'grado',
#    'presupuesto',
#    'total',
#    'gobierno',
#    'representa',
#    'equivalente',
#    'cuarta',
#    'parte',
#    'pib'],
#   ['ello',
#    'tomando',
#    'cuenta',
#    'gasto',
#    'federal',
#    'aumentará',
#    'términos',
#    'reales',
#    'respecto',
#    'realidad',
#    'desembolso',
#    'íntegro',
#    'representará',
#    'adición',
#    'neta',
#    'expansión',
#    'pib'],
#   ['estimulos',
#    'inversion',
#    'allá',
#    'mecanismos',
#    'corto',
#    'plazo',
#    'impidan',
#    'nuevas',
#    'alteraciones',
#    'mercados',
#    'financieros',
#    'sector',
#    'privado',
#    'sostiene',
#    'verdadera',
#    'recuperación',
#    'económica',
#    'deberá',
#    'originarse',
#    'resto',
#    'actividades',
#    'económicas',
#    'gubernamentales',
#    'reclama',
#    'acciones',
#    'inmediatas',
#    'estímulo',
#    'inversión',
#    'consumo',
#    'privado',
#    'disminución',
#    'carga',
#    'fiscal',
#    'política',
#    'industrial',
#    'fomento',
#    'además',
#    'impulso',
#    'indispensable',
#    'exportaciones'],
#   ['sólo',
#    'manera',
#    'posible',
#    'preparar',
#    'país',
#    'desequilibrios',
#    'nuevamente',
#    'presentó',
#    'principio',
#    'año',
#    'enero',
#    'mercados',
#    'financieros',
#    'arrancaron',
#    'perspectiva',
#    'diferente',
#    'permitió',
#    'ingreso',
#    'inversiones',
#    'extranjeras',
#    'mil',
#    'millones',
#    'dólares',
#    'bolsa',
#    'valores',
#    'millones',
#    'mercado',
#    'dinero'],
#   ['embargo',
#    'inestabilidad',
#    'febrero',
#    'ahuyentó',
#    'país',
#    'mil',
#    'millones',
#    'sector',
#    'bursátil',
#    'mil',
#    'millones',
#    'dólares',
#    'mercado',
#    'dinero'],
#   ['desafortunadamente',
#    'economía',
#    'mexicana',
#    'requiere',
#    'todavía',
#    'volumen',
#    'significativo',
#    'recursos',
#    'financieros',
#    'nacionales',
#    'extranjeros',
#    'debido',
#    'ello',
#    'vislumbra',
#    'disminución',
#    'consistente',
#    'tasas',
#    'interés'],
#   ['primera', 'plana', 'nota', 'siguiente', 'httpwwwexcelsiorcommxexehtml']],
#  [['lunes',
#    'abril',
#    'interminables',
#    'conflictos',
#    'agrarios',
#    'chiapas',
#    'invasiones',
#    'desalojos',
#    'muerte',
#    'recursos',
#    'destinados',
#    'regularización',
#    'desviados',
#    'botín',
#    'millones',
#    'funcionarios',
#    'particulares',
#    'hacienda',
#    'estatal',
#    'compras',
#    'irregulares',
#    'predios',
#    'persiste',
#    'inseguridad',
#    'tenencia',
#    'tierra',
#    'andres',
#    'becerril',
#    'enviado',
#    'iii',
#    'último',
#    'san',
#    'cristobal',
#    'casas',
#    'chis',
#    'marzocon',
#    'firma',
#    'acuerdo',
#    'agrario',
#    'declaración',
#    'chiapas',
#    'terminó',
#    'dotación',
#    'tierras',
#    'gobierno',
#    'perdió',
#    'herramienta',
#    'control',
#    'fundamental',
#    'posibilitó',
#    'espinoso',
#    'asunto',
#    'agrario',
#    'transforme',
#    'interminable',
#    'movimiento',
#    'político',
#    'severas',
#    'consecuencias',
#    'invasiones',
#    'desalojos',
#    'violencia',
#    'muerte'],
#   ['toda',
#    'historia',
#    'malas',
#    'cosechas',
#    'agro',
#    'entidad',
#    'padecido',
#    'sumarle',
#    'temporal',
#    'reciente',
#    'compra',
#    'tierras',
#    'desesperado',
#    'intento',
#    'atajar',
#    'caótica',
#    'situación',
#    'sólo',
#    'provocó',
#    'corrupción'],
#   ['calcula',
#    'últimos',
#    'dos',
#    'años',
#    'gobierno',
#    'estatal',
#    'destinado',
#    'regularización',
#    'agraria',
#    'merced',
#    'levantamiento',
#    'armado',
#    'ezln',
#    'millones',
#    'pesos',
#    'equivalentes',
#    'quinta',
#    'parte',
#    'deuda',
#    'estatal',
#    'cuales',
#    'millones',
#    'convirtieron',
#    'botín',
#    'negocio',
#    'redondo',
#    'funcionarios',
#    'públicos',
#    'particulares',
#    'sigue',
#    'prófugos',
#    'justicia'],
#   ['rodolfo',
#    'ulloa',
#    'flores',
#    'ex',
#    'secretario',
#    'gobierno',
#    'saúl',
#    'prado',
#    'guerrero',
#    'ex',
#    'coordinador',
#    'desarrollo',
#    'agrario',
#    'mandato',
#    'javier',
#    'lópez',
#    'moreno',
#    'acusados',
#    'actual',
#    'administración',
#    'chiapaneca',
#    'presuntos',
#    'responsables',
#    'fraude',
#    'millones',
#    'pesos',
#    'compra',
#    'tierras',
#    'existen',
#    'sendas',
#    'órdenes',
#    'aprehensión'],
#   ['millones',
#    'pesos',
#    'según',
#    'contraloría',
#    'general',
#    'gobierno',
#    'local',
#    'debieron',
#    'servir',
#    'compra',
#    'predios',
#    'mil',
# ...
#    'sonreir',
#    'importarle',
#    'problemas',
#    'artista'],
#   ['años',
#    'debutó',
#    'teatro',
#    'dos',
#    'semanas',
#    'ello',
#    'convirtió',
#    'figura',
#    'compañía'],
#   ['causó',
#    'placer',
#    'además',
#    'trabajó',
#    'lado',
#    'mejores',
#    'actores',
#    'directores'],
#   ['dijo',
#    'mayor',
#    'ilusión',
#    'después',
#    'muerta',
#    'público',
#    'recuerde',
#    'sonría',
#    'diga',
#    'delia',
#    'magaña',
#    'payasita',
#    'pobres',
#    'muchísimas',
#    'películas',
#    'obras',
#    'teatrales'],
#   ['deseo', 'nombre', 'perdure', 'compañeros', 'actores', 'fallecidos'],
#   ['ayer',
#    'murió',
#    'años',
#    'edad',
#    'horas',
#    'víctima',
#    'neumonía',
#    'sobrevino',
#    'complicársele',
#    'diabetes',
#    'padecía',
#    'hace',
#    'años'],
#   ['velada',
#    'agencia',
#    'funeraria',
#    'félix',
#    'cuevas',
#    'mañana',
#    'incinerada'],
#   ['cenizas',
#    'depositadas',
#    'cripta',
#    'familiar',
#    'iglesia',
#    'san',
#    'felipe',
#    'neri',
#    'ciudad',
#    'satélite'],
#   ['nacionales', 'nota', 'siguiente', 'httpwwwexcelsiorcommxnachtml']],
#  [['lunes',
#    'abril',
#    'ocaso',
#    'proyecto',
#    'nacional',
#    'fracaso',
#    'neoliberal',
#    'segunda',
#    'cuatro',
#    'partes',
#    'dr',
#    'javier',
#    'esteinou',
#    'madrid',
#    'crítica',
#    'situación',
#    'global',
#    'país',
#    'aplicación',
#    'modelo',
#    'neoliberal',
#    'llegado',
#    'tal',
#    'nivel',
#    'según',
#    'indicadores',
#    'oficiales',
#    'proyecto',
#    'neoliberal',
#    'conquistó',
#    'últimos',
#    'tiempos',
#    'siguientes',
#    'metas',
#    'deuda',
#    'externa',
#    'país',
#    'ascendió',
#    'millones',
#    'dólares',
#    'convertido',
#    'deuda',
#    'externa',
#    'deuda',
#    'eterna'],
#   ['economía',
#    'quedó',
#    'deriva',
#    'producto',
#    'interno',
#    'bruto',
#    'pib',
#    'retrocedió',
#    'principios',
#    'decía',
#    'orden',
#    'puntos',
#    'último',
#    'trimestre',
#    'empezaría',
#    'notar',
#    'sólida',
#    'recuperación'],
#   ['valor',
#    'peso',
#    'depreció',
#    'incapacidad',
#    'banco',
#    'méxico',
#    'defenderlo',
#    'tal',
#    'hizo',
#    'necesario',
#    'surgimiento',
#    'insólito',
#    'anteproyecto',
#    'privado',
#    'principales',
#    'grandes',
#    'empresarios',
#    'mexicanos',
#    'exportan',
#    'cemex',
#    'alfa',
#    'desc',
#    'vitro',
#    'peñoles',
#    'grupo',
#    'carso',
#    'kimberly',
#    'clark',
#    'grupo',
#    'méxico',
#    'formar',
#    'fondo',
#    'contingencia',
#    'osciló',
#    'millones',
#    'dólares',
#    'enfrentar',
#    'embates',
#    'especulativos',
#    'peso',
#    'fijar',
#    'piso',
#    'paridad',
#    'rescatar',
#    'valor',
#    'moneda',
#    'nivel',
#    'extremo',
#    'subvaluación',
#    'colocó'],
#   ['inflación', 'superó', 'proyectado', 'año', 'pasado'],
#   ['quebraron',
#    'grandes',
#    'instalaciones',
#    'fabriles',
#    'cerraron',
#    'micro',
#    'pequeñas',
#    'empresas',
#    'debido',
#    'altas',
#    'tasas',
#    'intereses',
#    'superaron',
#    'riesgo',
#    'constante',
#    'mayor',
#    'devaluación',
#    'peso',
#    'frente',
#    'dólar'],
#   ['ciento',
#    'negocios',
#    'restantes',
#    'sobrevivido',
#    'encuentran',
#    'graves',
#    'problemas',
#    'financieros',
#    'coloca',
#    'situación',
#    'virtual',
#    'quiebra',
#    'moratoria',
#    'económica',
#    'frente',
#    'trabajadores',
#    'bancos',
#    'fisco',
#    'pues',
#    'deuda',
#    'creció'],
#   ['planta',
#    'productiva',
#    'nacional',
#    'sobrevivido',
#    'trabaja',
#    'capacidad',
#    'consecuencia',
#    'falta',
#    'liquidez',
#    'monetaria',
#    'elevado',
#    'costo',
#    'dinero'],
#   ['planta',
#    'fabril',
#    'momentos',
#    'sólo',
#    'enfrenta',
#    'falta',
#    'mercado',
#    'liquidez',
#    'desplome',
#    'ventas',
#    'deudas',
#    'estratosféricas',
#    'banca',
#    'comercial',
#    'sino',
#    'ahora',
#    'encara',
#    'desabasto',
#    'materias',
#    'primas',
#    'debido',
#    'encarecimiento',
#    'brutal',
#    'divisas'],
#   ['total',
#    'mil',
#    'unidades',
#    'transporte',
#    'carga',
#    'país',
#    'tan',
#    'sólo',
#    'funcionando',
#    'baja',
#    'demanda',
#    'servicio',
#    'quedando',
#    'inactivas',
#    'mil',
#    'unidades'],
#   ['salario',
#    'mínimo',
#    'perdió',
#    'pérdida',
#    'poder',
#    'adquisitivo',
#    'últimos',
#    'años',
#    'suma',
#    'colocándose',
#    'bajos',
#    'mundo'],
#   ['ejemplo',
#    'mientras',
#    'unidos',
#    'trabajador',
#    'recibe',
#    'promedio',
#    'dólares',
#    'día',
#    'labor',
#    'méxico',
#    'solamente',
#    'recibe',
#    'dos',
#    'dólares'],
#   ['mano',
#    'obra',
#    'mexicana',
#    'recibe',
#    'menos',
#    'argentina',
#    'menos',
#    'colombia',
#    'menos',
#    'brasil',
#    'menos',
#    'india'],
#   ['crisis',
#    'modificó',
#    'distribución',
#    'ingreso',
#    'tal',
#    'forma',
#    'creció',
#    'proporción',
#    'trabajadores',
#    'menos',
#    'ingresos',
#    'bajó',
#    'participación',
#    'empleados',
#    'mayores',
#    'niveles',
#    'salariales'],
#   ['ejemplo',
#    'porcentaje',
#    'población',
#    'ocupada',
#    'ingresos',
#    'menores',
#    'salario',
#    'mínimo',
#    'pasó',
#    'diciembre',
#    'agosto',
#    'mismo',
#    'periodo',
#    'trabajadores',
#    'ocupados',
#    'ganan',
#    'dos',
#    'salarios',
#    'mínimos',
#    'aumentó'],
#   ['contrario', 'ganan', 'dos', 'cinco', 'salarios', 'mínimos', 'bajó'],
#   ['decir',
#    'raíz',
#    'crisis',
#    'enfrenta',
#    'país',
#    'trabajadores',
#    'ganan',
#    'menos',
#    'menos',
#    'ganan'],
#   ['abandono',
#    'proyecto',
#    'agropecuario',
#    'últimas',
#    'décadas',
#    'ocasionó',
#    'después',
#    'haber',
#    'país',
#    'exportador',
#    'granos',
#    'ahora',
#    'perdido',
#    'seguridad',
#    'alimentaria',
#    'convertido',
#    'nación',
#    'importadora',
#    'miles',
#    'toneladas',
#    'anuales',
#    'alimentos'],
#   ['generó',
#    'nivel',
#    'productividad',
#    'ramo',
#    'bajara',
#    'dejaran',
#    'cultivar',
#    'mil',
#    'hectáreas',
#    'granos',
#    'básicos',
#    'provocando',
#    'importación',
#    'millones',
#    'toneladas',
#    'maíz',
#    'millones',
#    'habitantes',
#    'dependemos',
#    'importación',
#    'alimentos'],
#   ['ejemplo',
#    'simplemente',
#    'maíz',
#    'importar',
#    'millón',
#    'toneladas',
#    'completar',
#    'nutrición',
#    'sociedad'],
#   ['ello',
#    'alrededor',
#    'superficie',
#    'agrícola',
#    'país',
#    'ciclo',
#    'primaveraverano',
#    'quedó',
#    'cultivarse',
#    'incosteabilidad',
#    'falta',
#    'apoyo',
#    'financiero',
#    'sector',
#    'población',
#    'campesina',
#    'quedó',
#    'marginada',
#    'beneficios',
#    'proyecto',
#    'modernizador'],
#   ['ocasionó',
#    'últimos',
#    'seis',
#    'años',
#    'menos',
#    'productores',
#    'rurales',
#    'diariamente',
#    'abandonaran',
#    'actividad',
#    'campesina',
#    'emigrando',
#    'ciudades',
#    'unidos',
#    'reduciéndose',
#    'drásticamente',
#    'producción',
#    'principales',
#    'cultivos',
#    'nacionales'],
#   ['sector',
#    'bancario',
#    'enfrentó',
#    'peor',
#    'crisis',
#    'años',
#    'treinta',
#    'salir',
#    'desastre',
#    'financiero',
#    'recibió',
#    'apoyos',
#    'oficiales',
#    'millones',
#    'nuevos',
#    'pesos',
#    'millones',
#    'dólares',
#    'vía',
#    'fondo',
#    'bancario',
#    'protección',
#    'ahorro',
#    'fobaproa',
#    'equivalen',
#    'producto',
#    'interno',
#    'bruto',
#    'estimado'],
#   ['embargo',
#    'obstante',
#    'apoyo',
#    'monumental',
#    'recuperación',
#    'banca',
#    'utilidades',
#    'bajaron'],
#   ['significa',
#    'sobrevivir',
#    'sistemaenancario',
#    'todavía',
#    'requiere',
#    'apoyos',
#    'adicionales',
#    'mil',
#    'millones',
#    'nuevos',
#    'pesos',
#    'ligeramente',
#    'superiores',
#    'pib',
#    'pues',
#    'carteras',
#    'vencidas',
#    'seguido',
#    'creciendo',
#    'notablemente'],
#   ['ejemplo',
#    'resultado',
#    'aplicación',
#    'elevadas',
#    'tasas',
#    'interés',
#    'cartera',
#    'vencida',
#    'sistema',
#    'bancario',
#    'mexicano',
#    'gobiernos',
#    'estatales',
#    'municipios',
#    'país',
#    'creció',
#    'primeros',
#    'ocho',
#    'meses',
#    'administración',
#    'presidente',
#    'ernesto',
#    'zedillo',
#    'colocando',
#    'mayoría',
#    'municipios',
#    'virtual',
#    'quiebra',
#    'financiera',
#    'pese',
#    'esquemas',
#    'reestructuración',
#    'adeudos',
#    'impulsados',
#    'banca',
#    'estatal',
#    'privada'],
#   ['cartera',
#    'vencida',
#    'créditos',
#    'generales',
#    'crecieron',
#    'cartera',
#    'vencida',
#    'agro',
#    'creció',
#    'términos',
#    'nominales',
#    'cartera',
#    'vencida',
#    'créditos',
#    'corporativos',
#    'creció',
#    'otorgamiento',
#    'crédito',
#    'desplomó',
#    'país'],
#   ['desempleo',
#    'abierto',
#    'duplicó',
#    'alcanzando',
#    'personas',
#    'población',
#    'económicamente',
#    'activa',
#    'provocando',
#    'primeros',
#    'seis',
#    'meses',
#    'gobierno',
#    'pérdida',
#    'empleos',
#    'generados',
#    'últimos',
#    'años',
#    'desocupación',
#    'rural',
#    'urbana'],
#   ['ello',
#    'sector',
#    'informal',
#    'economía',
#    'crecido',
#    'últimos',
#    'años',
#    'dejando',
#    'subempleo',
#    'millones',
#    'personas'],
#   ['promedio',
#    'escolarización',
#    'país',
#    'permanece',
#    'año',
#    'primaria',
#    'mental',
#    'meta',
#    'conseguido',
#    'época',
#    'superado',
#    'términos',
#    'reales',
#    'metas',
#    'revolución',
#    'educativa',
#    'josé',
#    'vasconcelos',
#    'profundizada',
#    'lázaro',
#    'cárdenas',
#    'sino',
#    'acentuado',
#    'deterioro',
#    'calidad',
#    'educación',
#    'global'],
#   ['notas'],
#   ['inflación',
#    'caerá',
#    'pib',
#    'abascal',
#    'excelsior',
#    'octubre',
#    'persistente',
#    'retroceso',
#    'desarrollo',
#    'económico',
#    'financiero',
#    'octubre',
#    'crecimiento',
#    'realmente',
#    'vigoroso',
#    'mediados',
#    'gom',
#    'excelsior',
#    'noviembre',
#    'alcanzará',
#    'caída',
#    'pib',
#    'cierre',
#    'valenzuela',
#    'financiero',
#    'diciembre',
#    'pib',
#    'desplomará',
#    'excelsior',
#    'diciembre'],
#   [],
#   ['fondo',
#    'millones',
#    'dólares',
#    'defender',
#    'peso',
#    'propondrán',
#    'exportadores',
#    'excelsior',
#    'noviembre',
#    'economía',
#    'deriva',
#    'excelsior',
#    'diciembre'],
#   [],
#   ['inflación',
#    'alza',
#    'tarifas',
#    'públicas',
#    'secretaría',
#    'hacienda',
#    'excelsior',
#    'noviembre'],
#   [],
#   ['cerraron',
#    'mil',
#    'pequeñas',
#    'empresas',
#    'país',
#    'excelsior',
#    'diciembre'],
#   [],
#   ['casi',
#    'quiebra',
#    'mil',
#    'empresas',
#    'bancos',
#    'pueden',
#    'paralizar',
#    'planta',
#    'productiva',
#    'salcedo',
#    'excelsior',
#    'septiembre',
#    'empresas',
#    'problemas',
#    'financieros',
#    'ip',
#    'excelsior',
#    'octubre',
#    'desempleo',
#    'millones',
#    'inflación',
#    'cierre',
#    'mil',
#    'empresas',
#    'ip',
#    'excelsior',
#    'octubre',
#    'industrias',
#    'riesgo',
#    'moratoria',
#    'general',
#    'alerta',
#    'canacintra',
#    'financiero',
#    'octubre',
#    'problemas',
#    'empresas',
#    'afirma',
#    'coparmex',
#    'excelsior',
#    'octubre',
#    'industria',
#    'borde',
#    'moratoria',
#    'financiero',
#    'noviembre',
#    'incompatible',
#    'modelo',
#    'necesidades',
#    'planta',
#    'fabril',
#    'financiero',
#    'noviembre',
#    'moratoria',
#    'obligada',
#    'empresas',
#    'país',
#    'ane',
#    'excelsior',
#    'noviembre',
#    'peso',
#    'devaluó',
#    'cerraron',
#    'mil',
#    'empresas',
#    'excelsior',
#    'diciembre',
#    'sectores',
#    'productivos',
#    'pared',
#    'deuda',
#    'creció',
#    'financiero',
#    'diciembre',
#    'quiebra',
#    'planta',
#    'productiva',
#    'financiero',
#    'diciembre',
#    'dicha',
#    'situación',
#    'tan',
#    'grave',
#    'simplemente',
#    'mayo',
#    'quebraron',
#    'país',
#    'micro',
#    'pequeñas',
#    'industrias',
#    'consecuencia',
#    'apertura',
#    'comercial',
#    'crisis',
#    'generada',
#    'política',
#    'neoliberal'],
#   ['quebraron',
#    'fábricas',
#    'méxico',
#    'últimos',
#    'años',
#    'uanl',
#    'excelsior',
#    'septiembre',
#    'caída',
#    'demanda',
#    'prendas',
#    'vestir',
#    'provocó',
#    'quiebra',
#    'menos',
#    'empresas',
#    'desocupados',
#    'cayeron',
#    'ventas',
#    'industria',
#    'vestido',
#    'cniv',
#    'excelsior',
#    'noviembre',
#    'primeros',
#    'meses',
#    'cerrado',
#    'puertas',
#    'menos',
#    'farmacias',
#    'independientes',
#    'país',
#    'concecuencia',
#    'actual',
#    'crisis',
#    'económica'],
#   ['cierran',
#    'puertas',
#    'farmacias',
#    'país',
#    'va',
#    'año',
#    'canaco',
#    'universal',
#    'noviembre',
#    'sector',
#    'restaurantero',
#    'quebrado',
#    'empresas',
#    'quedado',
#    'desempleados',
#    'personas'],
#   ['van',
#    'desempleados',
#    'ramo',
#    'restaurantero',
#    'país',
#    'excelsior',
#    'octubre'],
#   [],
#   ['mermada', 'planta', 'productiva', 'financiero', 'octubre'],
#   [],
#   ['inicia', 'desabasto', 'materias', 'primas', 'financiero', 'noviembre'],
#   [],
#   ['inactivas',
#    'mil',
#    'unidades',
#    'transporte',
#    'carga',
#    'méxico',
#    'excelsior',
#    'noviembre'],
#   ['acelerado',
#    'deterioro',
#    'salario',
#    'mínimo',
#    'año',
#    'universal',
#    'noviembre',
#    'salario',
#    'mínimo',
#    'bajos',
#    'mundo',
#    'excelsior',
#    'noviembre',
#    'cae',
#    'salario',
#    'industrial',
#    'niveles',
#    'universal',
#    'diciembre'],
#   [],
#   ['modifica', 'crisis', 'distribución', 'ingresos', 'universal', 'noviembre'],
#   [],
#   ['bajó',
#    'producción',
#    'agro',
#    'aumentó',
#    'emigración',
#    'eu',
#    'lópez',
#    'g',
#    'universal',
#    'diciembre',
#    'recuperación',
#    'agropecuaria',
#    'requerirá',
#    'varios',
#    'años',
#    'labastida',
#    'jornada',
#    'diciembre'],
#   [],
#   ['importarán', 'año', 'toneladas', 'maíz', 'universal', 'enero'],
#   [],
#   ['desaparecen',
#    'empresas',
#    'universal',
#    'octubre',
#    'ociosa',
#    'superficie',
#    'agrícola',
#    'universal',
#    'octubre'],
#   [],
#   ['abandonaron',
#    'diario',
#    'labor',
#    'productores',
#    'rurales',
#    'seis',
#    'años',
#    'universal',
#    'febrero'],
#   [],
#   ['banca',
#    'enfrenta',
#    'peor',
#    'crisis',
#    'años',
#    'treinta',
#    'excelsior',
#    'diciembre',
#    'millones',
#    'costo',
#    'oficial',
#    'rescate',
#    'banca',
#    'universal',
#    'diciembre',
#    'inevitable',
#    'rescate',
#    'bancos',
#    'universal',
#    'diciembre'],
#   [],
#   ['cayeron', 'utilidades', 'bancarias', 'excelsior', 'diciembre'],
#   [],
#   ['necesita',
#    'banca',
#    'n$',
#    'mil',
#    'millones',
#    'superar',
#    'crisis',
#    'inverlat',
#    'financiero',
#    'diciembre'],
#   [],
#   ['asfixian',
#    'réditos',
#    'financiero',
#    'octubre',
#    'perversión',
#    'economía',
#    'elevar',
#    'tasas',
#    'retener',
#    'capitales',
#    'pacheco',
#    's',
#    'excelsior',
#    'noviembre'],
#   [],
#   ['cartera', 'vencida', 'creció', 'excelsior', 'diciembre'],
#   [],
#   ['cartera',
#    'vencida',
#    'agro',
#    'banc',
#    'áprivada',
#    'creció',
#    'jornada',
#    'diciembre',
#    'frena',
#    'agro',
#    'elevada',
#    'cartera',
#    'vencida',
#    'cna',
#    'universal',
#    'diciembre'],
#   [],
#   ['nuevo',
#    'impulso',
#    'cartera',
#    'vencida',
#    'llega',
#    'áócfel',
#    'financiero',
#    'diciembre'],
#   [],
#   ['disminuyó', 'crédito', 'bancario', 'nacional', 'excelsior', 'diciembre'],
#   [],
#   ['perdidos',
#    'meses',
#    'empleos',
#    'generados',
#    'años',
#    'sindicatos',
#    'excelsior',
#    'septiembre',
#    'economía',
#    'informal',
#    'empleo',
#    'pea',
#    'financiero',
#    'septiembre',
#    'crecido',
#    'sector',
#    'informal',
#    'últimos',
#    'seis',
#    'años',
#    'rosado',
#    'garcía',
#    'universal',
#    'octubre',
#    'alcanza',
#    'desempleo',
#    'millones',
#    'universal',
#    'octubre',
#    'millones',
#    'mexicanos',
#    'viven',
#    'subempleo',
#    'excelsior',
#    'octubre',
#    'llegó',
#    'desempleo',
#    'índice',
#    'alto',
#    'inegi',
#    'excelsior',
#    'noviembre',
#    'duplicó',
#    'año',
#    'tasa',
#    'nacional',
#    'desempleo',
#    'abierto',
#    'diciembre',
#    'simplemente',
#    'jalisco',
#    'enero',
#    'fecha',
#    'perdido',
#    'puestos',
#    'trabajo',
#    'registrados',
#    'instituto',
#    'mexicano',
#    'seguro',
#    'social',
#    'imss'],
#   ['freno',
#    'desempleo',
#    'jalisco',
#    'puestos',
#    'perdidos',
#    'excelsior',
#    'noviembre'],
#   [],
#   ['permanece',
#    'años',
#    'nivel',
#    'escolaridad',
#    'méxico',
#    'meta',
#    'alcanzada',
#    'financiero',
#    'febrero',
#    'nacionales']]]

# %% [markdown]
# ## Topics Distribution with Gensim
#
# Once we have completed our preprocessing, it's time to apply the functions which gensim provides us.

# %% [markdown]
# First we are going to try with all the articles of the selected text file.

# %%
from gensim import corpora
import gensim

# %%
lemmatized_articles_docs = list()
for item1 in lemmatized_articles:
    docs = list()
    for item2 in item1:
        docs = docs + item2
    lemmatized_articles_docs.append(docs)

# %%
lemmatized_articles_docs
# Out:
# [['martes',
#   'abril',
#   'monstruosa',
#   'diferencia',
#   'colosistas',
#   'colosismo',
#   'luis',
#   'gutierrez',
#   'gonzalez',
#   'luis',
#   'gutiérrez',
#   'sotomayor',
#   'federico',
#   'arreola',
#   'colosistas',
#   'cabales',
#   'según',
#   'dijo',
#   'amigo',
#   'luis',
#   'donaldo',
#   'ciertamente',
#   'nombre',
#   'circunstancias',
#   'luis',
#   'donaldo',
#   'colosio',
#   'llenado',
#   'insistentemente',
#   'volúmenes',
#   'espacios',
#   'medios',
#   'comunicación',
#   'renovada',
#   'actualidad',
#   'padecido',
#   'frenético',
#   'vaivén',
#   'ficciones',
#   'judiciales',
#   'políticas',
#   'integran',
#   'disgregan',
#   'metafísicas',
#   'metafísicas',
#   'aún',
#   'luis',
#   'donaldo',
#   'desprende',
#   'envuelve',
#   'lado',
#   'espejo',
#   'dos',
#   'años',
#   'eternos',
#   'insolvencias',
#   'dale',
#   'dale',
#   'fantasía',
#   'magia',
#   'dónde',
#   'quedó',
#   'bolita',
#   'traído',
#   'pueblo',
#   'hastío',
#   'cansancio',
#   'inminencia',
#   'percibe',
#   'váyanse',
#   'diablo',
#   'quórum',
#   'nacional',
#   'veía',
#   'decidido',
#   'instalar',
#   'sécula',
#   'seculórum',
#   'demandas',
#   'justicia',
#   'segundo',
#   'aniversario',
#   'asesinato',
#   'colosismo',
#   'astroso',
#   'luto',
#   'protagónico',
#   'intentado',
#   'empapar',
#   'drama',
#   'colosista',
#   'espesas',
#   'negras',
#   'lágrimas',
#   'llorona',
#   'profesional',
#   'velorio',
#   'antigüita',
#   'diciéndose',
#   'heredero',
#   'ideas',
#   'derechos',
#   'supuesto',
#   'paradigma',
#   'trampa',
#   'tendió',
#   'esotérico',
#   'colosismo',
#   'presidente',
#   'zedillo',
#   'ponce',
#   'león',
#   'amigo',
#   'líder',
#   'mandatario',
#   'dedica',
#   'culto',
#   'seguimiento',
#   'espirituales',
#   'dándole',
#   'satisfacción',
#   'compromisos',
#   'políticos',
#   'aquel',
#   'contrajo',
#   'actitud',
#   'moral',
#   'propició',
#   'trampa',
#   'fulano',
#   'zutano',
#   'dijeron',
#   'discípulos',
#   'hermanos',
#   'compañeros',
#   'lucha',
#   'asesores',
#   'caído',
#   'veras',
#   'hicieron',
#   'lado',
#   'vieron',
#   'cargar',
#   'don',
#   'ernesto',
#   'tropel',
#   'búfalos',
#   'llora',
#   'mama',
#   'colosistas',
#   'supieron',
#   'quisieron',
#   'vergüenza',
#   'confundidos',
#   'pegarse',
#   'ubre',
#   'mal',
#   'hicieron',
#   'colosismo',
#   'repartió',
#   'mercedes',
#   'presidenciales',
#   'parteaguas',
#   'brecha',
#   'insondable',
#   'separando',
#   'colosistas',
#   'colosismo',
#   'bandos',
#   'luis',
#   'donaldo',
#   'llamaba',
#   'dijo',
#   'nombres',
#   'respectivos',
#   'cabales',
#   'oportunistas',
#   'efeméride',
#   'dolorosa',
#   'colosismo',
#   'intentó',
#   'constituirse',
#   'dogma',
#   'doctrina',
#   'credo',
#   'político',
#   'allá',
#   'magdalena',
#   'leyendo',
#   'lumpen',
#   'histriónico',
#   'viendo',
#   'protagonismos',
#   'don',
#   'luis',
#   'colosio',
#   'venció',
#   'garruda',
#   'presencia',
#   'hilaridad',
#   'incontenible',
#   'colosismo',
#   'bah',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'scalfaro',
#   'aquí',
#   'allá',
#   'juan',
#   'maria',
#   'alponte',
#   'julio',
#   'villa',
#   'gagia',
#   'benito',
#   'mussolini',
#   'recibía',
#   'adolf',
#   'hitler',
#   'viajara',
#   'tren',
#   'italia',
#   'someter',
#   'dictador',
#   'italiano',
#   'larga',
#   'furiosa',
#   'requisitoria',
#   'comportamiento',
#   'manifiestamente',
#   'malo',
#   'dice',
#   'tropas',
#   'italianas',
#   'alemanes',
#   'sienten',
#   'heridos',
#   'julio',
#   'sicilia',
#   'desembarcado',
#   'angloamericanos',
#   'base',
#   'militar',
#   'augusta',
#   'rendido',
#   'hitler',
#   'exasperado',
#   'quiere',
#   'aceptar',
#   'italianos',
#   'quieren',
#   'combatir',
#   'mediodía',
#   'día',
#   'entrevista',
#   'cortada',
#   'secretario',
#   'duce',
#   'portaba',
#   'telegrama',
#   'voz',
#   'emocionada',
#   'mussolini',
#   'traduce',
#   'alemán',
#   'momento',
#   'enemigo',
#   'bombardea',
#   'roma',
#   'muertos',
#   'heridos',
#   'julio',
#   'palacio',
#   'venecia',
#   'produjo',
#   'partir',
#   'cinco',
#   'tarde',
#   'aquel',
#   'sábado',
#   'sombrío',
#   'acontecimientos',
#   'insólitos',
#   'viera',
#   'italia',
#   'día',
#   'duce',
#   'preside',
#   'así',
#   'cree',
#   'reunión',
#   'rutina',
#   'gran',
#   'consejo',
#   'fascista',
#   'rutina',
#   'gran',
#   'consejo',
#   'aprobará',
#   'moción',
#   'extraordinaria',
#   'moción',
#   'grandi',
#   'dejándole',
#   'minoría',
#   'pidiendo',
#   'poderes',
#   'posee',
#   'duce',
#   'traspasen',
#   'rey',
#   'día',
#   'siguiente',
#   'domingo',
#   'mussolini',
#   'acude',
#   'palacio',
#   'real',
#   'mientras',
#   'escucha',
#   'calles',
#   'abbasso',
#   'mussolini',
#   'rey',
#   'alertado',
#   'desposee',
#   'poderes',
#   'momento',
#   'duro',
#   'blando',
#   'dice',
#   'monarca',
#   'allora',
#   'tutto',
#   'finito',
#   'sera',
#   'della',
#   'mia',
#   'famiglia',
#   'comporta',
#   'piccolo',
#   'borghese',
#   'grandeza',
#   'advenedizo',
#   'poder',
#   'ustedes',
#   'saben',
#   'italia',
#   'mussolini',
#   'pasaría',
#   'aliados',
#   'alemanes',
#   'duce',
#   'apresado',
#   'partisanos',
#   'fusilado',
#   'huida',
#   'junio',
#   'país',
#   'referéndum',
#   'elegía',
#   'instituciones',
#   'italianos',
#   'votaron',
#   'república',
#   'monarquía',
#   'consagrara',
#   'marcia',
#   'roma',
#   'famosa',
#   'marcha',
#   'roma',
#   'mussolini',
#   'fascios',
#   'combate',
#   'convirtiéndole',
#   'jefe',
#   'gobierno',
#   'comenzaba',
#   'italia',
#   'edad',
#   'partidos',
#   'consagrando',
#   'democracia',
#   'cristiana',
#   'partido',
#   'mayoritario',
#   'mayoría',
#   'relativa',
#   'formarían',
#   'coaliciones',
#   'gubernamentales',
#   'tempestades',
#   'posguerra',
#   'nación',
#   'italiana',
#   'pese',
#   'fragilidad',
#   'gobiernos',
#   'realizaría',
#   'hazañas',
#   'notables',
#   'económicas',
#   'industriales',
#   'mundo',
#   'actual',
#   'convertido',
#   'siete',
#   'grandes',
#   'millones',
#   'habitantes',
#   'crecimiento',
#   'demográfico',
#   'ingreso',
#   'persona',
#   'dólares',
#   'exportaciones',
#   'alcanzaron',
#   'impresionante',
#   'suma',
#   'millones',
#   'dólares',
#   'importaciones',
#   'millones',
#   'unas',
#   'elecciones',
#   'históricas',
#   'derrumbaba',
#   'régimen',
#   'partitocrazia',
#   'entrarse',
#   'verdadera',
#   'definición',
#   'estabilidad',
#   'enterraba',
#   'pasado',
#   'presente',
#   'fortalecido',
#   'presidente',
#   'oscar',
#   'luigi',
#   'scalfaro',
#   'extraordinaria',
#   'inteligencia',
#   'mesura',
#   'dirigido',
#   'periodo',
#   'complejo',
#   'gobierno',
#   'apresta',
#   'elecciones',
#   'decisivas',
#   'próximo',
#   'mes',
#   'abril',
#   'ello',
#   'momento',
#   'mismo',
#   'italia',
#   'ocupa',
#   'presidencia',
#   'rotativa',
#   'seis',
#   'meses',
#   'europa',
#   'scalfaro',
#   'hoy',
#   'asciende',
#   'nivel',
#   'hombres',
#   'crear',
#   'cenizas',
#   'primera',
#   'república',
#   'cimientos',
#   'segunda',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'jabón',
#   'olor',
#   'suprema',
#   'lavamanos',
#   'javier',
#   'romero',
#   'cada',
#   'habla',
#   'feria',
#   'según',
#   'va',
#   'tan',
#   'socorrido',
#   'refrán',
#   'eleva',
#   'veces',
#   'cimas',
#   'políticas',
#   'quién',
#   'definitiva',
#   'favoreció',
#   'fallo',
#   'corte',
#   'suprema',
#   'diferendo',
#   'gobernador',
#   'tabasco',
#   'procurador',
#   'república',
#   'juzgar',
#   'reacciones',
#   'cada',
#   'habla',
#   'según',
#   'intereses',
#   'simpatías',
#   'antipatías',
#   'políticas',
#   'mismo',
#   'dice',
#   'madrazo',
#   'seco',
#   'madrazo',
#   'salió',
#   'bien',
#   'librado',
#   'declara',
#   'empate',
#   'cierto',
#   'asunto',
#   'originó',
#   'ardid',
#   'aporreado',
#   'gobernador',
#   'esperaba',
#   'diera',
#   'pie',
#   'verso',
#   'forzado',
#   'ir',
#   'dilucidando',
#   'papel',
#   'corte',
#   'tribunal',
#   'legalidad',
#   'queda',
#   'aún',
#   'veremos',
#   'sobreseimiento',
#   'esencial',
#   'suprema',
#   'eludió',
#   'fondo',
#   'intríngulis',
#   'vulgar',
#   'mil',
#   'veces',
#   'dijo',
#   'pasado',
#   'supremos',
#   'juristas',
#   'optaron',
#   'lavarse',
#   'manos',
#   'aunque',
#   'ahora',
#   'despidan',
#   'olor',
#   'jabón',
#   'fino',
#   'atisbaron',
#   'palangana',
#   'través',
#   'grietas',
#   'procedimiento',
#   'dijérase',
#   'aferran',
#   'tesis',
#   'viejos',
#   'constituyentes',
#   'deseaban',
#   'corte',
#   'impoluta',
#   'nunca',
#   'manchada',
#   'mezquindades',
#   'sucia',
#   'política',
#   'pese',
#   'vivirse',
#   'tiempo',
#   'pide',
#   'canta',
#   'real',
#   'vigencia',
#   'triada',
#   'poderes',
#   'constitucionales',
#   'sometimientos',
#   'hace',
#   'buen',
#   'titipuchal',
#   'años',
#   'mero',
#   'presidente',
#   'además',
#   'caudillo',
#   'obregón',
#   'puso',
#   'suprema',
#   'brete',
#   'antecesor',
#   'huerta',
#   'dejado',
#   'efecto',
#   'desconocimiento',
#   'gobernador',
#   'michoacán',
#   'decretado',
#   'senado',
#   'evidentes',
#   'trampas',
#   'obregón',
#   'quiso',
#   'embarcar',
#   'corte',
#   'pidió',
#   'dilucidar',
#   'embrollo',
#   'seguro',
#   'seguiría',
#   'aversión',
#   'múgica',
#   'suprema',
#   'enjabonada',
#   'dijo',
#   'incompetente',
#   'dejar',
#   'desafío',
#   'fuerza',
#   'caudillesca',
#   'duraron',
#   'aquellos',
#   'tenues',
#   'arrestos',
#   'autonomía',
#   'prudente',
#   'día',
#   'pleno',
#   'maximato',
#   'callista',
#   'suprema',
#   'dio',
#   'baño',
#   'cuerpo',
#   'entero',
#   'evadió',
#   'escándalo',
#   'demandaba',
#   'intervenir',
#   'destierro',
#   'luis',
#   'cabrera',
#   'reo',
#   'conferencia',
#   'crítica',
#   'célebre',
#   'rasgo',
#   'pundonor',
#   'ministro',
#   'alberto',
#   'vázquez',
#   'mercado',
#   'tiró',
#   'toga',
#   'hacerse',
#   'cómplice',
#   'prudencia',
#   'miedo',
#   'dudé',
#   'celebrada',
#   'nueva',
#   'independencia',
#   'informe',
#   'zedillo',
#   'observé',
#   'nunca',
#   'vistas',
#   'jamás',
#   'oídas',
#   'carantoñas',
#   'presidente',
#   'suprema',
#   'don',
#   'aguinaco',
#   'prodigaba',
#   'supremo',
#   'señor',
#   'lambiscón',
#   'diputados',
#   'pensé',
#   'acaso',
#   'emilio',
#   'rabasa',
#   'negaba',
#   'judicial',
#   'carácter',
#   'poder',
#   'reducía',
#   'departamento',
#   'jurídico',
#   'parece',
#   'resucitar',
#   'ahora',
#   'fallo',
#   'salomónico',
#   'aforismo',
#   'leguleyos',
#   'corte',
#   'vence',
#   'convence',
#   'esperemos',
#   'mejores',
#   'pruebas',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'dinero',
#   'banqueros',
#   'santiago',
#   'genoves',
#   'pena',
#   'mala',
#   'pena',
#   'quisiera',
#   'quitara',
#   'vino',
#   'vienen',
#   'saber',
#   'dónde',
#   'agua',
#   'mares',
#   'flores',
#   'mayo',
#   'vientos',
#   'bosque',
#   'vino',
#   'quedado',
#   'corazón',
#   'amargo',
#   'corteza',
#   'verde',
#   'verde',
#   'limón',
#   'respeto',
#   'elevada',
#   'investidura',
#   'parece',
#   'hombre',
#   'bueno',
#   'honesto',
#   'bienintencionado',
#   'trabajador',
#   'siento',
#   'simpatía',
#   'hacia',
#   'señor',
#   'presidente',
#   'zedillo',
#   'vámonos',
#   'hacia',
#   'pasado',
#   'ex',
#   'salinas',
#   'apenas',
#   'si',
#   'tardíamente',
#   'llegó',
#   'bordes',
#   'chiapas',
#   'unas',
#   'horas',
#   'sólo',
#   'decimos',
#   'méxico',
#   'taparle',
#   'ojo',
#   'macho',
#   'salía',
#   'inmediato',
#   'suiza',
#   'gran',
#   'reunión',
#   'banqueros',
#   'allí',
#   'pues',
#   'pretendía',
#   'aunque',
#   'viento',
#   'marea',
#   'pasar',
#   'presidente',
#   'omc',
#   'poderoso',
#   'caballero',
#   'don',
#   'dinero',
#   'ayer',
#   'dijo',
#   'pascual',
#   'si',
#   'casó',
#   'inés',
#   'interés',
#   'sino',
#   'capital',
#   'presidente',
#   'zedillo',
#   'europa',
#   'fundamentalmente',
#   'trató',
#   'aspectos',
#   'económicofinancieros',
#   'hace',
#   'unas',
#   'semanas',
#   'lix',
#   'convención',
#   'banca',
#   'cancún',
#   'así',
#   'pasada',
#   'convención',
#   'chiapas',
#   'ezln',
#   'dice',
#   'querida',
#   'amiga',
#   'rosario',
#   'guerra',
#   'excelsior',
#   'si',
#   'truena',
#   'sistema',
#   'financiero',
#   'tronamos',
#   'amiga',
#   'rosario',
#   'si',
#   'rompe',
#   'puente',
#   'podemos',
#   'atravesarlo',
#   'remo',
#   'barca',
#   'panga',
#   'manera',
#   'actuar',
#   'quebraron',
#   'miles',
#   'medianas',
#   'micro',
#   'empresas',
#   'quedaron',
#   'trabajo',
#   'cientos',
#   'miles',
#   'mexicanos',
#   'salvó',
#   'navío',
#   'casi',
#   'nadie',
#   'viva',
#   'convención',
#   'cancún',
#   'sólo',
#   'banqueros',
#   'economistas',
#   'financieros',
#   'políticos',
#   'disponiendo',
#   'vidas',
#   'sociólogos',
#   'psicólogos',
#   'filósofos',
#   'etcétera',
#   'allí',
#   'lugar',
#   'tratándose',
#   'trató',
#   'fondo',
#   'vida',
#   'social',
#   'méxico',
#   'zea',
#   'gonzález',
#   'casanova',
#   'sánchez',
#   'sosa',
#   'etcétera',
#   'decir',
#   'creo',
#   'mayor',
#   'parte',
#   'ésta',
#   'pena',
#   'pena',
#   'dinero',
#   'dinero',
#   'dinero',
#   'chiapas',
#   'apenas',
#   'si',
#   'cuenta',
#   'cuenta',
#   'convención',
#   'banqueros',
#   'allí',
#   'debió',
#   'sobrio',
#   'sabio',
#   'sergio',
#   'peña',
#   'historia',
#   'capitalismo',
#   'méxico',
#   'erradísimo',
#   'error',
#   'ello',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'nacionalista',
#   'natalio',
#   'vázquez',
#   'pallares',
#   'oscar',
#   'gonzalez',
#   'lopez',
#   'marzo',
#   'hace',
#   'quince',
#   'años',
#   'brusca',
#   'intempestivamente',
#   'terminó',
#   'fecunda',
#   'vida',
#   'mexicano',
#   'excepcional',
#   'nacido',
#   'coalcomán',
#   'población',
#   'tarasca',
#   'cuna',
#   'compatriota',
#   'ilustre',
#   'ricardo',
#   'torres',
#   'gaytán',
#   'relación',
#   'estrecha',
#   'fructífera',
#   'michoacán',
#   'patria',
#   'llamó',
#   'llama',
#   'natalio',
#   'vázquez',
#   'pallares',
#   'cardenista',
#   'años',
#   'máximo',
#   'fulgor',
#   'revolución',
#   'mexicana',
#   'cardenista',
#   'después',
#   'cardenista',
#   'siempre',
#   'natalio',
#   'combatiente',
#   'lúcido',
#   'tenaz',
#   'últimos',
#   'días',
#   'páginas',
#   'editoriales',
#   'excelsior',
#   'dejó',
#   'claras',
#   'enseñanzas',
#   'historia',
#   'patria',
#   'sobradas',
#   'muestras',
#   'capacidad',
#   'teórica',
#   'crear',
#   'desarrollar',
#   'tesis',
#   'fundamentales',
#   'proyecto',
#   'constitucional',
#   'desarrollo',
#   'febrero',
#   'nacionalismo',
#   'revolucionario',
#   'reconquista',
#   'méxico',
#   'delineadas',
#   'textos',
#   'originales',
#   'artículos',
#   'tercero',
#   'carta',
#   'magana',
#   'elaborada',
#   'representantes',
#   'pueblo',
#   'armas',
#   'triunfante',
#   'formidable',
#   'insurrección',
#   'dictadura',
#   'porfirista',
#   'siniestro',
#   'renuevo',
#   'golpistas',
#   'febrero',
#   'polichinelas',
#   'henry',
#   'lane',
#   'wilson',
#   'embajador',
#   'imperio',
#   'generales',
#   'bien',
#   'vistos',
#   'buenas',
#   'conciencias',
#   'jerarquía',
#   'católica',
#   'natalio',
#   'surgió',
#   'dirigente',
#   'juvenil',
#   'legendario',
#   'mítico',
#   'frente',
#   'estudiantil',
#   'socialista',
#   'occidente',
#   'luego',
#   'convergencia',
#   'primaveral',
#   'confederación',
#   'jóvenes',
#   'méxico',
#   'ingresó',
#   'gusto',
#   'orgullo',
#   'partido',
#   'revolución',
#   'mexicana',
#   'renovación',
#   'espléndida',
#   'pnr',
#   'callista',
#   'instinto',
#   'popular',
#   'advirtió',
#   'transformación',
#   'prm',
#   'pri',
#   'significaba',
#   'advenimiento',
#   'pandilla',
#   'contrarrevolucionaria',
#   'enemiga',
#   'agraristas',
#   'corrientes',
#   'sindicales',
#   'comunista',
#   'lombardista',
#   'pandilla',
#   'alemanista',
#   'fuerza',
#   'incontrastable',
#   'cardenismo',
#   'presente',
#   'junio',
#   'llevó',
#   'pesar',
#   'encono',
#   'grupo',
#   'comandado',
#   'jarocho',
#   'sayula',
#   'candidatura',
#   'diputación',
#   'federal',
#   'primavera',
#   'triunfó',
#   'ampliamente',
#   'necesidad',
#   'casillas',
#   'zapato',
#   'acarreo',
#   'votantes',
#   'carruseles',
#   'taqueos',
#   'compra',
#   'votos',
#   'hoy',
#   'quince',
#   'años',
#   'partida',
#   'física',
#   'natalio',
#   'recordamos',
#   'conducta',
#   'viril',
#   'gallarda',
#   'actitud',
#   'diputado',
#   'federal',
#   'denunciar',
#   'calidad',
#   'presidente',
#   'comisión',
#   'petróleo',
#   'cámara',
#   'diputados',
#   'firma',
#   'contratos',
#   'riesgo',
#   'pemex',
#   'compañías',
#   'privadas',
#   'estadunidenses',
#   'artículos',
#   'memorables',
#   'escritos',
#   'verano',
#   'aportó',
#   'legó',
#   'tarea',
#   'patriótica',
#   'rango',
#   'histórico',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'medios',
#   'educación',
#   'pasa',
#   'allí',
#   'margarita',
#   'michelena',
#   'casi',
#   'mismo',
#   'tiempo',
#   'contribuyentes',
#   'descubríamos',
#   'hermanita',
#   'procurador',
#   'lozano',
#   'gracia',
#   'anda',
#   'paseando',
#   'protegida',
#   'escolta',
#   'guaruras',
#   'mientras',
#   'humildes',
#   'ciudadanos',
#   'despanzurra',
#   'delincuente',
#   'cualquier',
#   'esquina',
#   'doctor',
#   'zedillo',
#   'decía',
#   'claro',
#   'medios',
#   'debían',
#   'vehículos',
#   'educación',
#   'moralización',
#   'pueblo',
#   'tan',
#   'cierto',
#   'hablemos',
#   'ahora',
#   'medios',
#   'particularmente',
#   'televisión',
#   'radio',
#   'televisión',
#   'ir',
#   'ahora',
#   'dañoso',
#   'hace',
#   'sino',
#   'atentar',
#   'valores',
#   'moral',
#   'inteligencia',
#   'ahí',
#   'ir',
#   'lejos',
#   'programas',
#   'deleznables',
#   'hoy',
#   'daniela',
#   'suelen',
#   'presentarse',
#   'individuillos',
#   'toda',
#   'laya',
#   'días',
#   'apareció',
#   'pantalla',
#   'golfales',
#   'importación',
#   'llamada',
#   'martha',
#   'sánchez',
#   'ningún',
#   'respeto',
#   'público',
#   'relató',
#   'chiste',
#   'soez',
#   'todas',
#   'letras',
#   'cuya',
#   'causa',
#   'todavía',
#   'arden',
#   'muchas',
#   'orejas',
#   'violación',
#   'ley',
#   'federal',
#   'radio',
#   'televisión',
#   'bastado',
#   'tiempos',
#   'programa',
#   'cosa',
#   'llaman',
#   'programa',
#   'saliera',
#   'aire',
#   'ipso',
#   'facto',
#   'toda',
#   'televisión',
#   'buena',
#   'parte',
#   'radio',
#   'invadidas',
#   'cosas',
#   'inmundas',
#   'intimamente',
#   'shanik',
#   'cada',
#   'vez',
#   'abundantes',
#   'programas',
#   'nota',
#   'roja',
#   'digan',
#   'si',
#   'toda',
#   'basura',
#   'solo',
#   'programa',
#   'informe',
#   'cultive',
#   'salvo',
#   'programas',
#   'noticiosos',
#   'telenovelas',
#   'vehículo',
#   'seguro',
#   'llenar',
#   'masa',
#   'imbecilidades',
#   'ahí',
#   'va',
#   'premio',
#   'mayor',
#   'maría',
#   'barrio',
#   'dos',
#   'bodrios',
#   'debería',
#   'vergonzoso',
#   'transmitir',
#   'visto',
#   'existe',
#   'monitoreo',
#   'alguno',
#   'autoridad',
#   'competente',
#   'material',
#   'utilizado',
#   'televisión',
#   'manera',
#   'vergüenzas',
#   'públicas',
#   'llegarían',
#   'hogares',
#   'así',
#   'podría',
#   'hablar',
#   'competencias',
#   'refiriéndose',
#   'televisión',
#   'azteca',
#   'buena',
#   'ley',
#   'posible',
#   'compradores',
#   'privados',
#   'canales',
#   'hacen',
#   'sino',
#   'copiar',
#   'mal',
#   'televisa',
#   'dos',
#   'grandes',
#   'canales',
#   'pasan',
#   'material',
#   'calidad',
#   'veces',
#   'maravillosa',
#   'gracia',
#   'pues',
#   'trata',
#   'frecuencias',
#   'pagadas',
#   'gobierno',
#   'medios',
#   'masivos',
#   'comunicación',
#   'refería',
#   'presidente',
#   'día',
#   'cumplía',
#   'años',
#   'organización',
#   'televisión',
#   'iberoamericana',
#   'oti',
#   'señor',
#   'cañedo',
#   'trató',
#   'aprovechar',
#   'viaje',
#   'toro',
#   'arrancar',
#   'presidente',
#   'elogios',
#   'funesta',
#   'obra',
#   'televisión',
#   'privada',
#   'cierto',
#   'público',
#   'necesita',
#   'entretenimiento',
#   'confundir',
#   'diversión',
#   'degradación',
#   'somete',
#   'auditorio',
#   'muchísimas',
#   'horas',
#   'diarias',
#   'presentándole',
#   'cosas',
#   'aberrantes',
#   'si',
#   'tratara',
#   'natural',
#   'correcto',
#   'mundo',
#   'sazonado',
#   'despropósitos',
#   'crean',
#   'falsos',
#   'ídolos',
#   'falsos',
#   'valores',
#   'vemos',
#   'forma',
#   'cumple',
#   'televisión',
#   'primero',
#   'cometidos',
#   'educar',
#   'cuenta',
#   'recursos',
#   'si',
#   'descontamos',
#   'talento',
#   'así',
#   'muestras',
#   'escatología',
#   'violencia',
#   'fomenta',
#   'conducta',
#   'delictuosa',
#   'sofocados',
#   'hora',
#   'pedir',
#   'cuentas',
#   'televisión',
#   'privada',
#   'fechorías',
#   'impunes',
#   'causas',
#   'ésta',
#   'contaminado',
#   'ambiente',
#   'moral',
#   'vamos',
#   'malviviendo',
#   'menos',
#   'momento',
#   'televisión',
#   'privada',
#   'funciona',
#   'concesiones',
#   'federales',
#   'dicho',
#   'correspondencia',
#   'apartado',
#   'postal',
#   'ciudad',
#   'número',
#   'fax',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'camino',
#   'hambruna',
#   'tocar',
#   'fondo',
#   'fernando',
#   'cesarman',
#   'mazorca',
#   'dobla',
#   'frecuencia',
#   'escuchamos',
#   'discursos',
#   'economistas',
#   'políticos',
#   'tocamos',
#   'fondo',
#   'podemos',
#   'hundirnos',
#   'crisis',
#   'quién',
#   'sabe',
#   'tocar',
#   'fondo',
#   'hoy',
#   'vivimos',
#   'amenaza',
#   'brotes',
#   'hambruna',
#   'gravedad',
#   'crisis',
#   'económica',
#   'sumada',
#   'tremendas',
#   'sequías',
#   'norte',
#   'insuficiencia',
#   'producción',
#   'alimentos',
#   'erosión',
#   'tierra',
#   'muerte',
#   'ganado',
#   'falta',
#   'previsión',
#   'evitar',
#   'catástrofes',
#   'llevan',
#   'rincones',
#   'hambruna',
#   'cuándo',
#   'toca',
#   'fondo',
#   'terrible',
#   'despertarnos',
#   'noticia',
#   'sierra',
#   'tal',
#   'lugar',
#   'grupo',
#   'pobladores',
#   'comer',
#   'causa',
#   'sequía',
#   'condiciones',
#   'políticas',
#   'extrema',
#   'pobreza',
#   'deforestación',
#   'arroyos',
#   'secos',
#   'esqueletos',
#   'chivos',
#   'gente',
#   'hambre',
#   'niños',
#   'flacos',
#   'madres',
#   'huesudas',
#   'hombres',
#   'viejos',
#   'transparentes',
#   'hambrunas',
#   'brutales',
#   'sufren',
#   'profunda',
#   'vergüenza',
#   'pueblos',
#   'padecen',
#   'hambrunas',
#   'encuentran',
#   'extremo',
#   'espectro',
#   'ecocidio',
#   'suceden',
#   'desequilibrio',
#   'hombre',
#   'paisaje',
#   'total',
#   'destrozo',
#   'casa',
#   'final',
#   'utópica',
#   'fantasía',
#   'armonía',
#   'hombre',
#   'medio',
#   'fracaso',
#   'sociedad',
#   'fracaso',
#   'sistemas',
#   'políticos',
#   'fracaso',
#   'humillación',
#   'humanismo',
#   'contenido',
#   'proyectos',
#   'patria',
#   'sucedió',
#   'sierra',
#   'tarahumara',
#   'sigue',
#   'sucediendo',
#   'hace',
#   'dos',
#   'años',
#   'presenciamos',
#   'drama',
#   'hambre',
#   'sierra',
#   'pronta',
#   'reacción',
#   'autoridades',
#   'embargo',
#   'problema',
#   'continúa',
#   'regado',
#   'toda',
#   'superficie',
#   'país',
#   'rincón',
#   'escape',
#   'presencia',
#   'niños',
#   'adultos',
#   'desnutridos',
#   'padecen',
#   'hambre',
#   'crónica',
#   'aumento',
#   'precio',
#   'productos',
#   'alimenticios',
#   'básicos',
#   'leche',
#   'azúcar',
#   'ahora',
#   'tortilla',
#   'acelera',
#   'escasez',
#   'alimentos',
#   'habitantes',
#   'pobres',
#   'declaraciones',
#   'oficiales',
#   'justifican',
#   'aumentos',
#   'terminar',
#   'costosos',
#   'subsidios',
#   'pronto',
#   'después',
#   'años',
#   'dado',
#   'cuenta',
#   'regulan',
#   'precios',
#   'controlan',
#   'subsidios',
#   'subsidios',
#   'beneficiaban',
#   'salarios',
#   'adecuados',
#   'además',
#   'existía',
#   'corrupción',
#   'manejo',
#   'sabíamos',
#   'economistas',
#   'sino',
#   'sólo',
#   'tratamos',
#   'entender',
#   'dificultades',
#   'manejo',
#   'dinero',
#   'perspectivas',
#   'subsidios',
#   'regalo',
#   'población',
#   'sino',
#   'simplemente',
#   'forma',
#   'compensar',
#   'pésimos',
#   'salarios',
#   'así',
#   'malos',
#   'ingresos',
#   'podía',
#   'adquirir',
#   'cantidad',
#   'adecuada',
#   'productos',
#   'subsidiados',
#   'además',
#   'podían',
#   'utilizar',
#   'servicios',
#   'subsidiados',
#   'transporte',
#   'hoy',
#   'enfrentamos',
#   'grave',
#   'situación',
#   'subsidios',
#   'tienden',
#   'eliminados',
#   'sueldos',
#   'siguen',
#   'raquíticos',
#   'aún',
#   'deplorables',
#   'subida',
#   'precios',
#   'aquellos',
#   'insumos',
#   'subsidiados',
#   'constituye',
#   'catástrofe',
#   'ecológica',
#   'pobreza',
#   'signo',
#   'degradación',
#   'posibilidad',
#   'pueblo',
#   'conseguir',
#   'pobreza',
#   'escasez',
#   'productos',
#   'indispensables',
#   'subsistencia',
#   'grave',
#   'además',
#   'precios',
#   'predicciones',
#   'producción',
#   'granos',
#   'embargo',
#   'absurdamente',
#   'tranquilos',
#   'si',
#   'pasara',
#   'grave',
#   'vivir',
#   'geranios',
#   'tierra',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'hace',
#   'años',
#   'abril',
#   'fuerzas',
#   'estadunidenses',
#   'británicas',
#   'registraron',
#   'casas',
#   'poblaciones',
#   'situadas',
#   'parte',
#   'occidental',
#   'alemania',
#   'austria',
#   'objeto',
#   'detener',
#   'cerca',
#   'mil',
#   'alemanes',
#   'sospecha',
#   'implicados',
#   'rebelión',
#   'nazi',
#   'ninguno',
#   'soldados',
#   'resultó',
#   'herido',
#   'sindicato',
#   'trabajadores',
#   'industria',
#   'cinematográfica',
#   'perdió',
#   'laudo',
#   'laboral',
#   'sindicato',
#   'encabezado',
#   'cantinflas',
#   'jorge',
#   'negrete',
#   'según',
#   'segunda',
#   'agrupación',
#   'podrá',
#   'filmar',
#   'películas',
#   'interpuso',
#   'recurso',
#   'obligó',
#   'juez',
#   'primero',
#   'distrito',
#   'administrativo',
#   'licenciado',
#   'ponciano',
#   'hernández',
#   'ortega',
#   'pedir',
#   'presidente',
#   'república',
#   'diga',
#   'si',
#   'opinión',
#   'emitida',
#   'respecto',
#   'conflicto',
#   'cinematografistas',
#   'simple',
#   'opinión',
#   'decir',
#   'si',
#   'características',
#   'fallo',
#   'arbitral',
#   'ello',
#   'dependerá',
#   'justicia',
#   'federal',
#   'decida',
#   'si',
#   'amparo',
#   'promovido',
#   'stic',
#   'laudo',
#   'procedente',
#   'vez',
#   'organizados',
#   'legalmente',
#   'concluida',
#   'estructura',
#   'administrativa',
#   'partidos',
#   'políticos',
#   'sólo',
#   'quedan',
#   'candidatos',
#   'presidenciales',
#   'fuerza',
#   'debidamente',
#   'organizada',
#   'licenciados',
#   'miguel',
#   'alemán',
#   'ezequiel',
#   'padilla',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'hace',
#   'años',
#   'teniente',
#   'william',
#   'calley',
#   'sentenciado',
#   'cadena',
#   'perpetua',
#   'tribunal',
#   'militar',
#   'juzgó',
#   'considerarlo',
#   'culpable',
#   'asesinato',
#   'menos',
#   'hombres',
#   'mujeres',
#   'niños',
#   'vietnamitas',
#   'my',
#   'lai',
#   'hace',
#   'tres',
#   'años',
#   'apelación',
#   'automática',
#   'trámite',
#   'puede',
#   'demorar',
#   'varios',
#   'meses',
#   'presidente',
#   'tribunal',
#   'coronel',
#   'reid',
#   'kennedy',
#   'dijo',
#   'jurados',
#   'leer',
#   'veredicto',
#   'comprendo',
#   'señores',
#   'agonía',
#   'debieron',
#   'haber',
#   'pasado',
#   'ustedes',
#   'mismos',
#   'oficiales',
#   'agradezco',
#   'luego',
#   'ordenó',
#   'escribano',
#   'lectura',
#   'veredicto',
#   'teniente',
#   'william',
#   'calley',
#   'presidente',
#   'corte',
#   'deber',
#   'informarle',
#   'tribunal',
#   'condena',
#   'encarcelado',
#   'trabajos',
#   'forzados',
#   'tiempo',
#   'dure',
#   'vida',
#   'natural',
#   'dado',
#   'baja',
#   'ejército',
#   'privado',
#   'haberes',
#   'indemnizaciones',
#   'calley',
#   'puesto',
#   'pie',
#   'cuadró',
#   'militarmente',
#   'escuchar',
#   'sentencia',
#   'reacción',
#   'cadena',
#   'caracterizó',
#   'campañas',
#   'anulado',
#   'veredicto',
#   'elevación',
#   'protesta',
#   'funcionarios',
#   'así',
#   'solicitudes',
#   'formales',
#   'clemencia',
#   'militares',
#   'ex',
#   'soldados',
#   'personas',
#   'hijos',
#   'peleando',
#   'vietnam',
#   'parte',
#   'hombre',
#   'nueva',
#   'york',
#   'envió',
#   'telegrama',
#   'decía',
#   'cuelguen',
#   'calley',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml'],
#  ['martes',
#   'abril',
#   'ningún',
#   'caso',
#   'modificaré',
#   'rumbo',
#   'cuentos',
#   'políticos',
#   'francisco',
#   'martin',
#   'moreno',
#   'señor',
#   'respondió',
#   'coro',
#   'unísono',
#   'si',
#   'echamos',
#   'andar',
#   'economía',
#   'aun',
#   'lograrlo',
#   'aumentar',
#   'índices',
#   'inflación',
#   'podría',
#   'aumentar',
#   'peligrosamente',
#   'efervescencia',
#   'social',
#   'podemos',
#   'señor',
#   'tener',
#   'disciplina',
#   'nación',
#   'desarrollada',
#   'requiere',
#   'encontrar',
#   'dosis',
#   'término',
#   'medio',
#   'crecer',
#   'ir',
#   'dominando',
#   'gradualmente',
#   'inflación',
#   'ningún',
#   'caso',
#   'variaré',
#   'rumbo',
#   'señor',
#   'vivimos',
#   'estanflación',
#   'mezcla',
#   'explosiva',
#   'estancamiento',
#   'económico',
#   'inflación',
#   'peor',
#   'dos',
#   'mundos',
#   'empresas',
#   'difícilmente',
#   'podrán',
#   'resistir',
#   'tiempo',
#   'oxígeno',
#   'crédito',
#   'ventas',
#   'recuperación',
#   'cartera',
#   'escasamente',
#   'hacen',
#   'negocios',
#   'pocos',
#   'pocos',
#   'dinero',
#   'pocos',
#   'pocos',
#   'cumplen',
#   'obligaciones',
#   'bancarias',
#   'fiscales',
#   'insuficiencia',
#   'financiera',
#   'generan',
#   'utilidades',
#   'ende',
#   'causan',
#   'impuestos',
#   'empresas',
#   'pobres',
#   'fisco',
#   'pobre',
#   'país',
#   'pobre',
#   'señor',
#   'inaplazable',
#   'gaste',
#   'gobierno',
#   'acertada',
#   'medianía',
#   'empezar',
#   'crecer',
#   'ningún',
#   'caso',
#   'variaré',
#   'rumbo',
#   'señor',
#   'usted',
#   'razonable',
#   'correcto',
#   'hacer',
#   'cualquier',
#   'esfuerzo',
#   'tal',
#   'detener',
#   'inflación',
#   'dañar',
#   'altísimo',
#   'impuesto',
#   'social',
#   'comunidad',
#   'sólo',
#   'empresas',
#   'sólo',
#   'contratan',
#   'nadie',
#   'sino',
#   'despiden',
#   'masivamente',
#   'personal',
#   'tal',
#   'sobrevivir',
#   'gente',
#   'pierde',
#   'empleos',
#   'asfixia',
#   'económica',
#   'impotencia',
#   'financiera',
#   'extremo',
#   'poder',
#   'pagar',
#   'colegiatura',
#   'hijos',
#   'constituye',
#   'duda',
#   'invitación',
#   'violencia',
#   'pronto',
#   'escoger',
#   'control',
#   'inflación',
#   'manifestaciones',
#   'urbanas',
#   'ciudadanos',
#   'dispuestos',
#   'familias',
#   'perezcan',
#   'hambre',
#   'ningún',
#   'caso',
#   'variaré',
#   'rumbo',
#   'suelte',
#   'gasto',
#   'señor',
#   'suéltelo',
#   'aun',
#   'conceder',
#   'aumentos',
#   'salariales',
#   'suframos',
#   'nuevos',
#   'incrementos',
#   'precios',
#   'bienes',
#   'servicios',
#   'presta',
#   'menos',
#   'parálisis',
#   'estancamiento',
#   'postración',
#   'nacional',
#   'encontramos',
#   'ahí',
#   'sale',
#   'bueno',
#   'señor',
#   'alejémonos',
#   'libros',
#   'texto',
#   'alejémonos',
#   'tesis',
#   'doctorado',
#   'pensemos',
#   'hombre',
#   'hagamos',
#   'detenernos',
#   'teoría',
#   'económica',
#   'sequía',
#   'financiera',
#   'promueve',
#   'banco',
#   'méxico',
#   'demoledora',
#   'inhumana',
#   'incendiaria',
#   'éxito',
#   'aplicación',
#   'fascista',
#   'entonces',
#   'mexicanos',
#   'demostrarle',
#   'catastróficos',
#   'errores',
#   'señor',
#   'ningún',
#   'caso',
#   'variaré',
#   'rumbo',
#   'paciente',
#   'sed',
#   'señor',
#   'démosle',
#   'agua',
#   'muera',
#   'sobra',
#   'sabemos',
#   'conveniente',
#   'señor',
#   'muerte',
#   'salvémosle',
#   'vida',
#   'disminución',
#   'circulante',
#   'coyuntura',
#   'económica',
#   'equivale',
#   'cerrar',
#   'llave',
#   'oxígeno',
#   'enfermo',
#   'desesperación',
#   'social',
#   'puede',
#   'desbordarse',
#   'cualquier',
#   'momento',
#   'produciendo',
#   'mal',
#   'mayor',
#   'quiere',
#   'evitar',
#   'semejante',
#   'política',
#   'económica',
#   'escuche',
#   'usted',
#   'señor',
#   'si',
#   'usted',
#   'desea',
#   'controlar',
#   'inflación',
#   'afectar',
#   'aún',
#   'marginados',
#   'logrará',
#   'posición',
#   'extremista',
#   'fanático',
#   'frenazo',
#   'lastimar',
#   'precisamente',
#   'usted',
#   'pretende',
#   'ayudar',
#   'toda',
#   'justicia',
#   'ningún',
#   'caso',
#   'variaré',
#   'rumbo',
#   'puede',
#   'haber',
#   'alzamientos',
#   'regionales',
#   'ningún',
#   'caso',
#   'variaré',
#   'rumbo',
#   'puede',
#   'haber',
#   'violencia',
#   'hambre',
#   'desesperación',
#   'corremos',
#   'peligro',
#   'injustificado',
#   'ningún',
#   'caso',
#   'variaré',
#   'rumbo',
#   'variaré',
#   'rumbo',
#   'aun',
#   'final',
#   'aun',
#   'final',
#   'ningún',
#   'caso',
#   'variaré',
#   'rumbo',
#   'cualquier',
#   'asunto',
#   'relacionado',
#   'autor',
#   'columna',
#   'favor',
#   'enviar',
#   'comunicación',
#   'fax',
#   'editorial',
#   'httpwwwexcelsiorcommxedihtml'],
#  ['lunes',
#   'abril',
#   'volatilidad',
#   'nociva',
#   'economía',
#   'mexicana',
#   'sigue',
#   'lograr',
#   'sistema',
#   'financiero',
#   'elimine',
#   'altos',
#   'niveles',
#   'volatilidad',
#   'según',
#   'centro',
#   'estudios',
#   'económicos',
#   'sector',
#   'privado',
#   'ceesp',
#   'problemas',
#   'sector',
#   'originaron',
#   'sólo',
#   'febrero',
#   'salieran',
#   'país',
#   'millones',
#   'dólares',
#   'cifra',
#   'equivalente',
#   'casi',
#   'millones',
#   'dólares',
#   'ingresado',
#   'enero',
#   'través',
#   'mercado',
#   'dinero',
#   'bolsa',
#   'valores',
#   'organismo',
#   'destaca',
#   'problemas',
#   'eslabón',
#   'débil',
#   'conflictivo',
#   'méxico',
#   'sistema',
#   'financiero',
#   'continúa',
#   'arrastrando',
#   'planta',
#   'productiva',
#   'hacia',
#   'contracción',
#   'endeudamiento',
#   'extremo',
#   'peor',
#   'aún',
#   'altas',
#   'tasas',
#   'interés',
#   'empujan',
#   'hacia',
#   'insolvencia',
#   'desempleo',
#   'hecho',
#   'encarecimiento',
#   'escasez',
#   'crédito',
#   'mayor',
#   'obstáculo',
#   'reactivación',
#   'desarrollo',
#   'país',
#   'sentido',
#   'estimaciones',
#   'ceesp',
#   'advierten',
#   'horizonte',
#   'económico',
#   'propicio',
#   'salgamos',
#   'crisis',
#   'datos',
#   'pronostica',
#   'después',
#   'abril',
#   'tasas',
#   'interés',
#   'reanuden',
#   'tendencia',
#   'baja',
#   'fenómeno',
#   'va',
#   'traducir',
#   'forzosamente',
#   'retraso',
#   'tan',
#   'anunciado',
#   'repunte',
#   'económico',
#   'además',
#   'reconoció',
#   'si',
#   'bien',
#   'valor',
#   'real',
#   'producto',
#   'interno',
#   'bruto',
#   'igualará',
#   'nivel',
#   'dentro',
#   'par',
#   'años',
#   'inversión',
#   'consumo',
#   'privado',
#   'requerirán',
#   'periodo',
#   'prolongado',
#   'recuperarse',
#   'lamentable',
#   'todavía',
#   'alturas',
#   'país',
#   'logre',
#   'abatir',
#   'desequilibrios',
#   'estructurales',
#   'economía',
#   'ello',
#   'crece',
#   'peligro',
#   'grave',
#   'crisis',
#   'social',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxedihtml'],
#  ['lunes',
#   'abril',
#   'larios',
#   'necesario',
#   'devaluar',
#   'considera',
#   'presidente',
#   'consejo',
#   'coordinador',
#   'empresarial',
#   'héctor',
#   'larios',
#   'santillán',
#   'reducción',
#   'mitad',
#   'servicio',
#   'deuda',
#   'externa',
#   'año',
#   'permitirá',
#   'empresas',
#   'disponer',
#   'mayores',
#   'recursos',
#   'económicos',
#   'invertir',
#   'punto',
#   'vista',
#   'puede',
#   'resultar',
#   'acertado',
#   'verse',
#   'empresas',
#   'inviertan',
#   'ahora',
#   'sólo',
#   'dicho',
#   'van',
#   'disponer',
#   'mayores',
#   'recursos',
#   'si',
#   'llegan',
#   'conseguirlos',
#   'empresarios',
#   'temen',
#   'mismo',
#   'gobierno',
#   'reprochan',
#   'poner',
#   'circular',
#   'dinero',
#   'máxime',
#   'aconsejable',
#   'sobrevaluación',
#   'peso',
#   'devaluación',
#   'menos',
#   'lenta',
#   'impone',
#   'larios',
#   'estima',
#   'debe',
#   'hacer',
#   'corregir',
#   'cifras',
#   'balanza',
#   'comercial',
#   'calcula',
#   'segundo',
#   'semestre',
#   'año',
#   'paridad',
#   'pesodólar',
#   'pasará',
#   'ó',
#   'unidad',
#   'sector',
#   'empresarial',
#   'pendiente',
#   'prefieren',
#   'conservar',
#   'dólares',
#   'invertir',
#   'pesos',
#   'nuevas',
#   'empresas',
#   'además',
#   'sector',
#   'cae',
#   'especulación',
#   'mismo',
#   'gobierno',
#   'pequeño',
#   'ahorrador',
#   'sabe',
#   'hacer',
#   'persiste',
#   'desconfianza',
#   'mientras',
#   'generan',
#   'nuevas',
#   'fuentes',
#   'empleo',
#   'cce',
#   'prevé',
#   'año',
#   'producto',
#   'interno',
#   'bruto',
#   'elevarse',
#   'inflación',
#   'aproximadamente',
#   'mitad',
#   'respecto',
#   'año',
#   'anterior',
#   'ojalá',
#   'cumpla',
#   'pues',
#   'viendo',
#   'cómo',
#   'aumentan',
#   'carencias',
#   'pueblo',
#   'crece',
#   'pobreza',
#   'llega',
#   'situaciones',
#   'críticas',
#   'debemos',
#   'pesimistas',
#   'tampoco',
#   'engañarnos',
#   'cosas',
#   'van',
#   'mejor',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxedihtml'],
#  ['lunes',
#   'abril',
#   'regaño',
#   'episcopal',
#   'caso',
#   'buenos',
#   'cristianos',
#   'semana',
#   'santa',
#   'mejor',
#   'dicho',
#   'debiera',
#   'motivo',
#   'honda',
#   'reflexión',
#   'sentido',
#   'crucifixión',
#   'muerte',
#   'jesús',
#   'pretexto',
#   'holganza',
#   'excesos',
#   'toda',
#   'índole',
#   'partir',
#   'ayer',
#   'domingo',
#   'ramos',
#   'ojalá',
#   'prevalecieran',
#   'humildad',
#   'virtudes',
#   'lamentablemente',
#   'olvidadas',
#   'sentido',
#   'arzobispo',
#   'méxico',
#   'pida',
#   'políticos',
#   'empresarios',
#   'líderes',
#   'sociales',
#   'mexicanos',
#   'debió',
#   'decir',
#   'mensaje',
#   'aunque',
#   'mayoría',
#   'pueda',
#   'atenderlo',
#   'dejar',
#   'lado',
#   'ostentación',
#   'prepotencia',
#   'lujos',
#   'innecesarios',
#   'ofenden',
#   'miseria',
#   'agobia',
#   'cientos',
#   'miles',
#   'familias',
#   'arzobispo',
#   'norberto',
#   'rivera',
#   'carrera',
#   'secundaron',
#   'obispos',
#   'felipe',
#   'arizmendi',
#   'javier',
#   'lozano',
#   'aprovecha',
#   'oportunidad',
#   'atacar',
#   'gobierno',
#   'hoy',
#   'moda',
#   'hagan',
#   'empresarios',
#   'hace',
#   'apoyaban',
#   'tono',
#   'impropio',
#   'dijo',
#   'sociedad',
#   'deben',
#   'lavarse',
#   'manos',
#   'tomar',
#   'decisiones',
#   'perversas',
#   'débiles',
#   'lesionen',
#   'realidad',
#   'millones',
#   'pobres',
#   'hambrientos',
#   'viven',
#   'largo',
#   'territorio',
#   'nacional',
#   'prelado',
#   'dice',
#   'debió',
#   'decir',
#   'gobierno',
#   'pues',
#   'sociedad',
#   'forma',
#   'parte',
#   'aquél',
#   'hecha',
#   'aclaración',
#   'cabe',
#   'preguntar',
#   'arzobispo',
#   'decisiones',
#   'perversas',
#   'pueden',
#   'tomar',
#   'tomado',
#   'gobierno',
#   'sociedad',
#   'perjuicio',
#   'pobres',
#   'quiere',
#   'decir',
#   'señalar',
#   'autoridades',
#   'deben',
#   'lavarse',
#   'manos',
#   'ahora',
#   'moda',
#   'clérigos',
#   'critiquen',
#   'poder',
#   'público',
#   'menos',
#   'debe',
#   'pedírsele',
#   'precisión',
#   'acusaciones',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxedihtml'],
#  ['lunes',
#   'abril',
#   'desalojos',
#   'violencia',
#   'prosiguen',
#   'chiapas',
#   'violencia',
#   'desalojos',
#   'invasiones',
#   'tierra',
#   'abuso',
#   'campesinado',
#   'terminarse',
#   'acuerdo',
#   'agrario',
#   'dotación',
#   'tierras',
#   'régimen',
#   'perdió',
#   'herramienta',
#   'control',
#   'últimos',
#   'dos',
#   'años',
#   'calcula',
#   'gobierno',
#   'estatal',
#   'destinado',
#   'debido',
#   'levantamiento',
#   'ezln',
#   'millones',
#   'pesos',
#   'compra',
#   'tierras',
#   'adjudicarlas',
#   'organizaciones',
#   'campesinas',
#   'apegadas',
#   'gobierno',
#   'detectado',
#   'muchas',
#   'irregularidades',
#   'aplicación',
#   'política',
#   'advierte',
#   'uso',
#   'mano',
#   'dura',
#   'tratan',
#   'apoderarse',
#   'pedazo',
#   'tierra',
#   'poder',
#   'vivir',
#   'problema',
#   'tierra',
#   'terminará',
#   'mientras',
#   'aplique',
#   'adecuadamente',
#   'justa',
#   'distribución',
#   'campos',
#   'miras',
#   'riqueza',
#   'producto',
#   'cultivo',
#   'equitativamente',
#   'distribuida',
#   'asignaciones',
#   'fondos',
#   'indemnizaciones',
#   'mal',
#   'controlados',
#   'convierten',
#   'recurso',
#   'enriquecimiento',
#   'ilegal',
#   'funcionarios',
#   'negocios',
#   'surgen',
#   'socaire',
#   'subvenciones',
#   'pagan',
#   'tierra',
#   'dan',
#   'muestras',
#   'mansedumbre',
#   'política',
#   'reciben',
#   'terreno',
#   'peor',
#   'represión',
#   'brutal',
#   'sigue',
#   'aumentando',
#   'lista',
#   'crímenes',
#   'enfrentamientos',
#   'impiden',
#   'adecuada',
#   'conciliación',
#   'intereses',
#   'diálogo',
#   'fructífero',
#   'establecer',
#   'firmemente',
#   'sistema',
#   'favorezca',
#   'sufridos',
#   'indígenas',
#   'respetar',
#   'propietarios',
#   'haciendas',
#   'respeto',
#   'merece',
#   'hambre',
#   'desventurados',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxexehtml'],
#  ['lunes',
#   'abril',
#   'salieron',
#   'país',
#   'millones',
#   'dls',
#   'febrero',
#   'ceesp',
#   'significan',
#   'casi',
#   'captado',
#   'enero',
#   'volatilidad',
#   'desequilibrios',
#   'financieros',
#   'extendieron',
#   'trimestre',
#   'después',
#   'abril',
#   'reanudarán',
#   'tasas',
#   'interés',
#   'tendencia',
#   'baja',
#   'prevé',
#   'apenas',
#   'valor',
#   'real',
#   'pib',
#   'igualará',
#   'nivel',
#   'logrado',
#   'embargo',
#   'inversión',
#   'consumo',
#   'privado',
#   'tardarán',
#   'tiempo',
#   'recuperarse',
#   'abatir',
#   'inflación',
#   'inducir',
#   'comportamiento',
#   'congruente',
#   'tipo',
#   'cambio',
#   'urge',
#   'fortalecer',
#   'actividades',
#   'productivas',
#   'gasto',
#   'puede',
#   'afectar',
#   'macroeconomía',
#   'resulta',
#   'pequeña',
#   'influencia',
#   'ejerce',
#   'aplicación',
#   'presupuesto',
#   'público',
#   'afirma',
#   'pide',
#   'reducir',
#   'carga',
#   'fiscal',
#   'fomento',
#   'industrial',
#   'mayor',
#   'impulso',
#   'exportaciones',
#   'alberto',
#   'navarrete',
#   'volatilidad',
#   'desequilibrios',
#   'financieros',
#   'primer',
#   'trimestre',
#   'año',
#   'originaron',
#   'sólo',
#   'febrero',
#   'salieran',
#   'país',
#   'millones',
#   'dólares',
#   'cifra',
#   'equivale',
#   'casi',
#   'ciento',
#   'millones',
#   'dólares',
#   'ingresado',
#   'enero',
#   'medio',
#   'mercado',
#   'dinero',
#   'bolsa',
#   'valores',
#   'reveló',
#   'centro',
#   'estudios',
#   'económicos',
#   'sector',
#   'privado',
#   'ceesp',
#   'reporte',
#   'información',
#   'básica',
#   'toma',
#   'decisiones',
#   'documento',
#   'carácter',
#   'restringido',
#   'organismo',
#   'iniciativa',
#   'privada',
#   'señaló',
#   'después',
#   'abril',
#   'tasas',
#   'intereses',
#   'reanuden',
#   'tendencia',
#   'baja',
#   'materia',
#   'crecimiento',
#   'económico',
#   'reconoció',
#   'si',
#   'bien',
#   'valor',
#   'real',
#   'producto',
#   'interno',
#   'bruto',
#   'igualará',
#   'nivel',
#   'dentro',
#   'par',
#   'años',
#   'inversión',
#   'consumo',
#   'privado',
#   'requerirán',
#   'periodo',
#   'prologado',
#   'recuperarse',
#   'ello',
#   'virtud',
#   'consumo',
#   'privado',
#   'decreció',
#   'ciento',
#   'significa',
#   'caída',
#   'veces',
#   'registrada',
#   'pib',
#   'mismo',
#   'año',
#   'comparación',
#   'parte',
#   'inversión',
#   'total',
#   'año',
#   'pasado',
#   'ciento',
#   'baja',
#   'hecho',
#   'situó',
#   'niveles',
#   'similares',
#   'significó',
#   'retroceso',
#   'cinco',
#   'años',
#   'acuerdo',
#   'organismo',
#   'análisis',
#   'empresarial',
#   'perspectivas',
#   'recuperación',
#   'económica',
#   'año',
#   'enfrentan',
#   'problemas',
#   'específicos',
#   'reto',
#   'actual',
#   'política',
#   'económica',
#   'doble',
#   'parte',
#   'dice',
#   'imprescindible',
#   'consolidar',
#   'estabilidad',
#   'principales',
#   'variables',
#   'financieras',
#   'abatir',
#   'presiones',
#   'inflacionarias',
#   'inducir',
#   'comportamiento',
#   'congruente',
#   'tipo',
#   'cambio',
#   'igualmente',
#   'urgente',
#   'actividades',
#   'productivas',
#   'fortalezcan',
#   'implicaría',
#   'utilizar',
#   'instrumentos',
#   'expansión',
#   'gasto',
#   'agregado',
#   'podrían',
#   'alterar',
#   'precario',
#   'equilibrio',
#   'macroeconómico',
#   'junto',
#   'tema',
#   'rezgo',
#   'aplicación',
#   'gasto',
#   'público',
#   'órgano',
#   'análisis',
#   'cúpula',
#   'empresarial',
#   'desmitifica',
#   'alcance',
#   'mismo',
#   'recursos',
#   'públicos',
#   'si',
#   'bien',
#   'gasto',
#   'público',
#   'puede',
#   'operar',
#   'disparador',
#   'catalizador',
#   'recuperación',
#   'influencia',
#   'desempeño',
#   'general',
#   'economía',
#   'pequeña',
#   'grado',
#   'presupuesto',
#   'total',
#   'gobierno',
#   'representa',
#   'equivalente',
#   'cuarta',
#   'parte',
#   'pib',
#   'ello',
#   'tomando',
#   'cuenta',
#   'gasto',
#   'federal',
#   'aumentará',
#   'términos',
#   'reales',
#   'respecto',
#   'realidad',
#   'desembolso',
#   'íntegro',
#   'representará',
#   'adición',
#   'neta',
#   'expansión',
#   'pib',
#   'estimulos',
#   'inversion',
#   'allá',
#   'mecanismos',
#   'corto',
#   'plazo',
#   'impidan',
#   'nuevas',
#   'alteraciones',
#   'mercados',
#   'financieros',
#   'sector',
#   'privado',
#   'sostiene',
#   'verdadera',
#   'recuperación',
#   'económica',
#   'deberá',
#   'originarse',
#   'resto',
#   'actividades',
#   'económicas',
#   'gubernamentales',
#   'reclama',
#   'acciones',
#   'inmediatas',
#   'estímulo',
#   'inversión',
#   'consumo',
#   'privado',
#   'disminución',
#   'carga',
#   'fiscal',
#   'política',
#   'industrial',
#   'fomento',
#   'además',
#   'impulso',
#   'indispensable',
#   'exportaciones',
#   'sólo',
#   'manera',
#   'posible',
#   'preparar',
#   'país',
#   'desequilibrios',
#   'nuevamente',
#   'presentó',
#   'principio',
#   'año',
#   'enero',
#   'mercados',
#   'financieros',
#   'arrancaron',
#   'perspectiva',
#   'diferente',
#   'permitió',
#   'ingreso',
#   'inversiones',
#   'extranjeras',
#   'mil',
#   'millones',
#   'dólares',
#   'bolsa',
#   'valores',
#   'millones',
#   'mercado',
#   'dinero',
#   'embargo',
#   'inestabilidad',
#   'febrero',
#   'ahuyentó',
#   'país',
#   'mil',
#   'millones',
#   'sector',
#   'bursátil',
#   'mil',
#   'millones',
#   'dólares',
#   'mercado',
#   'dinero',
#   'desafortunadamente',
#   'economía',
#   'mexicana',
#   'requiere',
#   'todavía',
#   'volumen',
#   'significativo',
#   'recursos',
#   'financieros',
#   'nacionales',
#   'extranjeros',
#   'debido',
#   'ello',
#   'vislumbra',
#   'disminución',
#   'consistente',
#   'tasas',
#   'interés',
#   'primera',
#   'plana',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxexehtml'],
#  ['lunes',
#   'abril',
#   'interminables',
#   'conflictos',
#   'agrarios',
#   'chiapas',
#   'invasiones',
#   'desalojos',
#   'muerte',
#   'recursos',
#   'destinados',
#   'regularización',
#   'desviados',
#   'botín',
#   'millones',
#   'funcionarios',
#   'particulares',
#   'hacienda',
#   'estatal',
#   'compras',
#   'irregulares',
#   'predios',
#   'persiste',
#   'inseguridad',
#   'tenencia',
#   'tierra',
#   'andres',
#   'becerril',
#   'enviado',
#   'iii',
#   'último',
#   'san',
#   'cristobal',
#   'casas',
#   'chis',
#   'marzocon',
#   'firma',
#   'acuerdo',
#   'agrario',
#   'declaración',
#   'chiapas',
#   'terminó',
#   'dotación',
#   'tierras',
#   'gobierno',
#   'perdió',
#   'herramienta',
#   'control',
#   'fundamental',
#   'posibilitó',
#   'espinoso',
#   'asunto',
#   'agrario',
#   'transforme',
#   'interminable',
#   'movimiento',
#   'político',
#   'severas',
#   'consecuencias',
#   'invasiones',
#   'desalojos',
#   'violencia',
#   'muerte',
#   'toda',
#   'historia',
#   'malas',
#   'cosechas',
#   'agro',
#   'entidad',
#   'padecido',
#   'sumarle',
#   'temporal',
#   'reciente',
#   'compra',
#   'tierras',
#   'desesperado',
#   'intento',
#   'atajar',
#   'caótica',
#   'situación',
#   'sólo',
#   'provocó',
#   'corrupción',
#   'calcula',
#   'últimos',
#   'dos',
#   'años',
#   'gobierno',
#   'estatal',
#   'destinado',
#   'regularización',
#   'agraria',
#   'merced',
#   'levantamiento',
#   'armado',
#   'ezln',
#   'millones',
#   'pesos',
#   'equivalentes',
#   'quinta',
#   'parte',
#   'deuda',
#   'estatal',
#   'cuales',
#   'millones',
#   'convirtieron',
#   'botín',
#   'negocio',
#   'redondo',
#   'funcionarios',
#   'públicos',
#   'particulares',
#   'sigue',
#   'prófugos',
#   'justicia',
#   'rodolfo',
#   'ulloa',
#   'flores',
#   'ex',
#   'secretario',
#   'gobierno',
#   'saúl',
#   'prado',
#   'guerrero',
#   'ex',
#   'coordinador',
#   'desarrollo',
#   'agrario',
#   'mandato',
#   'javier',
#   'lópez',
#   'moreno',
#   'acusados',
#   'actual',
#   'administración',
#   'chiapaneca',
#   'presuntos',
#   'responsables',
#   'fraude',
#   'millones',
#   'pesos',
#   'compra',
#   'tierras',
#   'existen',
#   'sendas',
#   'órdenes',
#   'aprehensión',
#   'millones',
#   'pesos',
#   'según',
#   'contraloría',
#   'general',
#   'gobierno',
#   'local',
#   'debieron',
#   'servir',
#   'compra',
#   'predios',
#   'mil',
#   'hectáreas',
#   'municipios',
#   'total',
#   'tres',
#   'cuatro',
#   'mil',
#   'pesos',
#   'hectárea',
#   'gobierno',
#   'consideró',
#   'uniformidad',
#   'tabulador',
#   'precios',
#   'manera',
#   'reforma',
#   'agraria',
#   'chiapas',
#   'afirman',
#   'líderes',
#   'campesinos',
#   'investigadores',
#   'camina',
#   'exactamente',
#   'sentido',
#   'opuesto',
#   'buscaban',
#   'principios',
#   'inspiraron',
#   'lugar',
#   'lograr',
#   'seguridad',
#   'tenencia',
#   'tierra',
#   'entidad',
#   'convertida',
#   'verdadero',
#   'polvorín',
#   'ideales',
#   'justicia',
#   'desarrollo',
#   'libertad',
#   'ven',
#   'cada',
#   'vez',
#   'alejados',
#   'escenario',
#   'agrario',
#   'chiapaneco',
#   'así',
#   'continúan',
#   'colonización',
#   'reforma',
#   'agraria',
#   'integral',
#   'compras',
#   'tierras',
#   'entregar',
#   'dividir',
#   'organizaciones',
#   'recesión',
#   'económica',
#   'superposición',
#   'dotaciones',
#   'conflicto',
#   'armado',
#   'estructuras',
#   'sociales',
#   'tradicionales',
#   'corrupción',
#   'entorpecido',
#   'regularización',
#   'tenencia',
#   'tierra',
#   'chiapas',
#   'ahora',
#   'acuerdo',
#   'agrario',
#   'pasado',
#   'marzo',
#   'pretende',
#   'finiquitar',
#   'escenario',
#   'corrupción',
#   'violencia',
#   'suma',
#   'factor',
#   'preponderante',
#   'obstante',
#   'escritor',
#   'eraclio',
#   'zepeda',
#   'secretario',
#   'gobierno',
#   'eduardo',
#   'robledo',
#   'ahora',
#   'julio',
#   'césar',
#   'ruiz',
#   'ferro',
#   'declaró',
#   'palabra',
#   'desalojo',
#   'prohibida',
#   'gobierno',
#   'chiapaneco',
#   'particular',
#   'partido',
#   'revolución',
#   'democrática',
#   'prd',
#   'lista',
#   'nombres',
#   'personas',
#   'muertas',
#   'enero',
#   'hechos',
#   'chicomuselo',
#   'fecha',
#   'pichucalco',
#   'nicolás',
#   'ruiz',
#   'decesos',
#   'cuestiones',
#   'agrarias',
#   'mayoría',
#   'gerardo',
#   'lio',
#   'méndez',
#   'dariel',
#   'resino',
#   'gordillo',
#   'tomás',
#   'velázquez',
#   'hernández',
#   'víctimas',
#   'chicomuselo',
#   'francisco',
#   'uribe',
#   'hernández',
#   'falleció',
#   'estación',
#   'juárez',
#   'enero',
#   'decesos',
#   'sumaron',
#   'juan',
#   'méndez',
#   'torres',
#   'pedro',
#   'méndez',
#   'torres',
#   'pedro',
#   'méndez',
#   'arcos',
#   'marzo',
#   'salto',
#   'agua',
#   'tumbalá',
#   'mismo',
#   'mes',
#   'murieron',
#   'sebastián',
#   'peña',
#   'díaz',
#   'sebastián',
#   'arcos',
#   'guzmán',
#   'juan',
#   'lópez',
#   'jiménez',
#   'sólo',
#   'tres',
#   'días',
#   'después',
#   'venustiano',
#   'carranza',
#   'cayeron',
#   'israel',
#   'pérez',
#   'gonzález',
#   'manuel',
#   'díaz',
#   'vázquez',
#   'abril',
#   'pasado',
#   'falleció',
#   'florentino',
#   'velasco',
#   'alfaro',
#   'municipio',
#   'margaritas',
#   'junio',
#   'tila',
#   'reportó',
#   'muerte',
#   'héctor',
#   'pérez',
#   'torres',
#   'sabanilla',
#   'julio',
#   'francisco',
#   'alvarez',
# ...
#   'mudo',
#   'película',
#   'gaucho',
#   'méxico',
#   'actuó',
#   'teatro',
#   'lado',
#   'virginia',
#   'fábregas',
#   'última',
#   'actuación',
#   'serie',
#   'histórica',
#   'televisión',
#   'senda',
#   'gloria',
#   'muchas',
#   'veces',
#   'actuó',
#   'lado',
#   'esposo',
#   'roberto',
#   'panzón',
#   'soto',
#   'huellas',
#   'quedaron',
#   'teatro',
#   'chino',
#   'hollywood',
#   'aunque',
#   'aspiración',
#   'inicial',
#   'convertirse',
#   'doctora',
#   'teatro',
#   'lírico',
#   'descubrió',
#   'empresario',
#   'estadunidense',
#   'firmó',
#   'contrato',
#   'cinco',
#   'años',
#   'ingreso',
#   'dólares',
#   'semana',
#   'allá',
#   'filmó',
#   'tres',
#   'películas',
#   'español',
#   'grandes',
#   'planes',
#   'querían',
#   'convertir',
#   'mary',
#   'pickfford',
#   'latina',
#   'maestros',
#   'actuación',
#   'canto',
#   'baile',
#   'inglés',
#   'según',
#   'admitió',
#   'dedicó',
#   'diversión',
#   'hollywood',
#   'emilio',
#   'indio',
#   'fernández',
#   'rené',
#   'cardona',
#   'reprobó',
#   'examen',
#   'ello',
#   'cancelaron',
#   'contrato',
#   'regreso',
#   'méxico',
#   'integró',
#   'cine',
#   'nacional',
#   'hizo',
#   'películas',
#   'descuellan',
#   'sangre',
#   'manda',
#   'viuda',
#   'alegre',
#   'internado',
#   'señoritas',
#   'guerra',
#   'pasteles',
#   'monja',
#   'alférez',
#   'bésame',
#   'hijo',
#   'desobediente',
#   'feria',
#   'san',
#   'marcos',
#   'pobres',
#   'ustedes',
#   'ricos',
#   'últimas',
#   'lagunilla',
#   'barrio',
#   'ii',
#   'tres',
#   'etapas',
#   'vida',
#   'momento',
#   'amargo',
#   'vida',
#   'madre',
#   'falleció',
#   'comunicaron',
#   'actuar',
#   'teatro',
#   'mostró',
#   'profesionalismo',
#   'entonces',
#   'declaró',
#   'debe',
#   'respeto',
#   'público',
#   'paga',
#   'sonreir',
#   'importarle',
#   'problemas',
#   'artista',
#   'años',
#   'debutó',
#   'teatro',
#   'dos',
#   'semanas',
#   'ello',
#   'convirtió',
#   'figura',
#   'compañía',
#   'causó',
#   'placer',
#   'además',
#   'trabajó',
#   'lado',
#   'mejores',
#   'actores',
#   'directores',
#   'dijo',
#   'mayor',
#   'ilusión',
#   'después',
#   'muerta',
#   'público',
#   'recuerde',
#   'sonría',
#   'diga',
#   'delia',
#   'magaña',
#   'payasita',
#   'pobres',
#   'muchísimas',
#   'películas',
#   'obras',
#   'teatrales',
#   'deseo',
#   'nombre',
#   'perdure',
#   'compañeros',
#   'actores',
#   'fallecidos',
#   'ayer',
#   'murió',
#   'años',
#   'edad',
#   'horas',
#   'víctima',
#   'neumonía',
#   'sobrevino',
#   'complicársele',
#   'diabetes',
#   'padecía',
#   'hace',
#   'años',
#   'velada',
#   'agencia',
#   'funeraria',
#   'félix',
#   'cuevas',
#   'mañana',
#   'incinerada',
#   'cenizas',
#   'depositadas',
#   'cripta',
#   'familiar',
#   'iglesia',
#   'san',
#   'felipe',
#   'neri',
#   'ciudad',
#   'satélite',
#   'nacionales',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxnachtml'],
#  ['lunes',
#   'abril',
#   'ocaso',
#   'proyecto',
#   'nacional',
#   'fracaso',
#   'neoliberal',
#   'segunda',
#   'cuatro',
#   'partes',
#   'dr',
#   'javier',
#   'esteinou',
#   'madrid',
#   'crítica',
#   'situación',
#   'global',
#   'país',
#   'aplicación',
#   'modelo',
#   'neoliberal',
#   'llegado',
#   'tal',
#   'nivel',
#   'según',
#   'indicadores',
#   'oficiales',
#   'proyecto',
#   'neoliberal',
#   'conquistó',
#   'últimos',
#   'tiempos',
#   'siguientes',
#   'metas',
#   'deuda',
#   'externa',
#   'país',
#   'ascendió',
#   'millones',
#   'dólares',
#   'convertido',
#   'deuda',
#   'externa',
#   'deuda',
#   'eterna',
#   'economía',
#   'quedó',
#   'deriva',
#   'producto',
#   'interno',
#   'bruto',
#   'pib',
#   'retrocedió',
#   'principios',
#   'decía',
#   'orden',
#   'puntos',
#   'último',
#   'trimestre',
#   'empezaría',
#   'notar',
#   'sólida',
#   'recuperación',
#   'valor',
#   'peso',
#   'depreció',
#   'incapacidad',
#   'banco',
#   'méxico',
#   'defenderlo',
#   'tal',
#   'hizo',
#   'necesario',
#   'surgimiento',
#   'insólito',
#   'anteproyecto',
#   'privado',
#   'principales',
#   'grandes',
#   'empresarios',
#   'mexicanos',
#   'exportan',
#   'cemex',
#   'alfa',
#   'desc',
#   'vitro',
#   'peñoles',
#   'grupo',
#   'carso',
#   'kimberly',
#   'clark',
#   'grupo',
#   'méxico',
#   'formar',
#   'fondo',
#   'contingencia',
#   'osciló',
#   'millones',
#   'dólares',
#   'enfrentar',
#   'embates',
#   'especulativos',
#   'peso',
#   'fijar',
#   'piso',
#   'paridad',
#   'rescatar',
#   'valor',
#   'moneda',
#   'nivel',
#   'extremo',
#   'subvaluación',
#   'colocó',
#   'inflación',
#   'superó',
#   'proyectado',
#   'año',
#   'pasado',
#   'quebraron',
#   'grandes',
#   'instalaciones',
#   'fabriles',
#   'cerraron',
#   'micro',
#   'pequeñas',
#   'empresas',
#   'debido',
#   'altas',
#   'tasas',
#   'intereses',
#   'superaron',
#   'riesgo',
#   'constante',
#   'mayor',
#   'devaluación',
#   'peso',
#   'frente',
#   'dólar',
#   'ciento',
#   'negocios',
#   'restantes',
#   'sobrevivido',
#   'encuentran',
#   'graves',
#   'problemas',
#   'financieros',
#   'coloca',
#   'situación',
#   'virtual',
#   'quiebra',
#   'moratoria',
#   'económica',
#   'frente',
#   'trabajadores',
#   'bancos',
#   'fisco',
#   'pues',
#   'deuda',
#   'creció',
#   'planta',
#   'productiva',
#   'nacional',
#   'sobrevivido',
#   'trabaja',
#   'capacidad',
#   'consecuencia',
#   'falta',
#   'liquidez',
#   'monetaria',
#   'elevado',
#   'costo',
#   'dinero',
#   'planta',
#   'fabril',
#   'momentos',
#   'sólo',
#   'enfrenta',
#   'falta',
#   'mercado',
#   'liquidez',
#   'desplome',
#   'ventas',
#   'deudas',
#   'estratosféricas',
#   'banca',
#   'comercial',
#   'sino',
#   'ahora',
#   'encara',
#   'desabasto',
#   'materias',
#   'primas',
#   'debido',
#   'encarecimiento',
#   'brutal',
#   'divisas',
#   'total',
#   'mil',
#   'unidades',
#   'transporte',
#   'carga',
#   'país',
#   'tan',
#   'sólo',
#   'funcionando',
#   'baja',
#   'demanda',
#   'servicio',
#   'quedando',
#   'inactivas',
#   'mil',
#   'unidades',
#   'salario',
#   'mínimo',
#   'perdió',
#   'pérdida',
#   'poder',
#   'adquisitivo',
#   'últimos',
#   'años',
#   'suma',
#   'colocándose',
#   'bajos',
#   'mundo',
#   'ejemplo',
#   'mientras',
#   'unidos',
#   'trabajador',
#   'recibe',
#   'promedio',
#   'dólares',
#   'día',
#   'labor',
#   'méxico',
#   'solamente',
#   'recibe',
#   'dos',
#   'dólares',
#   'mano',
#   'obra',
#   'mexicana',
#   'recibe',
#   'menos',
#   'argentina',
#   'menos',
#   'colombia',
#   'menos',
#   'brasil',
#   'menos',
#   'india',
#   'crisis',
#   'modificó',
#   'distribución',
#   'ingreso',
#   'tal',
#   'forma',
#   'creció',
#   'proporción',
#   'trabajadores',
#   'menos',
#   'ingresos',
#   'bajó',
#   'participación',
#   'empleados',
#   'mayores',
#   'niveles',
#   'salariales',
#   'ejemplo',
#   'porcentaje',
#   'población',
#   'ocupada',
#   'ingresos',
#   'menores',
#   'salario',
#   'mínimo',
#   'pasó',
#   'diciembre',
#   'agosto',
#   'mismo',
#   'periodo',
#   'trabajadores',
#   'ocupados',
#   'ganan',
#   'dos',
#   'salarios',
#   'mínimos',
#   'aumentó',
#   'contrario',
#   'ganan',
#   'dos',
#   'cinco',
#   'salarios',
#   'mínimos',
#   'bajó',
#   'decir',
#   'raíz',
#   'crisis',
#   'enfrenta',
#   'país',
#   'trabajadores',
#   'ganan',
#   'menos',
#   'menos',
#   'ganan',
#   'abandono',
#   'proyecto',
#   'agropecuario',
#   'últimas',
#   'décadas',
#   'ocasionó',
#   'después',
#   'haber',
#   'país',
#   'exportador',
#   'granos',
#   'ahora',
#   'perdido',
#   'seguridad',
#   'alimentaria',
#   'convertido',
#   'nación',
#   'importadora',
#   'miles',
#   'toneladas',
#   'anuales',
#   'alimentos',
#   'generó',
#   'nivel',
#   'productividad',
#   'ramo',
#   'bajara',
#   'dejaran',
#   'cultivar',
#   'mil',
#   'hectáreas',
#   'granos',
#   'básicos',
#   'provocando',
#   'importación',
#   'millones',
#   'toneladas',
#   'maíz',
#   'millones',
#   'habitantes',
#   'dependemos',
#   'importación',
#   'alimentos',
#   'ejemplo',
#   'simplemente',
#   'maíz',
#   'importar',
#   'millón',
#   'toneladas',
#   'completar',
#   'nutrición',
#   'sociedad',
#   'ello',
#   'alrededor',
#   'superficie',
#   'agrícola',
#   'país',
#   'ciclo',
#   'primaveraverano',
#   'quedó',
#   'cultivarse',
#   'incosteabilidad',
#   'falta',
#   'apoyo',
#   'financiero',
#   'sector',
#   'población',
#   'campesina',
#   'quedó',
#   'marginada',
#   'beneficios',
#   'proyecto',
#   'modernizador',
#   'ocasionó',
#   'últimos',
#   'seis',
#   'años',
#   'menos',
#   'productores',
#   'rurales',
#   'diariamente',
#   'abandonaran',
#   'actividad',
#   'campesina',
#   'emigrando',
#   'ciudades',
#   'unidos',
#   'reduciéndose',
#   'drásticamente',
#   'producción',
#   'principales',
#   'cultivos',
#   'nacionales',
#   'sector',
#   'bancario',
#   'enfrentó',
#   'peor',
#   'crisis',
#   'años',
#   'treinta',
#   'salir',
#   'desastre',
#   'financiero',
#   'recibió',
#   'apoyos',
#   'oficiales',
#   'millones',
#   'nuevos',
#   'pesos',
#   'millones',
#   'dólares',
#   'vía',
#   'fondo',
#   'bancario',
#   'protección',
#   'ahorro',
#   'fobaproa',
#   'equivalen',
#   'producto',
#   'interno',
#   'bruto',
#   'estimado',
#   'embargo',
#   'obstante',
#   'apoyo',
#   'monumental',
#   'recuperación',
#   'banca',
#   'utilidades',
#   'bajaron',
#   'significa',
#   'sobrevivir',
#   'sistemaenancario',
#   'todavía',
#   'requiere',
#   'apoyos',
#   'adicionales',
#   'mil',
#   'millones',
#   'nuevos',
#   'pesos',
#   'ligeramente',
#   'superiores',
#   'pib',
#   'pues',
#   'carteras',
#   'vencidas',
#   'seguido',
#   'creciendo',
#   'notablemente',
#   'ejemplo',
#   'resultado',
#   'aplicación',
#   'elevadas',
#   'tasas',
#   'interés',
#   'cartera',
#   'vencida',
#   'sistema',
#   'bancario',
#   'mexicano',
#   'gobiernos',
#   'estatales',
#   'municipios',
#   'país',
#   'creció',
#   'primeros',
#   'ocho',
#   'meses',
#   'administración',
#   'presidente',
#   'ernesto',
#   'zedillo',
#   'colocando',
#   'mayoría',
#   'municipios',
#   'virtual',
#   'quiebra',
#   'financiera',
#   'pese',
#   'esquemas',
#   'reestructuración',
#   'adeudos',
#   'impulsados',
#   'banca',
#   'estatal',
#   'privada',
#   'cartera',
#   'vencida',
#   'créditos',
#   'generales',
#   'crecieron',
#   'cartera',
#   'vencida',
#   'agro',
#   'creció',
#   'términos',
#   'nominales',
#   'cartera',
#   'vencida',
#   'créditos',
#   'corporativos',
#   'creció',
#   'otorgamiento',
#   'crédito',
#   'desplomó',
#   'país',
#   'desempleo',
#   'abierto',
#   'duplicó',
#   'alcanzando',
#   'personas',
#   'población',
#   'económicamente',
#   'activa',
#   'provocando',
#   'primeros',
#   'seis',
#   'meses',
#   'gobierno',
#   'pérdida',
#   'empleos',
#   'generados',
#   'últimos',
#   'años',
#   'desocupación',
#   'rural',
#   'urbana',
#   'ello',
#   'sector',
#   'informal',
#   'economía',
#   'crecido',
#   'últimos',
#   'años',
#   'dejando',
#   'subempleo',
#   'millones',
#   'personas',
#   'promedio',
#   'escolarización',
#   'país',
#   'permanece',
#   'año',
#   'primaria',
#   'mental',
#   'meta',
#   'conseguido',
#   'época',
#   'superado',
#   'términos',
#   'reales',
#   'metas',
#   'revolución',
#   'educativa',
#   'josé',
#   'vasconcelos',
#   'profundizada',
#   'lázaro',
#   'cárdenas',
#   'sino',
#   'acentuado',
#   'deterioro',
#   'calidad',
#   'educación',
#   'global',
#   'notas',
#   'inflación',
#   'caerá',
#   'pib',
#   'abascal',
#   'excelsior',
#   'octubre',
#   'persistente',
#   'retroceso',
#   'desarrollo',
#   'económico',
#   'financiero',
#   'octubre',
#   'crecimiento',
#   'realmente',
#   'vigoroso',
#   'mediados',
#   'gom',
#   'excelsior',
#   'noviembre',
#   'alcanzará',
#   'caída',
#   'pib',
#   'cierre',
#   'valenzuela',
#   'financiero',
#   'diciembre',
#   'pib',
#   'desplomará',
#   'excelsior',
#   'diciembre',
#   'fondo',
#   'millones',
#   'dólares',
#   'defender',
#   'peso',
#   'propondrán',
#   'exportadores',
#   'excelsior',
#   'noviembre',
#   'economía',
#   'deriva',
#   'excelsior',
#   'diciembre',
#   'inflación',
#   'alza',
#   'tarifas',
#   'públicas',
#   'secretaría',
#   'hacienda',
#   'excelsior',
#   'noviembre',
#   'cerraron',
#   'mil',
#   'pequeñas',
#   'empresas',
#   'país',
#   'excelsior',
#   'diciembre',
#   'casi',
#   'quiebra',
#   'mil',
#   'empresas',
#   'bancos',
#   'pueden',
#   'paralizar',
#   'planta',
#   'productiva',
#   'salcedo',
#   'excelsior',
#   'septiembre',
#   'empresas',
#   'problemas',
#   'financieros',
#   'ip',
#   'excelsior',
#   'octubre',
#   'desempleo',
#   'millones',
#   'inflación',
#   'cierre',
#   'mil',
#   'empresas',
#   'ip',
#   'excelsior',
#   'octubre',
#   'industrias',
#   'riesgo',
#   'moratoria',
#   'general',
#   'alerta',
#   'canacintra',
#   'financiero',
#   'octubre',
#   'problemas',
#   'empresas',
#   'afirma',
#   'coparmex',
#   'excelsior',
#   'octubre',
#   'industria',
#   'borde',
#   'moratoria',
#   'financiero',
#   'noviembre',
#   'incompatible',
#   'modelo',
#   'necesidades',
#   'planta',
#   'fabril',
#   'financiero',
#   'noviembre',
#   'moratoria',
#   'obligada',
#   'empresas',
#   'país',
#   'ane',
#   'excelsior',
#   'noviembre',
#   'peso',
#   'devaluó',
#   'cerraron',
#   'mil',
#   'empresas',
#   'excelsior',
#   'diciembre',
#   'sectores',
#   'productivos',
#   'pared',
#   'deuda',
#   'creció',
#   'financiero',
#   'diciembre',
#   'quiebra',
#   'planta',
#   'productiva',
#   'financiero',
#   'diciembre',
#   'dicha',
#   'situación',
#   'tan',
#   'grave',
#   'simplemente',
#   'mayo',
#   'quebraron',
#   'país',
#   'micro',
#   'pequeñas',
#   'industrias',
#   'consecuencia',
#   'apertura',
#   'comercial',
#   'crisis',
#   'generada',
#   'política',
#   'neoliberal',
#   'quebraron',
#   'fábricas',
#   'méxico',
#   'últimos',
#   'años',
#   'uanl',
#   'excelsior',
#   'septiembre',
#   'caída',
#   'demanda',
#   'prendas',
#   'vestir',
#   'provocó',
#   'quiebra',
#   'menos',
#   'empresas',
#   'desocupados',
#   'cayeron',
#   'ventas',
#   'industria',
#   'vestido',
#   'cniv',
#   'excelsior',
#   'noviembre',
#   'primeros',
#   'meses',
#   'cerrado',
#   'puertas',
#   'menos',
#   'farmacias',
#   'independientes',
#   'país',
#   'concecuencia',
#   'actual',
#   'crisis',
#   'económica',
#   'cierran',
#   'puertas',
#   'farmacias',
#   'país',
#   'va',
#   'año',
#   'canaco',
#   'universal',
#   'noviembre',
#   'sector',
#   'restaurantero',
#   'quebrado',
#   'empresas',
#   'quedado',
#   'desempleados',
#   'personas',
#   'van',
#   'desempleados',
#   'ramo',
#   'restaurantero',
#   'país',
#   'excelsior',
#   'octubre',
#   'mermada',
#   'planta',
#   'productiva',
#   'financiero',
#   'octubre',
#   'inicia',
#   'desabasto',
#   'materias',
#   'primas',
#   'financiero',
#   'noviembre',
#   'inactivas',
#   'mil',
#   'unidades',
#   'transporte',
#   'carga',
#   'méxico',
#   'excelsior',
#   'noviembre',
#   'acelerado',
#   'deterioro',
#   'salario',
#   'mínimo',
#   'año',
#   'universal',
#   'noviembre',
#   'salario',
#   'mínimo',
#   'bajos',
#   'mundo',
#   'excelsior',
#   'noviembre',
#   'cae',
#   'salario',
#   'industrial',
#   'niveles',
#   'universal',
#   'diciembre',
#   'modifica',
#   'crisis',
#   'distribución',
#   'ingresos',
#   'universal',
#   'noviembre',
#   'bajó',
#   'producción',
#   'agro',
#   'aumentó',
#   'emigración',
#   'eu',
#   'lópez',
#   'g',
#   'universal',
#   'diciembre',
#   'recuperación',
#   'agropecuaria',
#   'requerirá',
#   'varios',
#   'años',
#   'labastida',
#   'jornada',
#   'diciembre',
#   'importarán',
#   'año',
#   'toneladas',
#   'maíz',
#   'universal',
#   'enero',
#   'desaparecen',
#   'empresas',
#   'universal',
#   'octubre',
#   'ociosa',
#   'superficie',
#   'agrícola',
#   'universal',
#   'octubre',
#   'abandonaron',
#   'diario',
#   'labor',
#   'productores',
#   'rurales',
#   'seis',
#   'años',
#   'universal',
#   'febrero',
#   'banca',
#   'enfrenta',
#   'peor',
#   'crisis',
#   'años',
#   'treinta',
#   'excelsior',
#   'diciembre',
#   'millones',
#   'costo',
#   'oficial',
#   'rescate',
#   'banca',
#   'universal',
#   'diciembre',
#   'inevitable',
#   'rescate',
#   'bancos',
#   'universal',
#   'diciembre',
#   'cayeron',
#   'utilidades',
#   'bancarias',
#   'excelsior',
#   'diciembre',
#   'necesita',
#   'banca',
#   'n$',
#   'mil',
#   'millones',
#   'superar',
#   'crisis',
#   'inverlat',
#   'financiero',
#   'diciembre',
#   'asfixian',
#   'réditos',
#   'financiero',
#   'octubre',
#   'perversión',
#   'economía',
#   'elevar',
#   'tasas',
#   'retener',
#   'capitales',
#   'pacheco',
#   's',
#   'excelsior',
#   'noviembre',
#   'cartera',
#   'vencida',
#   'creció',
#   'excelsior',
#   'diciembre',
#   'cartera',
#   'vencida',
#   'agro',
#   'banc',
#   'áprivada',
#   'creció',
#   'jornada',
#   'diciembre',
#   'frena',
#   'agro',
#   'elevada',
#   'cartera',
#   'vencida',
#   'cna',
#   'universal',
#   'diciembre',
#   'nuevo',
#   'impulso',
#   'cartera',
#   'vencida',
#   'llega',
#   'áócfel',
#   'financiero',
#   'diciembre',
#   'disminuyó',
#   'crédito',
#   'bancario',
#   'nacional',
#   'excelsior',
#   'diciembre',
#   'perdidos',
#   'meses',
#   'empleos',
#   'generados',
#   'años',
#   'sindicatos',
#   'excelsior',
#   'septiembre',
#   'economía',
#   'informal',
#   'empleo',
#   'pea',
#   'financiero',
#   'septiembre',
#   'crecido',
#   'sector',
#   'informal',
#   'últimos',
#   'seis',
#   'años',
#   'rosado',
#   'garcía',
#   'universal',
#   'octubre',
#   'alcanza',
#   'desempleo',
#   'millones',
#   'universal',
#   'octubre',
#   'millones',
#   'mexicanos',
#   'viven',
#   'subempleo',
#   'excelsior',
#   'octubre',
#   'llegó',
#   'desempleo',
#   'índice',
#   'alto',
#   'inegi',
#   'excelsior',
#   'noviembre',
#   'duplicó',
#   'año',
#   'tasa',
#   ...]]

# %%
dictionary_all = corpora.Dictionary(lemmatized_articles_docs)

# %%
doc_term_matrix_all = [dictionary_all.doc2bow(doc) for doc in lemmatized_articles_docs]

# %%
Lda = gensim.models.ldamodel.LdaModel

# %%
ldamodel_all = Lda(doc_term_matrix_all, num_topics = 4, id2word = dictionary_all, passes = 500)

# %%
print(ldamodel_all.print_topics(num_topics = 4, num_words = 5))
# Out:
# [(0, '0.005*"excelsior" + 0.004*"internet" + 0.004*"millones" + 0.004*"años" + 0.004*"empresas"'), (1, '0.004*"millones" + 0.004*"si" + 0.004*"méxico" + 0.003*"abril" + 0.003*"mil"'), (2, '0.005*"trabajadores" + 0.004*"gobierno" + 0.004*"señor" + 0.003*"día" + 0.003*"méxico"'), (3, '0.006*"gobierno" + 0.004*"millones" + 0.004*"pesos" + 0.003*"sólo" + 0.003*"mil"')]

# %% [markdown]
# Then we are going to try with the second article of the selected text file.

# %%
lemmatized_article_2 = [lemmatized_articles_docs[1]]

# %%
lemmatized_article_2
# Out:
# [['martes',
#   'abril',
#   'scalfaro',
#   'aquí',
#   'allá',
#   'juan',
#   'maria',
#   'alponte',
#   'julio',
#   'villa',
#   'gagia',
#   'benito',
#   'mussolini',
#   'recibía',
#   'adolf',
#   'hitler',
#   'viajara',
#   'tren',
#   'italia',
#   'someter',
#   'dictador',
#   'italiano',
#   'larga',
#   'furiosa',
#   'requisitoria',
#   'comportamiento',
#   'manifiestamente',
#   'malo',
#   'dice',
#   'tropas',
#   'italianas',
#   'alemanes',
#   'sienten',
#   'heridos',
#   'julio',
#   'sicilia',
#   'desembarcado',
#   'angloamericanos',
#   'base',
#   'militar',
#   'augusta',
#   'rendido',
#   'hitler',
#   'exasperado',
#   'quiere',
#   'aceptar',
#   'italianos',
#   'quieren',
#   'combatir',
#   'mediodía',
#   'día',
#   'entrevista',
#   'cortada',
#   'secretario',
#   'duce',
#   'portaba',
#   'telegrama',
#   'voz',
#   'emocionada',
#   'mussolini',
#   'traduce',
#   'alemán',
#   'momento',
#   'enemigo',
#   'bombardea',
#   'roma',
#   'muertos',
#   'heridos',
#   'julio',
#   'palacio',
#   'venecia',
#   'produjo',
#   'partir',
#   'cinco',
#   'tarde',
#   'aquel',
#   'sábado',
#   'sombrío',
#   'acontecimientos',
#   'insólitos',
#   'viera',
#   'italia',
#   'día',
#   'duce',
#   'preside',
#   'así',
#   'cree',
#   'reunión',
#   'rutina',
#   'gran',
#   'consejo',
#   'fascista',
#   'rutina',
#   'gran',
#   'consejo',
#   'aprobará',
#   'moción',
#   'extraordinaria',
#   'moción',
#   'grandi',
#   'dejándole',
#   'minoría',
#   'pidiendo',
#   'poderes',
#   'posee',
#   'duce',
#   'traspasen',
#   'rey',
#   'día',
#   'siguiente',
#   'domingo',
#   'mussolini',
#   'acude',
#   'palacio',
#   'real',
#   'mientras',
#   'escucha',
#   'calles',
#   'abbasso',
#   'mussolini',
#   'rey',
#   'alertado',
#   'desposee',
#   'poderes',
#   'momento',
#   'duro',
#   'blando',
#   'dice',
#   'monarca',
#   'allora',
#   'tutto',
#   'finito',
#   'sera',
#   'della',
#   'mia',
#   'famiglia',
#   'comporta',
#   'piccolo',
#   'borghese',
#   'grandeza',
#   'advenedizo',
#   'poder',
#   'ustedes',
#   'saben',
#   'italia',
#   'mussolini',
#   'pasaría',
#   'aliados',
#   'alemanes',
#   'duce',
#   'apresado',
#   'partisanos',
#   'fusilado',
#   'huida',
#   'junio',
#   'país',
#   'referéndum',
#   'elegía',
#   'instituciones',
#   'italianos',
#   'votaron',
#   'república',
#   'monarquía',
#   'consagrara',
#   'marcia',
#   'roma',
#   'famosa',
#   'marcha',
#   'roma',
#   'mussolini',
#   'fascios',
#   'combate',
#   'convirtiéndole',
#   'jefe',
#   'gobierno',
#   'comenzaba',
#   'italia',
#   'edad',
#   'partidos',
#   'consagrando',
#   'democracia',
#   'cristiana',
#   'partido',
#   'mayoritario',
#   'mayoría',
#   'relativa',
#   'formarían',
#   'coaliciones',
#   'gubernamentales',
#   'tempestades',
#   'posguerra',
#   'nación',
#   'italiana',
#   'pese',
#   'fragilidad',
#   'gobiernos',
#   'realizaría',
#   'hazañas',
#   'notables',
#   'económicas',
#   'industriales',
#   'mundo',
#   'actual',
#   'convertido',
#   'siete',
#   'grandes',
#   'millones',
#   'habitantes',
#   'crecimiento',
#   'demográfico',
#   'ingreso',
#   'persona',
#   'dólares',
#   'exportaciones',
#   'alcanzaron',
#   'impresionante',
#   'suma',
#   'millones',
#   'dólares',
#   'importaciones',
#   'millones',
#   'unas',
#   'elecciones',
#   'históricas',
#   'derrumbaba',
#   'régimen',
#   'partitocrazia',
#   'entrarse',
#   'verdadera',
#   'definición',
#   'estabilidad',
#   'enterraba',
#   'pasado',
#   'presente',
#   'fortalecido',
#   'presidente',
#   'oscar',
#   'luigi',
#   'scalfaro',
#   'extraordinaria',
#   'inteligencia',
#   'mesura',
#   'dirigido',
#   'periodo',
#   'complejo',
#   'gobierno',
#   'apresta',
#   'elecciones',
#   'decisivas',
#   'próximo',
#   'mes',
#   'abril',
#   'ello',
#   'momento',
#   'mismo',
#   'italia',
#   'ocupa',
#   'presidencia',
#   'rotativa',
#   'seis',
#   'meses',
#   'europa',
#   'scalfaro',
#   'hoy',
#   'asciende',
#   'nivel',
#   'hombres',
#   'crear',
#   'cenizas',
#   'primera',
#   'república',
#   'cimientos',
#   'segunda',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml']]

# %%
dictionary_art_2 = corpora.Dictionary(lemmatized_article_2)

# %%
doc_term_matrix_art_2 = [dictionary_art_2.doc2bow(doc) for doc in lemmatized_article_2]

# %%
ldamodel_art_2 = Lda(doc_term_matrix_art_2, num_topics = 4, id2word = dictionary_art_2, passes = 500)

# %%
print(ldamodel_art_2.print_topics(num_topics = 4, num_words = 5))
# Out:
# [(0, '0.019*"mussolini" + 0.016*"italia" + 0.013*"duce" + 0.010*"roma" + 0.010*"momento"'), (1, '0.004*"monarquía" + 0.004*"mismo" + 0.004*"nación" + 0.004*"mundo" + 0.004*"muertos"'), (2, '0.004*"monarquía" + 0.004*"mismo" + 0.004*"nación" + 0.004*"mundo" + 0.004*"muertos"'), (3, '0.004*"monarquía" + 0.004*"mismo" + 0.004*"nación" + 0.004*"mundo" + 0.004*"muertos"')]
